# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *
from datetime import date, timedelta, datetime
import requests
import json

# %%
spark = SparkSession.builder \
      .master("local[1]") \
      .appName("SparkByExamples.com") \
      .getOrCreate()

# %% [markdown]
# **IMPORTANDO DADOS DA API IBGE - CIDADES DO VALE DO PARAÍBA**

# %%
try:

    url = requests.get('http://servicodados.ibge.gov.br/api/v1/localidades/mesorregioes/3513/municipios').json()
    api_dumps = json.dumps(url)

except Exception as erro:
        print('Erro de requisição:', erro)

# %% [markdown]
# **EXPORTANDO DADOS PARA UM ARQUIVO JSON**

# %%
with open("/home/rowedder/arquivos_json/cidades_ibge.json", "w") as outfile: 
    outfile.write(api_dumps)

# %% [markdown]
# **IMPORTANDO DADOS**

# %%
dados = spark.read.json('/home/rowedder/arquivos_json/cidades_ibge.json')

# %% [markdown]
# **EXTRAÍNDO DADOS DA API (CIDADE, CODIGO DA CIDADE, ESTADO E REGIÃO)**

# %%
# NOME DAS CIDADES

dados0 = dados.select('nome') # API 1

dados1 = dados.select('nome') # API 2

cidade = [w[0] for w in dados1.collect()] # nomes das cidades da API - Previsão do tempo
dados_nome_cidade1 = [w[0] for w in dados0.collect()] # Popular a primeira tabela


lista_nome_cidade = []  #API 2

for i in dados_nome_cidade1:
    nome = i
    lista_nome_cidade.append(nome)

cidade0 = [lista_nome_cidade[0]] * 40
cidade1 = [lista_nome_cidade[1]] * 40
cidade2 = [lista_nome_cidade[2]] * 40
cidade3 = [lista_nome_cidade[3]] * 40
cidade4 = [lista_nome_cidade[4]] * 40
cidade5 = [lista_nome_cidade[5]] * 40
cidade6 = [lista_nome_cidade[6]] * 40
cidade7 = [lista_nome_cidade[7]] * 40
cidade8 = [lista_nome_cidade[8]] * 40
cidade9 = [lista_nome_cidade[9]] * 40
cidade10 = [lista_nome_cidade[10]] * 40
cidade11 = [lista_nome_cidade[11]] * 40
cidade12 = [lista_nome_cidade[12]] * 40
cidade13 = [lista_nome_cidade[13]] * 40
cidade14 = [lista_nome_cidade[14]] * 40
cidade15 = [lista_nome_cidade[15]] * 40
cidade16 = [lista_nome_cidade[16]] * 40
cidade17 = [lista_nome_cidade[17]] * 40
cidade18 = [lista_nome_cidade[18]] * 40
cidade19 = [lista_nome_cidade[19]] * 40
cidade20 = [lista_nome_cidade[20]] * 40
cidade21 = [lista_nome_cidade[21]] * 40
cidade22 = [lista_nome_cidade[22]] * 40
cidade23 = [lista_nome_cidade[23]] * 40
cidade24 = [lista_nome_cidade[24]] * 40
cidade25 = [lista_nome_cidade[25]] * 40
cidade26 = [lista_nome_cidade[26]] * 40
cidade27 = [lista_nome_cidade[27]] * 40
cidade28 = [lista_nome_cidade[28]] * 40
cidade29 = [lista_nome_cidade[29]] * 40
cidade30 = [lista_nome_cidade[30]] * 40
cidade31 = [lista_nome_cidade[31]] * 40
cidade32 = [lista_nome_cidade[32]] * 40
cidade33 = [lista_nome_cidade[33]] * 40
cidade34 = [lista_nome_cidade[34]] * 40
cidade35 = [lista_nome_cidade[35]] * 40
cidade36 = [lista_nome_cidade[36]] * 40
cidade37 = [lista_nome_cidade[37]] * 40
cidade38 = [lista_nome_cidade[38]] * 40


# CONCATENANDO LISTA DE NOMES DE CIDADES


cidade0.extend(cidade1)
cidade0.extend(cidade2)
cidade0.extend(cidade3)
cidade0.extend(cidade4)
cidade0.extend(cidade5)
cidade0.extend(cidade6)
cidade0.extend(cidade7)
cidade0.extend(cidade8)
cidade0.extend(cidade9)
cidade0.extend(cidade10)
cidade0.extend(cidade11)
cidade0.extend(cidade12)
cidade0.extend(cidade13)
cidade0.extend(cidade14)
cidade0.extend(cidade15)
cidade0.extend(cidade16)
cidade0.extend(cidade17)
cidade0.extend(cidade18)
cidade0.extend(cidade19)
cidade0.extend(cidade20)
cidade0.extend(cidade21)
cidade0.extend(cidade22)
cidade0.extend(cidade23)
cidade0.extend(cidade24)
cidade0.extend(cidade25)
cidade0.extend(cidade26)
cidade0.extend(cidade27)
cidade0.extend(cidade28)
cidade0.extend(cidade29)
cidade0.extend(cidade30)
cidade0.extend(cidade31)
cidade0.extend(cidade32)
cidade0.extend(cidade33)
cidade0.extend(cidade34)
cidade0.extend(cidade35)
cidade0.extend(cidade36)
cidade0.extend(cidade37)
cidade0.extend(cidade38)

column_nome_cidade = cidade0


# CÓDIGO DAS CIDADES

dados2 = dados.select('id')
dados_codigo_cidade = [w[0] for w in dados2.collect()]


lista_codigo_cidade = [] 

for t in dados_codigo_cidade:
    codigo = t
    lista_codigo_cidade.append(codigo)

codigo0 = [lista_codigo_cidade[0]] * 40
codigo1 = [lista_codigo_cidade[1]] * 40
codigo2 = [lista_codigo_cidade[2]] * 40
codigo3 = [lista_codigo_cidade[3]] * 40
codigo4 = [lista_codigo_cidade[4]] * 40
codigo5 = [lista_codigo_cidade[5]] * 40
codigo6 = [lista_codigo_cidade[6]] * 40
codigo7 = [lista_codigo_cidade[7]] * 40
codigo8 = [lista_codigo_cidade[8]] * 40
codigo9 = [lista_codigo_cidade[9]] * 40
codigo10 = [lista_codigo_cidade[10]] * 40
codigo11 = [lista_codigo_cidade[11]] * 40
codigo12 = [lista_codigo_cidade[12]] * 40
codigo13 = [lista_codigo_cidade[13]] * 40
codigo14 = [lista_codigo_cidade[14]] * 40
codigo15 = [lista_codigo_cidade[15]] * 40
codigo16 = [lista_codigo_cidade[16]] * 40
codigo17 = [lista_codigo_cidade[17]] * 40
codigo18 = [lista_codigo_cidade[18]] * 40
codigo19 = [lista_codigo_cidade[19]] * 40
codigo20 = [lista_codigo_cidade[20]] * 40
codigo21 = [lista_codigo_cidade[21]] * 40
codigo22 = [lista_codigo_cidade[22]] * 40
codigo23 = [lista_codigo_cidade[23]] * 40
codigo24 = [lista_codigo_cidade[24]] * 40
codigo25 = [lista_codigo_cidade[25]] * 40
codigo26 = [lista_codigo_cidade[26]] * 40
codigo27 = [lista_codigo_cidade[27]] * 40
codigo28 = [lista_codigo_cidade[28]] * 40
codigo29 = [lista_codigo_cidade[29]] * 40
codigo30 = [lista_codigo_cidade[30]] * 40
codigo31 = [lista_codigo_cidade[31]] * 40
codigo32 = [lista_codigo_cidade[32]] * 40
codigo33 = [lista_codigo_cidade[33]] * 40
codigo34 = [lista_codigo_cidade[34]] * 40
codigo35 = [lista_codigo_cidade[35]] * 40
codigo36 = [lista_codigo_cidade[36]] * 40
codigo37 = [lista_codigo_cidade[37]] * 40
codigo38 = [lista_codigo_cidade[38]] * 40


# CONCATENANDO LISTA DE NOMES DE CIDADES


codigo0.extend(codigo1)
codigo0.extend(codigo2)
codigo0.extend(codigo3)
codigo0.extend(codigo4)
codigo0.extend(codigo5)
codigo0.extend(codigo6)
codigo0.extend(codigo7)
codigo0.extend(codigo8)
codigo0.extend(codigo9)
codigo0.extend(codigo10)
codigo0.extend(codigo11)
codigo0.extend(codigo12)
codigo0.extend(codigo13)
codigo0.extend(codigo14)
codigo0.extend(codigo15)
codigo0.extend(codigo16)
codigo0.extend(codigo17)
codigo0.extend(codigo18)
codigo0.extend(codigo19)
codigo0.extend(codigo20)
codigo0.extend(codigo21)
codigo0.extend(codigo22)
codigo0.extend(codigo23)
codigo0.extend(codigo24)
codigo0.extend(codigo25)
codigo0.extend(codigo26)
codigo0.extend(codigo27)
codigo0.extend(codigo28)
codigo0.extend(codigo29)
codigo0.extend(codigo30)
codigo0.extend(codigo31)
codigo0.extend(codigo32)
codigo0.extend(codigo33)
codigo0.extend(codigo34)
codigo0.extend(codigo35)
codigo0.extend(codigo36)
codigo0.extend(codigo37)
codigo0.extend(codigo38)

column_codigo_cidade = codigo0
#print(len(column_codigo_cidade))

# ESTADO

dados_estado = dados.select('microrregiao.mesorregiao.UF.nome') 

column_estado = [e[0] for e in dados_estado.collect()] * 40
#print(len(column_estado))

# REGIÃO

dados_regiao = dados.select('microrregiao.mesorregiao.UF.regiao.nome') 

column_regiao = [e[0] for e in dados_regiao.collect()] * 40
#print(len(column_regiao))

# %%
api_key = 'Cadastrar a API Key no OpenWeather'
pais = 'BR'
estado = 'SP'

# %%
try:

    url0= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[0]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url1= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[1]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url2= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[2]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url3= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[3]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url4= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[4]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url5= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[5]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url6= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[6]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url7= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[7]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url8= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[8]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url9= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[9]},{estado},{pais}&appid={api_key}&lang=pt_br').json()


    api_dumps0 = json.dumps(url0)
    api_dumps1 = json.dumps(url1)
    api_dumps2 = json.dumps(url2)
    api_dumps3 = json.dumps(url3)
    api_dumps4 = json.dumps(url4)
    api_dumps5 = json.dumps(url5)
    api_dumps6 = json.dumps(url6)
    api_dumps7 = json.dumps(url7)
    api_dumps8 = json.dumps(url8)
    api_dumps9 = json.dumps(url9)
        
except Exception as erro:
    print('Erro de requisição:', erro)

# %%
try:
    
    url10= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[10]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url11= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[11]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url12= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[12]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url13= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[13]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url14= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[14]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url15= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[15]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url16= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[16]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url17= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[17]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url18= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[18]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url19= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[19]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url20= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[20]},{estado},{pais}&appid={api_key}&lang=pt_br').json()

    api_dumps10 = json.dumps(url10)
    api_dumps11 = json.dumps(url11)
    api_dumps12 = json.dumps(url12)
    api_dumps13 = json.dumps(url13)
    api_dumps14 = json.dumps(url14)
    api_dumps15 = json.dumps(url15)
    api_dumps16 = json.dumps(url16)
    api_dumps17 = json.dumps(url17)
    api_dumps18 = json.dumps(url18)
    api_dumps19 = json.dumps(url19)
    api_dumps20 = json.dumps(url20)

except Exception as erro:
        print('Erro de requisição:', erro)

# %%
try:  

    url21= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[21]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url22= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[22]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url23= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[23]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url24= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[24]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url25= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[25]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url26= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[26]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url27= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[27]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url28= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[28]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url29= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[29]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url30= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[30]},{estado},{pais}&appid={api_key}&lang=pt_br').json()

    api_dumps21 = json.dumps(url21)
    api_dumps22 = json.dumps(url22)
    api_dumps23 = json.dumps(url23)
    api_dumps24 = json.dumps(url24)
    api_dumps25 = json.dumps(url25)
    api_dumps26 = json.dumps(url26)
    api_dumps27 = json.dumps(url27)
    api_dumps28 = json.dumps(url28)
    api_dumps29 = json.dumps(url29)
    api_dumps30 = json.dumps(url30)

except Exception as erro:
    print('Erro de requisição:', erro)

# %%
try:

    url31= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[31]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url32= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[32]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url33= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[33]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url34= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[34]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url35= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[35]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url36= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[36]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url37= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[37]},{estado},{pais}&appid={api_key}&lang=pt_br').json()
    url38= requests.get(f'https://api.openweathermap.org/data/2.5/forecast?q={cidade[38]},{estado},{pais}&appid={api_key}&lang=pt_br').json()

    api_dumps31 = json.dumps(url31)
    api_dumps32 = json.dumps(url32)
    api_dumps33 = json.dumps(url33)
    api_dumps34 = json.dumps(url34)
    api_dumps35 = json.dumps(url35)
    api_dumps36 = json.dumps(url36)
    api_dumps37 = json.dumps(url37)
    api_dumps38 = json.dumps(url38)

except Exception as erro:
    print('Erro de requisição:', erro)

# %% [markdown]
# **EXPORTANDO ARQUIVOS JSON**

# %%
# 10 - 20

with open("/home/rowedder/arquivos_json/cidades0.json", "w") as outfile: 
    outfile.write(api_dumps0) 
    
with open("/home/rowedder/arquivos_json/cidades1.json", "w") as outfile: 
    outfile.write(api_dumps1) 

with open("/home/rowedder/arquivos_json/cidades2.json", "w") as outfile: 
    outfile.write(api_dumps2) 
    
with open("/home/rowedder/arquivos_json/cidades3.json", "w") as outfile: 
    outfile.write(api_dumps3) 

with open("/home/rowedder/arquivos_json/cidades4.json", "w") as outfile: 
    outfile.write(api_dumps4) 
    
with open("/home/rowedder/arquivos_json/cidades5.json", "w") as outfile: 
    outfile.write(api_dumps5) 

with open("/home/rowedder/arquivos_json/cidades6.json", "w") as outfile: 
    outfile.write(api_dumps6) 
    
with open("/home/rowedder/arquivos_json/cidades7.json", "w") as outfile: 
    outfile.write(api_dumps7) 

with open("/home/rowedder/arquivos_json/cidades8.json", "w") as outfile: 
    outfile.write(api_dumps8) 
    
with open("/home/rowedder/arquivos_json/cidades9.json", "w") as outfile: 
    outfile.write(api_dumps9) 

with open("/home/rowedder/arquivos_json/cidades10.json", "w") as outfile: 
    outfile.write(api_dumps10) 


# 11 - 20
    

with open("/home/rowedder/arquivos_json/cidades11.json", "w") as outfile: 
    outfile.write(api_dumps11) 

with open("/home/rowedder/arquivos_json/cidades12.json", "w") as outfile: 
    outfile.write(api_dumps12) 
    
with open("/home/rowedder/arquivos_json/cidades13.json", "w") as outfile: 
    outfile.write(api_dumps13) 

with open("/home/rowedder/arquivos_json/cidades14.json", "w") as outfile: 
    outfile.write(api_dumps14) 
    
with open("/home/rowedder/arquivos_json/cidades15.json", "w") as outfile: 
    outfile.write(api_dumps15) 

with open("/home/rowedder/arquivos_json/cidades16.json", "w") as outfile: 
    outfile.write(api_dumps16) 
    
with open("/home/rowedder/arquivos_json/cidades17.json", "w") as outfile: 
    outfile.write(api_dumps17) 

with open("/home/rowedder/arquivos_json/cidades18.json", "w") as outfile: 
    outfile.write(api_dumps18) 
    
with open("/home/rowedder/arquivos_json/cidades19.json", "w") as outfile: 
    outfile.write(api_dumps19) 

with open("/home/rowedder/arquivos_json/cidades20.json", "w") as outfile: 
    outfile.write(api_dumps20) 
    

# 21 - 30


with open("/home/rowedder/arquivos_json/cidades21.json", "w") as outfile: 
    outfile.write(api_dumps21) 

with open("/home/rowedder/arquivos_json/cidades22.json", "w") as outfile: 
    outfile.write(api_dumps22) 
    
with open("/home/rowedder/arquivos_json/cidades23.json", "w") as outfile: 
    outfile.write(api_dumps23) 

with open("/home/rowedder/arquivos_json/cidades24.json", "w") as outfile: 
    outfile.write(api_dumps24) 
    
with open("/home/rowedder/arquivos_json/cidades25.json", "w") as outfile: 
    outfile.write(api_dumps25) 

with open("/home/rowedder/arquivos_json/cidades26.json", "w") as outfile: 
    outfile.write(api_dumps26) 
    
with open("/home/rowedder/arquivos_json/cidades27.json", "w") as outfile: 
    outfile.write(api_dumps27) 

with open("/home/rowedder/arquivos_json/cidades28.json", "w") as outfile: 
    outfile.write(api_dumps28) 
    
with open("/home/rowedder/arquivos_json/cidades29.json", "w") as outfile: 
    outfile.write(api_dumps29) 

with open("/home/rowedder/arquivos_json/cidades30.json", "w") as outfile: 
    outfile.write(api_dumps30) 


# 31 - 38

    
with open("/home/rowedder/arquivos_json/cidades31.json", "w") as outfile: 
    outfile.write(api_dumps31) 

with open("/home/rowedder/arquivos_json/cidades32.json", "w") as outfile: 
    outfile.write(api_dumps32) 
    
with open("/home/rowedder/arquivos_json/cidades33.json", "w") as outfile: 
    outfile.write(api_dumps33) 

with open("/home/rowedder/arquivos_json/cidades34.json", "w") as outfile: 
    outfile.write(api_dumps34) 
    
with open("/home/rowedder/arquivos_json/cidades35.json", "w") as outfile: 
    outfile.write(api_dumps35) 

with open("/home/rowedder/arquivos_json/cidades36.json", "w") as outfile: 
    outfile.write(api_dumps36) 
    
with open("/home/rowedder/arquivos_json/cidades37.json", "w") as outfile: 
    outfile.write(api_dumps37) 

with open("/home/rowedder/arquivos_json/cidades38.json", "w") as outfile: 
    outfile.write(api_dumps38)

# %% [markdown]
# **IMPORTANDO ARQUIVOS JSON**

# %%
dados0 = spark.read.json('/home/rowedder/arquivos_json/cidades0.json')
dados1 = spark.read.json('/home/rowedder/arquivos_json/cidades1.json')
dados2 = spark.read.json('/home/rowedder/arquivos_json/cidades2.json')
dados3 = spark.read.json('/home/rowedder/arquivos_json/cidades3.json')
dados4 = spark.read.json('/home/rowedder/arquivos_json/cidades4.json')
dados5 = spark.read.json('/home/rowedder/arquivos_json/cidades5.json')
dados6 = spark.read.json('/home/rowedder/arquivos_json/cidades6.json')
dados7 = spark.read.json('/home/rowedder/arquivos_json/cidades7.json')
dados8 = spark.read.json('/home/rowedder/arquivos_json/cidades8.json')
dados9 = spark.read.json('/home/rowedder/arquivos_json/cidades9.json')
dados10 = spark.read.json('/home/rowedder/arquivos_json/cidades10.json')
dados11 = spark.read.json('/home/rowedder/arquivos_json/cidades11.json')
dados12 = spark.read.json('/home/rowedder/arquivos_json/cidades12.json')
dados13 = spark.read.json('/home/rowedder/arquivos_json/cidades13.json')
dados14 = spark.read.json('/home/rowedder/arquivos_json/cidades14.json')
dados15 = spark.read.json('/home/rowedder/arquivos_json/cidades15.json')
dados16 = spark.read.json('/home/rowedder/arquivos_json/cidades16.json')
dados17 = spark.read.json('/home/rowedder/arquivos_json/cidades17.json')
dados18 = spark.read.json('/home/rowedder/arquivos_json/cidades18.json')
dados19 = spark.read.json('/home/rowedder/arquivos_json/cidades19.json')
dados20 = spark.read.json('/home/rowedder/arquivos_json/cidades20.json')
dados21 = spark.read.json('/home/rowedder/arquivos_json/cidades21.json')
dados22 = spark.read.json('/home/rowedder/arquivos_json/cidades22.json')
dados23 = spark.read.json('/home/rowedder/arquivos_json/cidades23.json')
dados24 = spark.read.json('/home/rowedder/arquivos_json/cidades24.json')
dados25 = spark.read.json('/home/rowedder/arquivos_json/cidades25.json')
dados26 = spark.read.json('/home/rowedder/arquivos_json/cidades26.json')
dados27 = spark.read.json('/home/rowedder/arquivos_json/cidades27.json')
dados28 = spark.read.json('/home/rowedder/arquivos_json/cidades28.json')
dados29 = spark.read.json('/home/rowedder/arquivos_json/cidades29.json')
dados30 = spark.read.json('/home/rowedder/arquivos_json/cidades30.json')
dados31 = spark.read.json('/home/rowedder/arquivos_json/cidades31.json')
dados32 = spark.read.json('/home/rowedder/arquivos_json/cidades32.json')
dados33 = spark.read.json('/home/rowedder/arquivos_json/cidades33.json')
dados34 = spark.read.json('/home/rowedder/arquivos_json/cidades34.json')
dados35 = spark.read.json('/home/rowedder/arquivos_json/cidades35.json')
dados36 = spark.read.json('/home/rowedder/arquivos_json/cidades36.json')
dados37 = spark.read.json('/home/rowedder/arquivos_json/cidades37.json')
dados38 = spark.read.json('/home/rowedder/arquivos_json/cidades38.json')

# %%
"""
CIDADE 0
"""

# DATA

lista_data0 = dados0.select(explode('list.dt_txt').alias('Data'))
column_data0 = [a[0] for a in lista_data0.collect()]

# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao0 = dados0.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao0 = lista_descricao0\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao0 = lista_descricao0\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao0 = lista_descricao0\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao0 = lista_descricao0\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao0 = lista_descricao0\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao0 = lista_descricao0\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao0 = lista_descricao0\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao0 = [b[0] for b in lista_descricao0.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima0 = dados0.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima0 = lista_temperatura_maxima0\
    .select('*', (lista_temperatura_maxima0['Temp_maxima']- 273).alias('TemperaturaMaxima'))

#3- Diminuindo as casas decimais.
lista_temperatura_maxima0 = lista_temperatura_maxima0\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima0 = lista_temperatura_maxima0.select("TemperaturaMaxima")

column_temperatura_maxima0 = [c[0] for c in lista_temperatura_maxima0.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima0 = dados0.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima0 = lista_temperatura_minima0\
    .select('*', (lista_temperatura_minima0['Temp_minima']- 273).alias('TemperaturaMinima'))

#3- Diminuindo as casas decimais.
lista_temperatura_minima0 = lista_temperatura_minima0\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima0 = lista_temperatura_minima0.select("TemperaturaMinima")

column_temperatura_minima0 = [d[0] for d in lista_temperatura_minima0.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media0 = dados0.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media0 = lista_temperatura_media0\
    .select('*', (lista_temperatura_media0['Temp_media']- 273).alias('TemperaturaMedia'))

#3- Diminuindo as casas decimais.
lista_temperatura_media0 = lista_temperatura_media0\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media0 = lista_temperatura_media0.select("TemperaturaMedia")

column_temperatura_media0 = [e[0] for e in lista_temperatura_media0.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol0 = dados0.select('city.sunrise')
nascer_sol0 = [f[0] for f in lista_nascer_sol0.collect()] * 40

column_nascer_do_sol0 = []

for n in nascer_sol0:
    ns0 = int(n) # Convertendo para int
    ns0 = datetime.fromtimestamp(ns0, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns0 = str(ns0)
    ns0 = ns0[0:19]
    column_nascer_do_sol0.append(ns0)



# POR DO SOL

lista_por_sol0 = dados0.select('city.sunset')
por_sol0 = [g[0] for g in lista_por_sol0.collect()] * 40

column_por_do_sol0 = []

for p in por_sol0:
    ps0 = int(p) # Convertendo para int
    ps0 = datetime.fromtimestamp(ps0, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps0 = str(ps0)
    ps0 = ps0[0:19]
    column_por_do_sol0.append(ps0)
column_por_do_sol0 = column_por_do_sol0 * 40


# LATITUDE

lista_latitude0 = dados0.select('city.coord.lat')
column_latitude0 = [h[0] for h in lista_latitude0.collect()] * 40


# LONGITUDE

lista_longitude0 = dados0.select('city.coord.lon')
column_longitude0 = [j[0] for j in lista_longitude0.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento0 = dados0.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento0 = [l[0] for l in lista_velocidade_vento0.collect()]


# PAÍS (UMA ÚNICA VEZ PARA TODAS AS CIDADES)

lista_pais = dados0.select('city.country')
column_pais = [l[0] for l in lista_pais.collect()] * 1560

#---------------------------------------------------------------------------------------------------------

"""
CIDADE 1
"""

# DATA

lista_data1 = dados1.select (explode('list.dt_txt').alias('Data'))
column_data1 = [a[0] for a in lista_data1.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao1 = dados1.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao1 = lista_descricao1\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao1 = lista_descricao1\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao1 = lista_descricao1\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao1 = lista_descricao1\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao1 = lista_descricao1\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao1 = lista_descricao1\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao1 = lista_descricao1\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao1 = [b[0] for b in lista_descricao1.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima1= dados1.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima1= lista_temperatura_maxima1\
    .select('*', (lista_temperatura_maxima1['Temp_maxima']- 273).alias('TemperaturaMaxima'))

#3- Diminuindo as casas decimais.
lista_temperatura_maxima1= lista_temperatura_maxima1\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima1= lista_temperatura_maxima1.select("TemperaturaMaxima")

column_temperatura_maxima1= [c[0] for c in lista_temperatura_maxima1.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima1 = dados1.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima1 = lista_temperatura_minima1\
    .select('*', (lista_temperatura_minima1['Temp_minima']- 273).alias('TemperaturaMinima'))

#3- Diminuindo as casas decimais.
lista_temperatura_minima1 = lista_temperatura_minima1\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima1 = lista_temperatura_minima1.select("TemperaturaMinima")

column_temperatura_minima1 = [d[0] for d in lista_temperatura_minima1.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media1 = dados1.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media1 = lista_temperatura_media1\
    .select('*', (lista_temperatura_media1['Temp_media']- 273).alias('TemperaturaMedia'))

#3- Diminuindo as casas decimais.
lista_temperatura_media1 = lista_temperatura_media1\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media1 = lista_temperatura_media1.select("TemperaturaMedia")

column_temperatura_media1 = [e[0] for e in lista_temperatura_media1.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol1 = dados1.select('city.sunrise')
nascer_sol1 = [f[0] for f in lista_nascer_sol1.collect()] * 40

column_nascer_do_sol1 = []

for n in nascer_sol1:
    ns1 = int(n) # Convertendo para int
    ns1 = datetime.fromtimestamp(ns1, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns1 = str(ns1)
    ns1 = ns1[0:19]
    column_nascer_do_sol1.append(ns1)


# POR DO SOL

lista_por_sol1 = dados1.select('city.sunset')
por_sol1 = [g[0] for g in lista_por_sol1.collect()] * 40

column_por_do_sol1 = []

for p in por_sol1:
    ps1 = int(p) # Convertendo para int
    ps1 = datetime.fromtimestamp(ps1, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps1 = str(ps1)
    ps1 = ps1[0:19]
    column_por_do_sol1.append(ps1)
 

# LATITUDE

lista_latitude1 = dados1.select('city.coord.lat')
column_latitude1 = [h[0] for h in lista_latitude1.collect()] * 40 


# LONGITUDE

lista_longitude1 = dados1.select('city.coord.lon')
column_longitude1 = [j[0] for j in lista_longitude1.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento1 = dados1.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento1 = [l[0] for l in lista_velocidade_vento1.collect()]

#---------------------------------------------------------------------------------------------------

"""
CIDADE 2
"""

# DATA

lista_data2 = dados2.select (explode('list.dt_txt').alias('Data'))
column_data2 = [a[0] for a in lista_data2.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao2 = dados2.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao2 = lista_descricao2\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao2 = lista_descricao2\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao2 = lista_descricao2\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao2 = lista_descricao2\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao2 = lista_descricao2\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao2 = lista_descricao2\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao2 = lista_descricao2\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao2 = [b[0] for b in lista_descricao2.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima2= dados2.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima2= lista_temperatura_maxima2\
    .select('*', (lista_temperatura_maxima2['Temp_maxima']- 273).alias('TemperaturaMaxima'))

#3- Diminuindo as casas decimais.
lista_temperatura_maxima2= lista_temperatura_maxima2\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima2= lista_temperatura_maxima2.select("TemperaturaMaxima")

column_temperatura_maxima2= [c[0] for c in lista_temperatura_maxima2.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima2 = dados2.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima2 = lista_temperatura_minima2\
    .select('*', (lista_temperatura_minima2['Temp_minima']- 273).alias('TemperaturaMinima'))

#3- Diminuindo as casas decimais.
lista_temperatura_minima2 = lista_temperatura_minima2\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima2 = lista_temperatura_minima2.select("TemperaturaMinima")

column_temperatura_minima2 = [d[0] for d in lista_temperatura_minima2.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media2 = dados2.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media2 = lista_temperatura_media2\
    .select('*', (lista_temperatura_media2['Temp_media']- 273).alias('TemperaturaMedia'))

#3- Diminuindo as casas decimais.
lista_temperatura_media2 = lista_temperatura_media2\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media2 = lista_temperatura_media2.select("TemperaturaMedia")

column_temperatura_media2 = [e[0] for e in lista_temperatura_media2.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol2 = dados2.select('city.sunrise')
nascer_sol2 = [f[0] for f in lista_nascer_sol2.collect()] * 40

column_nascer_do_sol2 = []

for n in nascer_sol2:
    ns2 = int(n) # Convertendo para int
    ns2 = datetime.fromtimestamp(ns2, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns2 = str(ns2)
    ns2 = ns2[0:19]
    column_nascer_do_sol2.append(ns2)


# POR DO SOL

lista_por_sol2 = dados2.select('city.sunset')
por_sol2 = [g[0] for g in lista_por_sol2.collect()] * 40

column_por_do_sol2 = []

for p in por_sol2:
    ps2 = int(p) # Convertendo para int
    ps2 = datetime.fromtimestamp(ps2, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps2 = str(ps2)
    ps2 = ps2[0:19]
    column_por_do_sol2.append(ps2)


# LATITUDE

lista_latitude2 = dados2.select('city.coord.lat')
column_latitude2 = [h[0] for h in lista_latitude2.collect()] * 40 


# LONGITUDE

lista_longitude2 = dados2.select('city.coord.lon')
column_longitude2 = [j[0] for j in lista_longitude2.collect()] * 40 


# VELOCIDADE DO VENTO

lista_velocidade_vento2 = dados2.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento2 = [l[0] for l in lista_velocidade_vento2.collect()]

#--------------------------------------------------------------------------------------------------


"""
CIDADE 3
"""

# DATA

lista_data3 = dados3.select (explode('list.dt_txt').alias('Data'))
column_data3 = [a[0] for a in lista_data3.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao3 = dados3.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao3 = lista_descricao3\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao3 = lista_descricao3\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao3 = lista_descricao3\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao3 = lista_descricao3\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao3 = lista_descricao3\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao3 = lista_descricao3\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao3 = lista_descricao3\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao3 = [b[0] for b in lista_descricao3.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima3= dados3.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima3= lista_temperatura_maxima3\
    .select('*', (lista_temperatura_maxima3['Temp_maxima']- 273).alias('TemperaturaMaxima'))

#3- Diminuindo as casas decimais.
lista_temperatura_maxima3= lista_temperatura_maxima3\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima3= lista_temperatura_maxima3.select("TemperaturaMaxima")

column_temperatura_maxima3= [c[0] for c in lista_temperatura_maxima3.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima3 = dados3.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima3 = lista_temperatura_minima3\
    .select('*', (lista_temperatura_minima3['Temp_minima']- 273).alias('TemperaturaMinima'))

#3- Diminuindo as casas decimais.
lista_temperatura_minima3 = lista_temperatura_minima3\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima3 = lista_temperatura_minima3.select("TemperaturaMinima")

column_temperatura_minima3 = [d[0] for d in lista_temperatura_minima3.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media3 = dados3.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media3 = lista_temperatura_media3\
    .select('*', (lista_temperatura_media3['Temp_media']- 273).alias('TemperaturaMedia'))

#3- Diminuindo as casas decimais.
lista_temperatura_media3 = lista_temperatura_media3\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media3 = lista_temperatura_media3.select("TemperaturaMedia")

column_temperatura_media3 = [e[0] for e in lista_temperatura_media3.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol3 = dados3.select('city.sunrise')
nascer_sol3 = [f[0] for f in lista_nascer_sol3.collect()] * 40

column_nascer_do_sol3 = []

for n in nascer_sol3:
    ns3 = int(n) # Convertendo para int
    ns3 = datetime.fromtimestamp(ns3, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns3 = str(ns3)
    ns3 = ns3[0:19]
    column_nascer_do_sol3.append(ns3)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol3 = dados3.select('city.sunset')
por_sol3 = [g[0] for g in lista_por_sol3.collect()] * 40

column_por_do_sol3 = []

for p in por_sol3:
    ps3 = int(p) # Convertendo para int
    ps3 = datetime.fromtimestamp(ps3, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps3 = str(ps3)
    ps3 = ps3[0:19]
    column_por_do_sol3.append(ps3)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude3 = dados3.select('city.coord.lat')
column_latitude3 = [h[0] for h in lista_latitude3.collect()] * 40


# LONGITUDE

lista_longitude3 = dados3.select('city.coord.lon')
column_longitude3 = [j[0] for j in lista_longitude3.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento3 = dados3.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento3 = [l[0] for l in lista_velocidade_vento3.collect()]

#------------------------------------------------------------------------------------------------

"""
CIDADE 4
"""

# DATA

lista_data4 = dados4.select (explode('list.dt_txt').alias('Data'))
column_data4 = [a[0] for a in lista_data4.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao4 = dados4.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao4 = lista_descricao4\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao4 = lista_descricao4\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao4 = lista_descricao4\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao4 = lista_descricao4\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao4 = lista_descricao4\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao4 = lista_descricao4\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao4 = lista_descricao4\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao4 = [b[0] for b in lista_descricao4.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima4= dados4.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima4= lista_temperatura_maxima4\
    .select('*', (lista_temperatura_maxima4['Temp_maxima']- 274).alias('TemperaturaMaxima'))

#4- Diminuindo as casas decimais.
lista_temperatura_maxima4= lista_temperatura_maxima4\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima4= lista_temperatura_maxima4.select("TemperaturaMaxima")

column_temperatura_maxima4= [c[0] for c in lista_temperatura_maxima4.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima4 = dados4.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima4 = lista_temperatura_minima4\
    .select('*', (lista_temperatura_minima4['Temp_minima']- 274).alias('TemperaturaMinima'))

#4- Diminuindo as casas decimais.
lista_temperatura_minima4 = lista_temperatura_minima4\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima4 = lista_temperatura_minima4.select("TemperaturaMinima")

column_temperatura_minima4 = [d[0] for d in lista_temperatura_minima4.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media4 = dados4.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media4 = lista_temperatura_media4\
    .select('*', (lista_temperatura_media4['Temp_media']- 274).alias('TemperaturaMedia'))

#4- Diminuindo as casas decimais.
lista_temperatura_media4 = lista_temperatura_media4\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media4 = lista_temperatura_media4.select("TemperaturaMedia")

column_temperatura_media4 = [e[0] for e in lista_temperatura_media4.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol4 = dados4.select('city.sunrise')
nascer_sol4 = [f[0] for f in lista_nascer_sol4.collect()] * 40

column_nascer_do_sol4 = []

for n in nascer_sol4:
    ns4 = int(n) # Convertendo para int
    ns4 = datetime.fromtimestamp(ns4, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns4 = str(ns4)
    ns4 = ns4[0:19]
    column_nascer_do_sol4.append(ns4)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol4 = dados4.select('city.sunset')
por_sol4 = [g[0] for g in lista_por_sol4.collect()] * 40

column_por_do_sol4 = []

for p in por_sol4:
    ps4 = int(p) # Convertendo para int
    ps4 = datetime.fromtimestamp(ps4, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps4 = str(ps4)
    ps4 = ps4[0:19]
    column_por_do_sol4.append(ps4)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude4 = dados4.select('city.coord.lat')
column_latitude4 = [h[0] for h in lista_latitude4.collect()] * 40


# LONGITUDE

lista_longitude4 = dados4.select('city.coord.lon')
column_longitude4 = [j[0] for j in lista_longitude4.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento4 = dados4.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento4 = [l[0] for l in lista_velocidade_vento4.collect()]

#----------------------------------------------------------------------------------------------------


"""
CIDADE 5
"""

# DATA

lista_data5 = dados5.select (explode('list.dt_txt').alias('Data'))
column_data5 = [a[0] for a in lista_data5.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao5 = dados5.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao5 = lista_descricao5\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao5 = lista_descricao5\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao5 = lista_descricao5\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao5 = lista_descricao5\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao5 = lista_descricao5\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao5 = lista_descricao5\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao5 = lista_descricao5\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao5 = [b[0] for b in lista_descricao5.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima5= dados5.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima5= lista_temperatura_maxima5\
    .select('*', (lista_temperatura_maxima5['Temp_maxima']- 275).alias('TemperaturaMaxima'))

#5- Diminuindo as casas decimais.
lista_temperatura_maxima5= lista_temperatura_maxima5\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima5= lista_temperatura_maxima5.select("TemperaturaMaxima")

column_temperatura_maxima5= [c[0] for c in lista_temperatura_maxima5.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima5 = dados5.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima5 = lista_temperatura_minima5\
    .select('*', (lista_temperatura_minima5['Temp_minima']- 275).alias('TemperaturaMinima'))

#5- Diminuindo as casas decimais.
lista_temperatura_minima5 = lista_temperatura_minima5\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima5 = lista_temperatura_minima5.select("TemperaturaMinima")

column_temperatura_minima5 = [d[0] for d in lista_temperatura_minima5.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media5 = dados5.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media5 = lista_temperatura_media5\
    .select('*', (lista_temperatura_media5['Temp_media']- 275).alias('TemperaturaMedia'))

#5- Diminuindo as casas decimais.
lista_temperatura_media5 = lista_temperatura_media5\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media5 = lista_temperatura_media5.select("TemperaturaMedia")

column_temperatura_media5 = [e[0] for e in lista_temperatura_media5.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol5 = dados5.select('city.sunrise')
nascer_sol5 = [f[0] for f in lista_nascer_sol5.collect()] * 40

column_nascer_do_sol5 = []

for n in nascer_sol5:
    ns5 = int(n) # Convertendo para int
    ns5 = datetime.fromtimestamp(ns5, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns5 = str(ns5)
    ns5 = ns5[0:19]
    column_nascer_do_sol5.append(ns5)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol5 = dados5.select('city.sunset')
por_sol5 = [g[0] for g in lista_por_sol5.collect()] * 40

column_por_do_sol5 = []

for p in por_sol5:
    ps5 = int(p) # Convertendo para int
    ps5 = datetime.fromtimestamp(ps5, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps5 = str(ps5)
    ps5 = ps5[0:19]
    column_por_do_sol5.append(ps5)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude5 = dados5.select('city.coord.lat')
column_latitude5 = [h[0] for h in lista_latitude5.collect()] * 40


# LONGITUDE

lista_longitude5 = dados5.select('city.coord.lon')
column_longitude5 = [j[0] for j in lista_longitude5.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento5 = dados5.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento5 = [l[0] for l in lista_velocidade_vento5.collect()]

#----------------------------------------------------------------------------------------------------


"""
CIDADE 6
"""

# DATA

lista_data6 = dados6.select (explode('list.dt_txt').alias('Data'))
column_data6 = [a[0] for a in lista_data6.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao6 = dados6.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao6 = lista_descricao6\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao6 = lista_descricao6\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao6 = lista_descricao6\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao6 = lista_descricao6\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao6 = lista_descricao6\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao6 = lista_descricao6\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao6 = lista_descricao6\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao6 = [b[0] for b in lista_descricao6.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima6= dados6.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima6= lista_temperatura_maxima6\
    .select('*', (lista_temperatura_maxima6['Temp_maxima']- 276).alias('TemperaturaMaxima'))

#6- Diminuindo as casas decimais.
lista_temperatura_maxima6= lista_temperatura_maxima6\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima6= lista_temperatura_maxima6.select("TemperaturaMaxima")

column_temperatura_maxima6= [c[0] for c in lista_temperatura_maxima6.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima6 = dados6.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima6 = lista_temperatura_minima6\
    .select('*', (lista_temperatura_minima6['Temp_minima']- 276).alias('TemperaturaMinima'))

#6- Diminuindo as casas decimais.
lista_temperatura_minima6 = lista_temperatura_minima6\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima6 = lista_temperatura_minima6.select("TemperaturaMinima")

column_temperatura_minima6 = [d[0] for d in lista_temperatura_minima6.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media6 = dados6.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media6 = lista_temperatura_media6\
    .select('*', (lista_temperatura_media6['Temp_media']- 276).alias('TemperaturaMedia'))

#6- Diminuindo as casas decimais.
lista_temperatura_media6 = lista_temperatura_media6\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media6 = lista_temperatura_media6.select("TemperaturaMedia")

column_temperatura_media6 = [e[0] for e in lista_temperatura_media6.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol6 = dados6.select('city.sunrise')
nascer_sol6 = [f[0] for f in lista_nascer_sol6.collect()] * 40

column_nascer_do_sol6 = []

for n in nascer_sol6:
    ns6 = int(n) # Convertendo para int
    ns6 = datetime.fromtimestamp(ns6, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns6 = str(ns6)
    ns6 = ns6[0:19]
    column_nascer_do_sol6.append(ns6)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol6 = dados6.select('city.sunset')
por_sol6 = [g[0] for g in lista_por_sol6.collect()] * 40

column_por_do_sol6 = []

for p in por_sol6:
    ps6 = int(p) # Convertendo para int
    ps6 = datetime.fromtimestamp(ps6, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps6 = str(ps6)
    ps6 = ps6[0:19]
    column_por_do_sol6.append(ps6)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude6 = dados6.select('city.coord.lat')
column_latitude6 = [h[0] for h in lista_latitude6.collect()] * 40


# LONGITUDE

lista_longitude6 = dados6.select('city.coord.lon')
column_longitude6 = [j[0] for j in lista_longitude6.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento6 = dados6.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento6 = [l[0] for l in lista_velocidade_vento6.collect()]
#----------------------------------------------------------------------------------------------------


"""
CIDADE 7
"""

# DATA

lista_data7 = dados7.select (explode('list.dt_txt').alias('Data'))
column_data7 = [a[0] for a in lista_data7.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao7 = dados7.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao7 = lista_descricao7\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao7 = lista_descricao7\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao7 = lista_descricao7\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao7 = lista_descricao7\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao7 = lista_descricao7\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao7 = lista_descricao7\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao7 = lista_descricao7\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao7 = [b[0] for b in lista_descricao7.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima7= dados7.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima7= lista_temperatura_maxima7\
    .select('*', (lista_temperatura_maxima7['Temp_maxima']- 277).alias('TemperaturaMaxima'))

#7- Diminuindo as casas decimais.
lista_temperatura_maxima7= lista_temperatura_maxima7\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima7= lista_temperatura_maxima7.select("TemperaturaMaxima")

column_temperatura_maxima7= [c[0] for c in lista_temperatura_maxima7.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima7 = dados7.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima7 = lista_temperatura_minima7\
    .select('*', (lista_temperatura_minima7['Temp_minima']- 277).alias('TemperaturaMinima'))

#7- Diminuindo as casas decimais.
lista_temperatura_minima7 = lista_temperatura_minima7\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima7 = lista_temperatura_minima7.select("TemperaturaMinima")

column_temperatura_minima7 = [d[0] for d in lista_temperatura_minima7.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media7 = dados7.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media7 = lista_temperatura_media7\
    .select('*', (lista_temperatura_media7['Temp_media']- 277).alias('TemperaturaMedia'))

#7- Diminuindo as casas decimais.
lista_temperatura_media7 = lista_temperatura_media7\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media7 = lista_temperatura_media7.select("TemperaturaMedia")

column_temperatura_media7 = [e[0] for e in lista_temperatura_media7.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol7 = dados7.select('city.sunrise')
nascer_sol7 = [f[0] for f in lista_nascer_sol7.collect()] * 40

column_nascer_do_sol7 = []

for n in nascer_sol7:
    ns7 = int(n) # Convertendo para int
    ns7 = datetime.fromtimestamp(ns7, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns7 = str(ns7)
    ns7 = ns7[0:19]
    column_nascer_do_sol7.append(ns7)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol7 = dados7.select('city.sunset')
por_sol7 = [g[0] for g in lista_por_sol7.collect()] * 40

column_por_do_sol7 = []

for p in por_sol7:
    ps7 = int(p) # Convertendo para int
    ps7 = datetime.fromtimestamp(ps7, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps7 = str(ps7)
    ps7 = ps7[0:19]
    column_por_do_sol7.append(ps7)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude7 = dados7.select('city.coord.lat')
column_latitude7 = [h[0] for h in lista_latitude7.collect()] * 40


# LONGITUDE

lista_longitude7 = dados7.select('city.coord.lon')
column_longitude7 = [j[0] for j in lista_longitude7.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento7 = dados7.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento7 = [l[0] for l in lista_velocidade_vento7.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 8
"""

# DATA

lista_data8 = dados8.select (explode('list.dt_txt').alias('Data'))
column_data8 = [a[0] for a in lista_data8.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao8 = dados8.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao8 = lista_descricao8\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao8 = lista_descricao8\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao8 = lista_descricao8\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao8 = lista_descricao8\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao8 = lista_descricao8\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao8 = lista_descricao8\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao8 = lista_descricao8\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao8 = [b[0] for b in lista_descricao8.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima8= dados8.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima8= lista_temperatura_maxima8\
    .select('*', (lista_temperatura_maxima8['Temp_maxima']- 28).alias('TemperaturaMaxima'))

#8- Diminuindo as casas decimais.
lista_temperatura_maxima8= lista_temperatura_maxima8\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima8= lista_temperatura_maxima8.select("TemperaturaMaxima")

column_temperatura_maxima8= [c[0] for c in lista_temperatura_maxima8.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima8 = dados8.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima8 = lista_temperatura_minima8\
    .select('*', (lista_temperatura_minima8['Temp_minima']- 28).alias('TemperaturaMinima'))

#8- Diminuindo as casas decimais.
lista_temperatura_minima8 = lista_temperatura_minima8\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima8 = lista_temperatura_minima8.select("TemperaturaMinima")

column_temperatura_minima8 = [d[0] for d in lista_temperatura_minima8.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media8 = dados8.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media8 = lista_temperatura_media8\
    .select('*', (lista_temperatura_media8['Temp_media']- 28).alias('TemperaturaMedia'))

#8- Diminuindo as casas decimais.
lista_temperatura_media8 = lista_temperatura_media8\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media8 = lista_temperatura_media8.select("TemperaturaMedia")

column_temperatura_media8 = [e[0] for e in lista_temperatura_media8.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol8 = dados8.select('city.sunrise')
nascer_sol8 = [f[0] for f in lista_nascer_sol8.collect()] * 40

column_nascer_do_sol8 = []

for n in nascer_sol8:
    ns8 = int(n) # Convertendo para int
    ns8 = datetime.fromtimestamp(ns8, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns8 = str(ns8)
    ns8 = ns8[0:19]
    column_nascer_do_sol8.append(ns8)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol8 = dados8.select('city.sunset')
por_sol8 = [g[0] for g in lista_por_sol8.collect()] * 40

column_por_do_sol8 = []

for p in por_sol8:
    ps8 = int(p) # Convertendo para int
    ps8 = datetime.fromtimestamp(ps8, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps8 = str(ps8)
    ps8 = ps8[0:19]
    column_por_do_sol8.append(ps8)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude8 = dados8.select('city.coord.lat')
column_latitude8 = [h[0] for h in lista_latitude8.collect()] * 40


# LONGITUDE

lista_longitude8 = dados8.select('city.coord.lon')
column_longitude8 = [j[0] for j in lista_longitude8.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento8 = dados8.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento8 = [l[0] for l in lista_velocidade_vento8.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 9
"""

# DATA

lista_data9 = dados9.select (explode('list.dt_txt').alias('Data'))
column_data9 = [a[0] for a in lista_data9.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao9 = dados9.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao9 = lista_descricao9\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao9 = lista_descricao9\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao9 = lista_descricao9\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao9 = lista_descricao9\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao9 = lista_descricao9\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao9 = lista_descricao9\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao9 = lista_descricao9\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao9 = [b[0] for b in lista_descricao9.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima9= dados9.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima9= lista_temperatura_maxima9\
    .select('*', (lista_temperatura_maxima9['Temp_maxima']- 29).alias('TemperaturaMaxima'))

#9- Diminuindo as casas decimais.
lista_temperatura_maxima9= lista_temperatura_maxima9\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima9= lista_temperatura_maxima9.select("TemperaturaMaxima")

column_temperatura_maxima9= [c[0] for c in lista_temperatura_maxima9.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima9 = dados9.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima9 = lista_temperatura_minima9\
    .select('*', (lista_temperatura_minima9['Temp_minima']- 29).alias('TemperaturaMinima'))

#9- Diminuindo as casas decimais.
lista_temperatura_minima9 = lista_temperatura_minima9\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima9 = lista_temperatura_minima9.select("TemperaturaMinima")

column_temperatura_minima9 = [d[0] for d in lista_temperatura_minima9.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media9 = dados9.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media9 = lista_temperatura_media9\
    .select('*', (lista_temperatura_media9['Temp_media']- 29).alias('TemperaturaMedia'))

#9- Diminuindo as casas decimais.
lista_temperatura_media9 = lista_temperatura_media9\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media9 = lista_temperatura_media9.select("TemperaturaMedia")

column_temperatura_media9 = [e[0] for e in lista_temperatura_media9.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol9 = dados9.select('city.sunrise')
nascer_sol9 = [f[0] for f in lista_nascer_sol9.collect()] * 40

column_nascer_do_sol9 = []

for n in nascer_sol9:
    ns9 = int(n) # Convertendo para int
    ns9 = datetime.fromtimestamp(ns9, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns9 = str(ns9)
    ns9 = ns9[0:19]
    column_nascer_do_sol9.append(ns9)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol9 = dados9.select('city.sunset')
por_sol9 = [g[0] for g in lista_por_sol9.collect()] * 40

column_por_do_sol9 = []

for p in por_sol9:
    ps9 = int(p) # Convertendo para int
    ps9 = datetime.fromtimestamp(ps9, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps9 = str(ps9)
    ps9 = ps9[0:19]
    column_por_do_sol9.append(ps9)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude9 = dados9.select('city.coord.lat')
column_latitude9 = [h[0] for h in lista_latitude9.collect()] * 40


# LONGITUDE

lista_longitude9 = dados9.select('city.coord.lon')
column_longitude9 = [j[0] for j in lista_longitude9.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento9 = dados9.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento9 = [l[0] for l in lista_velocidade_vento9.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 10
"""

# DATA

lista_data10 = dados10.select (explode('list.dt_txt').alias('Data'))
column_data10 = [a[0] for a in lista_data10.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao10 = dados10.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao10 = lista_descricao10\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao10 = lista_descricao10\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao10 = lista_descricao10\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao10 = lista_descricao10\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao10 = lista_descricao10\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao10 = lista_descricao10\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao10 = lista_descricao10\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao10 = [b[0] for b in lista_descricao10.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima10= dados10.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima10= lista_temperatura_maxima10\
    .select('*', (lista_temperatura_maxima10['Temp_maxima']- 210).alias('TemperaturaMaxima'))

#10- Diminuindo as casas decimais.
lista_temperatura_maxima10= lista_temperatura_maxima10\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima10= lista_temperatura_maxima10.select("TemperaturaMaxima")

column_temperatura_maxima10= [c[0] for c in lista_temperatura_maxima10.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima10 = dados10.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima10 = lista_temperatura_minima10\
    .select('*', (lista_temperatura_minima10['Temp_minima']- 210).alias('TemperaturaMinima'))

#10- Diminuindo as casas decimais.
lista_temperatura_minima10 = lista_temperatura_minima10\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima10 = lista_temperatura_minima10.select("TemperaturaMinima")

column_temperatura_minima10 = [d[0] for d in lista_temperatura_minima10.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media10 = dados10.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media10 = lista_temperatura_media10\
    .select('*', (lista_temperatura_media10['Temp_media']- 210).alias('TemperaturaMedia'))

#10- Diminuindo as casas decimais.
lista_temperatura_media10 = lista_temperatura_media10\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media10 = lista_temperatura_media10.select("TemperaturaMedia")

column_temperatura_media10 = [e[0] for e in lista_temperatura_media10.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol10 = dados10.select('city.sunrise')
nascer_sol10 = [f[0] for f in lista_nascer_sol10.collect()] * 40

column_nascer_do_sol10 = []

for n in nascer_sol10:
    ns10 = int(n) # Convertendo para int
    ns10 = datetime.fromtimestamp(ns10, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns10 = str(ns10)
    ns10 = ns10[0:19]
    column_nascer_do_sol10.append(ns10)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol10 = dados10.select('city.sunset')
por_sol10 = [g[0] for g in lista_por_sol10.collect()] * 40

column_por_do_sol10 = []

for p in por_sol10:
    ps10 = int(p) # Convertendo para int
    ps10 = datetime.fromtimestamp(ps10, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps10 = str(ps10)
    ps10 = ps10[0:19]
    column_por_do_sol10.append(ps10)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude10 = dados10.select('city.coord.lat')
column_latitude10 = [h[0] for h in lista_latitude10.collect()] * 40


# LONGITUDE

lista_longitude10 = dados10.select('city.coord.lon')
column_longitude10 = [j[0] for j in lista_longitude10.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento10 = dados10.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento10 = [l[0] for l in lista_velocidade_vento10.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 11
"""

# DATA

lista_data11 = dados11.select (explode('list.dt_txt').alias('Data'))
column_data11 = [a[0] for a in lista_data11.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao11 = dados11.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao11 = lista_descricao11\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao11 = lista_descricao11\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao11 = lista_descricao11\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao11 = lista_descricao11\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao11 = lista_descricao11\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao11 = lista_descricao11\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao11 = lista_descricao11\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao11 = [b[0] for b in lista_descricao11.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima11= dados11.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima11= lista_temperatura_maxima11\
    .select('*', (lista_temperatura_maxima11['Temp_maxima']- 211).alias('TemperaturaMaxima'))

#11- Diminuindo as casas decimais.
lista_temperatura_maxima11= lista_temperatura_maxima11\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima11= lista_temperatura_maxima11.select("TemperaturaMaxima")

column_temperatura_maxima11= [c[0] for c in lista_temperatura_maxima11.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima11 = dados11.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima11 = lista_temperatura_minima11\
    .select('*', (lista_temperatura_minima11['Temp_minima']- 211).alias('TemperaturaMinima'))

#11- Diminuindo as casas decimais.
lista_temperatura_minima11 = lista_temperatura_minima11\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima11 = lista_temperatura_minima11.select("TemperaturaMinima")

column_temperatura_minima11 = [d[0] for d in lista_temperatura_minima11.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media11 = dados11.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media11 = lista_temperatura_media11\
    .select('*', (lista_temperatura_media11['Temp_media']- 211).alias('TemperaturaMedia'))

#11- Diminuindo as casas decimais.
lista_temperatura_media11 = lista_temperatura_media11\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media11 = lista_temperatura_media11.select("TemperaturaMedia")

column_temperatura_media11 = [e[0] for e in lista_temperatura_media11.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol11 = dados11.select('city.sunrise')
nascer_sol11 = [f[0] for f in lista_nascer_sol11.collect()] * 40

column_nascer_do_sol11 = []

for n in nascer_sol11:
    ns11 = int(n) # Convertendo para int
    ns11 = datetime.fromtimestamp(ns11, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns11 = str(ns11)
    ns11 = ns11[0:19]
    column_nascer_do_sol11.append(ns11)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol11 = dados11.select('city.sunset')
por_sol11 = [g[0] for g in lista_por_sol11.collect()] * 40

column_por_do_sol11 = []

for p in por_sol11:
    ps11 = int(p) # Convertendo para int
    ps11 = datetime.fromtimestamp(ps11, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps11 = str(ps11)
    ps11 = ps11[0:19]
    column_por_do_sol11.append(ps11)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude11 = dados11.select('city.coord.lat')
column_latitude11 = [h[0] for h in lista_latitude11.collect()] * 40


# LONGITUDE

lista_longitude11 = dados11.select('city.coord.lon')
column_longitude11 = [j[0] for j in lista_longitude11.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento11 = dados11.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento11 = [l[0] for l in lista_velocidade_vento11.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 12
"""

# DATA

lista_data12 = dados12.select (explode('list.dt_txt').alias('Data'))
column_data12 = [a[0] for a in lista_data12.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao12 = dados12.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao12 = lista_descricao12\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao12 = lista_descricao12\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao12 = lista_descricao12\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao12 = lista_descricao12\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao12 = lista_descricao12\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao12 = lista_descricao12\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao12 = lista_descricao12\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao12 = [b[0] for b in lista_descricao12.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima12= dados12.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima12= lista_temperatura_maxima12\
    .select('*', (lista_temperatura_maxima12['Temp_maxima']- 212).alias('TemperaturaMaxima'))

#12- Diminuindo as casas decimais.
lista_temperatura_maxima12= lista_temperatura_maxima12\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima12= lista_temperatura_maxima12.select("TemperaturaMaxima")

column_temperatura_maxima12= [c[0] for c in lista_temperatura_maxima12.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima12 = dados12.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima12 = lista_temperatura_minima12\
    .select('*', (lista_temperatura_minima12['Temp_minima']- 212).alias('TemperaturaMinima'))

#12- Diminuindo as casas decimais.
lista_temperatura_minima12 = lista_temperatura_minima12\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima12 = lista_temperatura_minima12.select("TemperaturaMinima")

column_temperatura_minima12 = [d[0] for d in lista_temperatura_minima12.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media12 = dados12.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media12 = lista_temperatura_media12\
    .select('*', (lista_temperatura_media12['Temp_media']- 212).alias('TemperaturaMedia'))

#12- Diminuindo as casas decimais.
lista_temperatura_media12 = lista_temperatura_media12\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media12 = lista_temperatura_media12.select("TemperaturaMedia")

column_temperatura_media12 = [e[0] for e in lista_temperatura_media12.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol12 = dados12.select('city.sunrise')
nascer_sol12 = [f[0] for f in lista_nascer_sol12.collect()] * 40

column_nascer_do_sol12 = []

for n in nascer_sol12:
    ns12 = int(n) # Convertendo para int
    ns12 = datetime.fromtimestamp(ns12, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns12 = str(ns12)
    ns12 = ns12[0:19]
    column_nascer_do_sol12.append(ns12)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol12 = dados12.select('city.sunset')
por_sol12 = [g[0] for g in lista_por_sol12.collect()] * 40

column_por_do_sol12 = []

for p in por_sol12:
    ps12 = int(p) # Convertendo para int
    ps12 = datetime.fromtimestamp(ps12, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps12 = str(ps12)
    ps12 = ps12[0:19]
    column_por_do_sol12.append(ps12)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude12 = dados12.select('city.coord.lat')
column_latitude12 = [h[0] for h in lista_latitude12.collect()] * 40


# LONGITUDE

lista_longitude12 = dados12.select('city.coord.lon')
column_longitude12 = [j[0] for j in lista_longitude12.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento12 = dados12.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento12 = [l[0] for l in lista_velocidade_vento12.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 13
"""

# DATA

lista_data13 = dados13.select (explode('list.dt_txt').alias('Data'))
column_data13 = [a[0] for a in lista_data13.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao13 = dados13.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao13 = lista_descricao13\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao13 = lista_descricao13\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao13 = lista_descricao13\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao13 = lista_descricao13\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao13 = lista_descricao13\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao13 = lista_descricao13\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao13 = lista_descricao13\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao13 = [b[0] for b in lista_descricao13.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima13= dados13.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima13= lista_temperatura_maxima13\
    .select('*', (lista_temperatura_maxima13['Temp_maxima']- 213).alias('TemperaturaMaxima'))

#13- Diminuindo as casas decimais.
lista_temperatura_maxima13= lista_temperatura_maxima13\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima13= lista_temperatura_maxima13.select("TemperaturaMaxima")

column_temperatura_maxima13= [c[0] for c in lista_temperatura_maxima13.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima13 = dados13.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima13 = lista_temperatura_minima13\
    .select('*', (lista_temperatura_minima13['Temp_minima']- 213).alias('TemperaturaMinima'))

#13- Diminuindo as casas decimais.
lista_temperatura_minima13 = lista_temperatura_minima13\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima13 = lista_temperatura_minima13.select("TemperaturaMinima")

column_temperatura_minima13 = [d[0] for d in lista_temperatura_minima13.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media13 = dados13.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media13 = lista_temperatura_media13\
    .select('*', (lista_temperatura_media13['Temp_media']- 213).alias('TemperaturaMedia'))

#13- Diminuindo as casas decimais.
lista_temperatura_media13 = lista_temperatura_media13\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media13 = lista_temperatura_media13.select("TemperaturaMedia")

column_temperatura_media13 = [e[0] for e in lista_temperatura_media13.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol13 = dados13.select('city.sunrise')
nascer_sol13 = [f[0] for f in lista_nascer_sol13.collect()] * 40

column_nascer_do_sol13 = []

for n in nascer_sol13:
    ns13 = int(n) # Convertendo para int
    ns13 = datetime.fromtimestamp(ns13, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns13 = str(ns13)
    ns13 = ns13[0:19]
    column_nascer_do_sol13.append(ns13)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol13 = dados13.select('city.sunset')
por_sol13 = [g[0] for g in lista_por_sol13.collect()] * 40

column_por_do_sol13 = []

for p in por_sol13:
    ps13 = int(p) # Convertendo para int
    ps13 = datetime.fromtimestamp(ps13, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps13 = str(ps13)
    ps13 = ps13[0:19]
    column_por_do_sol13.append(ps13)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude13 = dados13.select('city.coord.lat')
column_latitude13 = [h[0] for h in lista_latitude13.collect()] * 40


# LONGITUDE

lista_longitude13 = dados13.select('city.coord.lon')
column_longitude13 = [j[0] for j in lista_longitude13.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento13 = dados13.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento13 = [l[0] for l in lista_velocidade_vento13.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 14
"""

# DATA

lista_data14 = dados14.select (explode('list.dt_txt').alias('Data'))
column_data14 = [a[0] for a in lista_data14.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao14 = dados14.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao14 = lista_descricao14\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao14 = lista_descricao14\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao14 = lista_descricao14\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao14 = lista_descricao14\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao14 = lista_descricao14\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao14 = lista_descricao14\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao14 = lista_descricao14\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao14 = [b[0] for b in lista_descricao14.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima14= dados14.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima14= lista_temperatura_maxima14\
    .select('*', (lista_temperatura_maxima14['Temp_maxima']- 214).alias('TemperaturaMaxima'))

#14- Diminuindo as casas decimais.
lista_temperatura_maxima14= lista_temperatura_maxima14\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima14= lista_temperatura_maxima14.select("TemperaturaMaxima")

column_temperatura_maxima14= [c[0] for c in lista_temperatura_maxima14.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima14 = dados14.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima14 = lista_temperatura_minima14\
    .select('*', (lista_temperatura_minima14['Temp_minima']- 214).alias('TemperaturaMinima'))

#14- Diminuindo as casas decimais.
lista_temperatura_minima14 = lista_temperatura_minima14\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima14 = lista_temperatura_minima14.select("TemperaturaMinima")

column_temperatura_minima14 = [d[0] for d in lista_temperatura_minima14.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media14 = dados14.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media14 = lista_temperatura_media14\
    .select('*', (lista_temperatura_media14['Temp_media']- 214).alias('TemperaturaMedia'))

#14- Diminuindo as casas decimais.
lista_temperatura_media14 = lista_temperatura_media14\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media14 = lista_temperatura_media14.select("TemperaturaMedia")

column_temperatura_media14 = [e[0] for e in lista_temperatura_media14.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol14 = dados14.select('city.sunrise')
nascer_sol14 = [f[0] for f in lista_nascer_sol14.collect()] * 40

column_nascer_do_sol14 = []

for n in nascer_sol14:
    ns14 = int(n) # Convertendo para int
    ns14 = datetime.fromtimestamp(ns14, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns14 = str(ns14)
    ns14 = ns14[0:19]
    column_nascer_do_sol14.append(ns14)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol14 = dados14.select('city.sunset')
por_sol14 = [g[0] for g in lista_por_sol14.collect()] * 40

column_por_do_sol14 = []

for p in por_sol14:
    ps14 = int(p) # Convertendo para int
    ps14 = datetime.fromtimestamp(ps14, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps14 = str(ps14)
    ps14 = ps14[0:19]
    column_por_do_sol14.append(ps14)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude14 = dados14.select('city.coord.lat')
column_latitude14 = [h[0] for h in lista_latitude14.collect()] * 40


# LONGITUDE

lista_longitude14 = dados14.select('city.coord.lon')
column_longitude14 = [j[0] for j in lista_longitude14.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento14 = dados14.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento14 = [l[0] for l in lista_velocidade_vento14.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 15
"""

# DATA

lista_data15 = dados15.select (explode('list.dt_txt').alias('Data'))
column_data15 = [a[0] for a in lista_data15.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao15 = dados15.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao15 = lista_descricao15\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao15 = lista_descricao15\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao15 = lista_descricao15\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao15 = lista_descricao15\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao15 = lista_descricao15\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao15 = lista_descricao15\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao15 = lista_descricao15\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao15 = [b[0] for b in lista_descricao15.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima15= dados15.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima15= lista_temperatura_maxima15\
    .select('*', (lista_temperatura_maxima15['Temp_maxima']- 215).alias('TemperaturaMaxima'))

#15- Diminuindo as casas decimais.
lista_temperatura_maxima15= lista_temperatura_maxima15\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima15= lista_temperatura_maxima15.select("TemperaturaMaxima")

column_temperatura_maxima15= [c[0] for c in lista_temperatura_maxima15.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima15 = dados15.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima15 = lista_temperatura_minima15\
    .select('*', (lista_temperatura_minima15['Temp_minima']- 215).alias('TemperaturaMinima'))

#15- Diminuindo as casas decimais.
lista_temperatura_minima15 = lista_temperatura_minima15\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima15 = lista_temperatura_minima15.select("TemperaturaMinima")

column_temperatura_minima15 = [d[0] for d in lista_temperatura_minima15.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media15 = dados15.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media15 = lista_temperatura_media15\
    .select('*', (lista_temperatura_media15['Temp_media']- 215).alias('TemperaturaMedia'))

#15- Diminuindo as casas decimais.
lista_temperatura_media15 = lista_temperatura_media15\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media15 = lista_temperatura_media15.select("TemperaturaMedia")

column_temperatura_media15 = [e[0] for e in lista_temperatura_media15.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol15 = dados15.select('city.sunrise')
nascer_sol15 = [f[0] for f in lista_nascer_sol15.collect()] * 40

column_nascer_do_sol15 = []

for n in nascer_sol15:
    ns15 = int(n) # Convertendo para int
    ns15 = datetime.fromtimestamp(ns15, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns15 = str(ns15)
    ns15 = ns15[0:19]
    column_nascer_do_sol15.append(ns15)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol15 = dados15.select('city.sunset')
por_sol15 = [g[0] for g in lista_por_sol15.collect()] * 40

column_por_do_sol15 = []

for p in por_sol15:
    ps15 = int(p) # Convertendo para int
    ps15 = datetime.fromtimestamp(ps15, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps15 = str(ps15)
    ps15 = ps15[0:19]
    column_por_do_sol15.append(ps15)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude15 = dados15.select('city.coord.lat')
column_latitude15 = [h[0] for h in lista_latitude15.collect()] * 40


# LONGITUDE

lista_longitude15 = dados15.select('city.coord.lon')
column_longitude15 = [j[0] for j in lista_longitude15.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento15 = dados15.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento15 = [l[0] for l in lista_velocidade_vento15.collect()]


#--------------------------------------------------------------------------------------------------------

"""
CIDADE 16
"""

# DATA

lista_data16 = dados16.select (explode('list.dt_txt').alias('Data'))
column_data16 = [a[0] for a in lista_data16.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao16 = dados16.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao16 = lista_descricao16\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao16 = lista_descricao16\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao16 = lista_descricao16\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao16 = lista_descricao16\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao16 = lista_descricao16\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao16 = lista_descricao16\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao16 = lista_descricao16\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao16 = [b[0] for b in lista_descricao16.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima16= dados16.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima16= lista_temperatura_maxima16\
    .select('*', (lista_temperatura_maxima16['Temp_maxima']- 216).alias('TemperaturaMaxima'))

#16- Diminuindo as casas decimais.
lista_temperatura_maxima16= lista_temperatura_maxima16\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima16= lista_temperatura_maxima16.select("TemperaturaMaxima")

column_temperatura_maxima16= [c[0] for c in lista_temperatura_maxima16.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima16 = dados16.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima16 = lista_temperatura_minima16\
    .select('*', (lista_temperatura_minima16['Temp_minima']- 216).alias('TemperaturaMinima'))

#16- Diminuindo as casas decimais.
lista_temperatura_minima16 = lista_temperatura_minima16\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima16 = lista_temperatura_minima16.select("TemperaturaMinima")

column_temperatura_minima16 = [d[0] for d in lista_temperatura_minima16.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media16 = dados16.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media16 = lista_temperatura_media16\
    .select('*', (lista_temperatura_media16['Temp_media']- 216).alias('TemperaturaMedia'))

#16- Diminuindo as casas decimais.
lista_temperatura_media16 = lista_temperatura_media16\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media16 = lista_temperatura_media16.select("TemperaturaMedia")

column_temperatura_media16 = [e[0] for e in lista_temperatura_media16.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol16 = dados16.select('city.sunrise')
nascer_sol16 = [f[0] for f in lista_nascer_sol16.collect()] * 40

column_nascer_do_sol16 = []

for n in nascer_sol16:
    ns16 = int(n) # Convertendo para int
    ns16 = datetime.fromtimestamp(ns16, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns16 = str(ns16)
    ns16 = ns16[0:19]
    column_nascer_do_sol16.append(ns16)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol16 = dados16.select('city.sunset')
por_sol16 = [g[0] for g in lista_por_sol16.collect()] * 40

column_por_do_sol16 = []

for p in por_sol16:
    ps16 = int(p) # Convertendo para int
    ps16 = datetime.fromtimestamp(ps16, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps16 = str(ps16)
    ps16 = ps16[0:19]
    column_por_do_sol16.append(ps16)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude16 = dados16.select('city.coord.lat')
column_latitude16 = [h[0] for h in lista_latitude16.collect()] * 40


# LONGITUDE

lista_longitude16 = dados16.select('city.coord.lon')
column_longitude16 = [j[0] for j in lista_longitude16.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento16 = dados16.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento16 = [l[0] for l in lista_velocidade_vento16.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 17
"""

# DATA

lista_data17 = dados17.select (explode('list.dt_txt').alias('Data'))
column_data17 = [a[0] for a in lista_data17.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao17 = dados17.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao17 = lista_descricao17\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao17 = lista_descricao17\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao17 = lista_descricao17\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao17 = lista_descricao17\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao17 = lista_descricao17\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao17 = lista_descricao17\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao17 = lista_descricao17\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao17 = [b[0] for b in lista_descricao17.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima17= dados17.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima17= lista_temperatura_maxima17\
    .select('*', (lista_temperatura_maxima17['Temp_maxima']- 217).alias('TemperaturaMaxima'))

#17- Diminuindo as casas decimais.
lista_temperatura_maxima17= lista_temperatura_maxima17\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima17= lista_temperatura_maxima17.select("TemperaturaMaxima")

column_temperatura_maxima17= [c[0] for c in lista_temperatura_maxima17.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima17 = dados17.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima17 = lista_temperatura_minima17\
    .select('*', (lista_temperatura_minima17['Temp_minima']- 217).alias('TemperaturaMinima'))

#17- Diminuindo as casas decimais.
lista_temperatura_minima17 = lista_temperatura_minima17\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima17 = lista_temperatura_minima17.select("TemperaturaMinima")

column_temperatura_minima17 = [d[0] for d in lista_temperatura_minima17.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media17 = dados17.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media17 = lista_temperatura_media17\
    .select('*', (lista_temperatura_media17['Temp_media']- 217).alias('TemperaturaMedia'))

#17- Diminuindo as casas decimais.
lista_temperatura_media17 = lista_temperatura_media17\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media17 = lista_temperatura_media17.select("TemperaturaMedia")

column_temperatura_media17 = [e[0] for e in lista_temperatura_media17.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol17 = dados17.select('city.sunrise')
nascer_sol17 = [f[0] for f in lista_nascer_sol17.collect()] * 40

column_nascer_do_sol17 = []

for n in nascer_sol17:
    ns17 = int(n) # Convertendo para int
    ns17 = datetime.fromtimestamp(ns17, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns17 = str(ns17)
    ns17 = ns17[0:19]
    column_nascer_do_sol17.append(ns17)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol17 = dados17.select('city.sunset')
por_sol17 = [g[0] for g in lista_por_sol17.collect()] * 40

column_por_do_sol17 = []

for p in por_sol17:
    ps17 = int(p) # Convertendo para int
    ps17 = datetime.fromtimestamp(ps17, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps17 = str(ps17)
    ps17 = ps17[0:19]
    column_por_do_sol17.append(ps17)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude17 = dados17.select('city.coord.lat')
column_latitude17 = [h[0] for h in lista_latitude17.collect()] * 40


# LONGITUDE

lista_longitude17 = dados17.select('city.coord.lon')
column_longitude17 = [j[0] for j in lista_longitude17.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento17 = dados17.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento17 = [l[0] for l in lista_velocidade_vento17.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 18
"""

# DATA

lista_data18 = dados18.select (explode('list.dt_txt').alias('Data'))
column_data18 = [a[0] for a in lista_data18.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao18 = dados18.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao18 = lista_descricao18\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao18 = lista_descricao18\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao18 = lista_descricao18\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao18 = lista_descricao18\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao18 = lista_descricao18\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao18 = lista_descricao18\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao18 = lista_descricao18\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao18 = [b[0] for b in lista_descricao18.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima18= dados18.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima18= lista_temperatura_maxima18\
    .select('*', (lista_temperatura_maxima18['Temp_maxima']- 218).alias('TemperaturaMaxima'))

#18- Diminuindo as casas decimais.
lista_temperatura_maxima18= lista_temperatura_maxima18\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima18= lista_temperatura_maxima18.select("TemperaturaMaxima")

column_temperatura_maxima18= [c[0] for c in lista_temperatura_maxima18.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima18 = dados18.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima18 = lista_temperatura_minima18\
    .select('*', (lista_temperatura_minima18['Temp_minima']- 218).alias('TemperaturaMinima'))

#18- Diminuindo as casas decimais.
lista_temperatura_minima18 = lista_temperatura_minima18\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima18 = lista_temperatura_minima18.select("TemperaturaMinima")

column_temperatura_minima18 = [d[0] for d in lista_temperatura_minima18.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media18 = dados18.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media18 = lista_temperatura_media18\
    .select('*', (lista_temperatura_media18['Temp_media']- 218).alias('TemperaturaMedia'))

#18- Diminuindo as casas decimais.
lista_temperatura_media18 = lista_temperatura_media18\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media18 = lista_temperatura_media18.select("TemperaturaMedia")

column_temperatura_media18 = [e[0] for e in lista_temperatura_media18.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol18 = dados18.select('city.sunrise')
nascer_sol18 = [f[0] for f in lista_nascer_sol18.collect()] * 40

column_nascer_do_sol18 = []

for n in nascer_sol18:
    ns18 = int(n) # Convertendo para int
    ns18 = datetime.fromtimestamp(ns18, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns18 = str(ns18)
    ns18 = ns18[0:19]
    column_nascer_do_sol18.append(ns18)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol18 = dados18.select('city.sunset')
por_sol18 = [g[0] for g in lista_por_sol18.collect()] * 40

column_por_do_sol18 = []

for p in por_sol18:
    ps18 = int(p) # Convertendo para int
    ps18 = datetime.fromtimestamp(ps18, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps18 = str(ps18)
    ps18 = ps18[0:19]
    column_por_do_sol18.append(ps18)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude18 = dados18.select('city.coord.lat')
column_latitude18 = [h[0] for h in lista_latitude18.collect()] * 40


# LONGITUDE

lista_longitude18 = dados18.select('city.coord.lon')
column_longitude18 = [j[0] for j in lista_longitude18.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento18 = dados18.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento18 = [l[0] for l in lista_velocidade_vento18.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 19
"""

# DATA

lista_data19 = dados19.select (explode('list.dt_txt').alias('Data'))
column_data19 = [a[0] for a in lista_data19.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao19 = dados19.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao19 = lista_descricao19\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao19 = lista_descricao19\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao19 = lista_descricao19\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao19 = lista_descricao19\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao19 = lista_descricao19\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao19 = lista_descricao19\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao19 = lista_descricao19\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao19 = [b[0] for b in lista_descricao19.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima19= dados19.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima19= lista_temperatura_maxima19\
    .select('*', (lista_temperatura_maxima19['Temp_maxima']- 219).alias('TemperaturaMaxima'))

#19- Diminuindo as casas decimais.
lista_temperatura_maxima19= lista_temperatura_maxima19\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima19= lista_temperatura_maxima19.select("TemperaturaMaxima")

column_temperatura_maxima19= [c[0] for c in lista_temperatura_maxima19.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima19 = dados19.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima19 = lista_temperatura_minima19\
    .select('*', (lista_temperatura_minima19['Temp_minima']- 219).alias('TemperaturaMinima'))

#19- Diminuindo as casas decimais.
lista_temperatura_minima19 = lista_temperatura_minima19\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima19 = lista_temperatura_minima19.select("TemperaturaMinima")

column_temperatura_minima19 = [d[0] for d in lista_temperatura_minima19.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media19 = dados19.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media19 = lista_temperatura_media19\
    .select('*', (lista_temperatura_media19['Temp_media']- 219).alias('TemperaturaMedia'))

#19- Diminuindo as casas decimais.
lista_temperatura_media19 = lista_temperatura_media19\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media19 = lista_temperatura_media19.select("TemperaturaMedia")

column_temperatura_media19 = [e[0] for e in lista_temperatura_media19.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol19 = dados19.select('city.sunrise')
nascer_sol19 = [f[0] for f in lista_nascer_sol19.collect()] * 40

column_nascer_do_sol19 = []

for n in nascer_sol19:
    ns19 = int(n) # Convertendo para int
    ns19 = datetime.fromtimestamp(ns19, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns19 = str(ns19)
    ns19 = ns19[0:19]
    column_nascer_do_sol19.append(ns19)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol19 = dados19.select('city.sunset')
por_sol19 = [g[0] for g in lista_por_sol19.collect()] * 40

column_por_do_sol19 = []

for p in por_sol19:
    ps19 = int(p) # Convertendo para int
    ps19 = datetime.fromtimestamp(ps19, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps19 = str(ps19)
    ps19 = ps19[0:19]
    column_por_do_sol19.append(ps19)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude19 = dados19.select('city.coord.lat')
column_latitude19 = [h[0] for h in lista_latitude19.collect()] * 40


# LONGITUDE

lista_longitude19 = dados19.select('city.coord.lon')
column_longitude19 = [j[0] for j in lista_longitude19.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento19 = dados19.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento19 = [l[0] for l in lista_velocidade_vento19.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 20
"""

# DATA

lista_data20 = dados20.select (explode('list.dt_txt').alias('Data'))
column_data20 = [a[0] for a in lista_data20.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao20 = dados20.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao20 = lista_descricao20\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao20 = lista_descricao20\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao20 = lista_descricao20\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao20 = lista_descricao20\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao20 = lista_descricao20\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao20 = lista_descricao20\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao20 = lista_descricao20\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao20 = [b[0] for b in lista_descricao20.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima20= dados20.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima20= lista_temperatura_maxima20\
    .select('*', (lista_temperatura_maxima20['Temp_maxima']- 220).alias('TemperaturaMaxima'))

#20- Diminuindo as casas decimais.
lista_temperatura_maxima20= lista_temperatura_maxima20\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima20= lista_temperatura_maxima20.select("TemperaturaMaxima")

column_temperatura_maxima20= [c[0] for c in lista_temperatura_maxima20.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima20 = dados20.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima20 = lista_temperatura_minima20\
    .select('*', (lista_temperatura_minima20['Temp_minima']- 220).alias('TemperaturaMinima'))

#20- Diminuindo as casas decimais.
lista_temperatura_minima20 = lista_temperatura_minima20\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima20 = lista_temperatura_minima20.select("TemperaturaMinima")

column_temperatura_minima20 = [d[0] for d in lista_temperatura_minima20.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media20 = dados20.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media20 = lista_temperatura_media20\
    .select('*', (lista_temperatura_media20['Temp_media']- 220).alias('TemperaturaMedia'))

#20- Diminuindo as casas decimais.
lista_temperatura_media20 = lista_temperatura_media20\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media20 = lista_temperatura_media20.select("TemperaturaMedia")

column_temperatura_media20 = [e[0] for e in lista_temperatura_media20.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol20 = dados20.select('city.sunrise')
nascer_sol20 = [f[0] for f in lista_nascer_sol20.collect()] * 40

column_nascer_do_sol20 = []

for n in nascer_sol20:
    ns20 = int(n) # Convertendo para int
    ns20 = datetime.fromtimestamp(ns20, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns20 = str(ns20)
    ns20 = ns20[0:19]
    column_nascer_do_sol20.append(ns20)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol20 = dados20.select('city.sunset')
por_sol20 = [g[0] for g in lista_por_sol20.collect()] * 40

column_por_do_sol20 = []

for p in por_sol20:
    ps20 = int(p) # Convertendo para int
    ps20 = datetime.fromtimestamp(ps20, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps20 = str(ps20)
    ps20 = ps20[0:19]
    column_por_do_sol20.append(ps20)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude20 = dados20.select('city.coord.lat')
column_latitude20 = [h[0] for h in lista_latitude20.collect()] * 40


# LONGITUDE

lista_longitude20 = dados20.select('city.coord.lon')
column_longitude20 = [j[0] for j in lista_longitude20.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento20 = dados20.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento20 = [l[0] for l in lista_velocidade_vento20.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 21
"""

# DATA

lista_data21 = dados21.select (explode('list.dt_txt').alias('Data'))
column_data21 = [a[0] for a in lista_data21.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao21 = dados21.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao21 = lista_descricao21\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao21 = lista_descricao21\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao21 = lista_descricao21\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao21 = lista_descricao21\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao21 = lista_descricao21\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao21 = lista_descricao21\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao21 = lista_descricao21\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao21 = [b[0] for b in lista_descricao21.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima21= dados21.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima21= lista_temperatura_maxima21\
    .select('*', (lista_temperatura_maxima21['Temp_maxima']- 221).alias('TemperaturaMaxima'))

#21- Diminuindo as casas decimais.
lista_temperatura_maxima21= lista_temperatura_maxima21\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima21= lista_temperatura_maxima21.select("TemperaturaMaxima")

column_temperatura_maxima21= [c[0] for c in lista_temperatura_maxima21.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima21 = dados21.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima21 = lista_temperatura_minima21\
    .select('*', (lista_temperatura_minima21['Temp_minima']- 221).alias('TemperaturaMinima'))

#21- Diminuindo as casas decimais.
lista_temperatura_minima21 = lista_temperatura_minima21\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima21 = lista_temperatura_minima21.select("TemperaturaMinima")

column_temperatura_minima21 = [d[0] for d in lista_temperatura_minima21.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media21 = dados21.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media21 = lista_temperatura_media21\
    .select('*', (lista_temperatura_media21['Temp_media']- 221).alias('TemperaturaMedia'))

#21- Diminuindo as casas decimais.
lista_temperatura_media21 = lista_temperatura_media21\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media21 = lista_temperatura_media21.select("TemperaturaMedia")

column_temperatura_media21 = [e[0] for e in lista_temperatura_media21.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol21 = dados21.select('city.sunrise')
nascer_sol21 = [f[0] for f in lista_nascer_sol21.collect()] * 40

column_nascer_do_sol21 = []

for n in nascer_sol21:
    ns21 = int(n) # Convertendo para int
    ns21 = datetime.fromtimestamp(ns21, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns21 = str(ns21)
    ns21 = ns21[0:19]
    column_nascer_do_sol21.append(ns21)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol21 = dados21.select('city.sunset')
por_sol21 = [g[0] for g in lista_por_sol21.collect()] * 40

column_por_do_sol21 = []

for p in por_sol21:
    ps21 = int(p) # Convertendo para int
    ps21 = datetime.fromtimestamp(ps21, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps21 = str(ps21)
    ps21 = ps21[0:19]
    column_por_do_sol21.append(ps21)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude21 = dados21.select('city.coord.lat')
column_latitude21 = [h[0] for h in lista_latitude21.collect()] * 40


# LONGITUDE

lista_longitude21 = dados21.select('city.coord.lon')
column_longitude21 = [j[0] for j in lista_longitude21.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento21 = dados21.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento21 = [l[0] for l in lista_velocidade_vento21.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 22
"""

# DATA

lista_data22 = dados22.select (explode('list.dt_txt').alias('Data'))
column_data22 = [a[0] for a in lista_data22.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao22 = dados22.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao22 = lista_descricao22\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao22 = lista_descricao22\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao22 = lista_descricao22\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao22 = lista_descricao22\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao22 = lista_descricao22\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao22 = lista_descricao22\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao22 = lista_descricao22\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao22 = [b[0] for b in lista_descricao22.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima22= dados22.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima22= lista_temperatura_maxima22\
    .select('*', (lista_temperatura_maxima22['Temp_maxima']- 222).alias('TemperaturaMaxima'))

#22- Diminuindo as casas decimais.
lista_temperatura_maxima22= lista_temperatura_maxima22\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima22= lista_temperatura_maxima22.select("TemperaturaMaxima")

column_temperatura_maxima22= [c[0] for c in lista_temperatura_maxima22.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima22 = dados22.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima22 = lista_temperatura_minima22\
    .select('*', (lista_temperatura_minima22['Temp_minima']- 222).alias('TemperaturaMinima'))

#22- Diminuindo as casas decimais.
lista_temperatura_minima22 = lista_temperatura_minima22\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima22 = lista_temperatura_minima22.select("TemperaturaMinima")

column_temperatura_minima22 = [d[0] for d in lista_temperatura_minima22.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media22 = dados22.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media22 = lista_temperatura_media22\
    .select('*', (lista_temperatura_media22['Temp_media']- 222).alias('TemperaturaMedia'))

#22- Diminuindo as casas decimais.
lista_temperatura_media22 = lista_temperatura_media22\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media22 = lista_temperatura_media22.select("TemperaturaMedia")

column_temperatura_media22 = [e[0] for e in lista_temperatura_media22.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol22 = dados22.select('city.sunrise')
nascer_sol22 = [f[0] for f in lista_nascer_sol22.collect()] * 40

column_nascer_do_sol22 = []

for n in nascer_sol22:
    ns22 = int(n) # Convertendo para int
    ns22 = datetime.fromtimestamp(ns22, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns22 = str(ns22)
    ns22 = ns22[0:19]
    column_nascer_do_sol22.append(ns22)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol22 = dados22.select('city.sunset')
por_sol22 = [g[0] for g in lista_por_sol22.collect()] * 40

column_por_do_sol22 = []

for p in por_sol22:
    ps22 = int(p) # Convertendo para int
    ps22 = datetime.fromtimestamp(ps22, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps22 = str(ps22)
    ps22 = ps22[0:19]
    column_por_do_sol22.append(ps22)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude22 = dados22.select('city.coord.lat')
column_latitude22 = [h[0] for h in lista_latitude22.collect()] * 40


# LONGITUDE

lista_longitude22 = dados22.select('city.coord.lon')
column_longitude22 = [j[0] for j in lista_longitude22.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento22 = dados22.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento22 = [l[0] for l in lista_velocidade_vento22.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 23
"""

# DATA

lista_data23 = dados23.select (explode('list.dt_txt').alias('Data'))
column_data23 = [a[0] for a in lista_data23.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao23 = dados23.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao23 = lista_descricao23\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao23 = lista_descricao23\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao23 = lista_descricao23\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao23 = lista_descricao23\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao23 = lista_descricao23\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao23 = lista_descricao23\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao23 = lista_descricao23\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao23 = [b[0] for b in lista_descricao23.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima23= dados23.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima23= lista_temperatura_maxima23\
    .select('*', (lista_temperatura_maxima23['Temp_maxima']- 223).alias('TemperaturaMaxima'))

#23- Diminuindo as casas decimais.
lista_temperatura_maxima23= lista_temperatura_maxima23\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima23= lista_temperatura_maxima23.select("TemperaturaMaxima")

column_temperatura_maxima23= [c[0] for c in lista_temperatura_maxima23.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima23 = dados23.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima23 = lista_temperatura_minima23\
    .select('*', (lista_temperatura_minima23['Temp_minima']- 223).alias('TemperaturaMinima'))

#23- Diminuindo as casas decimais.
lista_temperatura_minima23 = lista_temperatura_minima23\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima23 = lista_temperatura_minima23.select("TemperaturaMinima")

column_temperatura_minima23 = [d[0] for d in lista_temperatura_minima23.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media23 = dados23.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media23 = lista_temperatura_media23\
    .select('*', (lista_temperatura_media23['Temp_media']- 223).alias('TemperaturaMedia'))

#23- Diminuindo as casas decimais.
lista_temperatura_media23 = lista_temperatura_media23\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media23 = lista_temperatura_media23.select("TemperaturaMedia")

column_temperatura_media23 = [e[0] for e in lista_temperatura_media23.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol23 = dados23.select('city.sunrise')
nascer_sol23 = [f[0] for f in lista_nascer_sol23.collect()] * 40

column_nascer_do_sol23 = []

for n in nascer_sol23:
    ns23 = int(n) # Convertendo para int
    ns23 = datetime.fromtimestamp(ns23, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns23 = str(ns23)
    ns23 = ns23[0:19]
    column_nascer_do_sol23.append(ns23)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol23 = dados23.select('city.sunset')
por_sol23 = [g[0] for g in lista_por_sol23.collect()] * 40

column_por_do_sol23 = []

for p in por_sol23:
    ps23 = int(p) # Convertendo para int
    ps23 = datetime.fromtimestamp(ps23, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps23 = str(ps23)
    ps23 = ps23[0:19]
    column_por_do_sol23.append(ps23)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude23 = dados23.select('city.coord.lat')
column_latitude23 = [h[0] for h in lista_latitude23.collect()] * 40


# LONGITUDE

lista_longitude23 = dados23.select('city.coord.lon')
column_longitude23 = [j[0] for j in lista_longitude23.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento23 = dados23.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento23 = [l[0] for l in lista_velocidade_vento23.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 24
"""

# DATA

lista_data24 = dados24.select (explode('list.dt_txt').alias('Data'))
column_data24 = [a[0] for a in lista_data24.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao24 = dados24.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao24 = lista_descricao24\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao24 = lista_descricao24\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao24 = lista_descricao24\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao24 = lista_descricao24\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao24 = lista_descricao24\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao24 = lista_descricao24\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao24 = lista_descricao24\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao24 = [b[0] for b in lista_descricao24.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima24= dados24.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima24= lista_temperatura_maxima24\
    .select('*', (lista_temperatura_maxima24['Temp_maxima']- 224).alias('TemperaturaMaxima'))

#24- Diminuindo as casas decimais.
lista_temperatura_maxima24= lista_temperatura_maxima24\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima24= lista_temperatura_maxima24.select("TemperaturaMaxima")

column_temperatura_maxima24= [c[0] for c in lista_temperatura_maxima24.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima24 = dados24.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima24 = lista_temperatura_minima24\
    .select('*', (lista_temperatura_minima24['Temp_minima']- 224).alias('TemperaturaMinima'))

#24- Diminuindo as casas decimais.
lista_temperatura_minima24 = lista_temperatura_minima24\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima24 = lista_temperatura_minima24.select("TemperaturaMinima")

column_temperatura_minima24 = [d[0] for d in lista_temperatura_minima24.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media24 = dados24.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media24 = lista_temperatura_media24\
    .select('*', (lista_temperatura_media24['Temp_media']- 224).alias('TemperaturaMedia'))

#24- Diminuindo as casas decimais.
lista_temperatura_media24 = lista_temperatura_media24\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media24 = lista_temperatura_media24.select("TemperaturaMedia")

column_temperatura_media24 = [e[0] for e in lista_temperatura_media24.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol24 = dados24.select('city.sunrise')
nascer_sol24 = [f[0] for f in lista_nascer_sol24.collect()] * 40

column_nascer_do_sol24 = []

for n in nascer_sol24:
    ns24 = int(n) # Convertendo para int
    ns24 = datetime.fromtimestamp(ns24, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns24 = str(ns24)
    ns24 = ns24[0:19]
    column_nascer_do_sol24.append(ns24)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol24 = dados24.select('city.sunset')
por_sol24 = [g[0] for g in lista_por_sol24.collect()] * 40

column_por_do_sol24 = []

for p in por_sol24:
    ps24 = int(p) # Convertendo para int
    ps24 = datetime.fromtimestamp(ps24, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps24 = str(ps24)
    ps24 = ps24[0:19]
    column_por_do_sol24.append(ps24)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude24 = dados24.select('city.coord.lat')
column_latitude24 = [h[0] for h in lista_latitude24.collect()] * 40


# LONGITUDE

lista_longitude24 = dados24.select('city.coord.lon')
column_longitude24 = [j[0] for j in lista_longitude24.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento24 = dados24.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento24 = [l[0] for l in lista_velocidade_vento24.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 25
"""

# DATA

lista_data25 = dados25.select (explode('list.dt_txt').alias('Data'))
column_data25 = [a[0] for a in lista_data25.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao25 = dados25.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao25 = lista_descricao25\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao25 = lista_descricao25\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao25 = lista_descricao25\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao25 = lista_descricao25\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao25 = lista_descricao25\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao25 = lista_descricao25\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao25 = lista_descricao25\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao25 = [b[0] for b in lista_descricao25.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima25= dados25.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima25= lista_temperatura_maxima25\
    .select('*', (lista_temperatura_maxima25['Temp_maxima']- 225).alias('TemperaturaMaxima'))

#25- Diminuindo as casas decimais.
lista_temperatura_maxima25= lista_temperatura_maxima25\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima25= lista_temperatura_maxima25.select("TemperaturaMaxima")

column_temperatura_maxima25= [c[0] for c in lista_temperatura_maxima25.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima25 = dados25.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima25 = lista_temperatura_minima25\
    .select('*', (lista_temperatura_minima25['Temp_minima']- 225).alias('TemperaturaMinima'))

#25- Diminuindo as casas decimais.
lista_temperatura_minima25 = lista_temperatura_minima25\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima25 = lista_temperatura_minima25.select("TemperaturaMinima")

column_temperatura_minima25 = [d[0] for d in lista_temperatura_minima25.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media25 = dados25.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media25 = lista_temperatura_media25\
    .select('*', (lista_temperatura_media25['Temp_media']- 225).alias('TemperaturaMedia'))

#25- Diminuindo as casas decimais.
lista_temperatura_media25 = lista_temperatura_media25\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media25 = lista_temperatura_media25.select("TemperaturaMedia")

column_temperatura_media25 = [e[0] for e in lista_temperatura_media25.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol25 = dados25.select('city.sunrise')
nascer_sol25 = [f[0] for f in lista_nascer_sol25.collect()] * 40

column_nascer_do_sol25 = []

for n in nascer_sol25:
    ns25 = int(n) # Convertendo para int
    ns25 = datetime.fromtimestamp(ns25, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns25 = str(ns25)
    ns25 = ns25[0:19]
    column_nascer_do_sol25.append(ns25)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol25 = dados25.select('city.sunset')
por_sol25 = [g[0] for g in lista_por_sol25.collect()] * 40

column_por_do_sol25 = []

for p in por_sol25:
    ps25 = int(p) # Convertendo para int
    ps25 = datetime.fromtimestamp(ps25, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps25 = str(ps25)
    ps25 = ps25[0:19]
    column_por_do_sol25.append(ps25)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude25 = dados25.select('city.coord.lat')
column_latitude25 = [h[0] for h in lista_latitude25.collect()] * 40


# LONGITUDE

lista_longitude25 = dados25.select('city.coord.lon')
column_longitude25 = [j[0] for j in lista_longitude25.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento25 = dados25.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento25 = [l[0] for l in lista_velocidade_vento25.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 26
"""

# DATA

lista_data26 = dados26.select (explode('list.dt_txt').alias('Data'))
column_data26 = [a[0] for a in lista_data26.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao26 = dados26.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao26 = lista_descricao26\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao26 = lista_descricao26\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao26 = lista_descricao26\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao26 = lista_descricao26\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao26 = lista_descricao26\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao26 = lista_descricao26\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao26 = lista_descricao26\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao26 = [b[0] for b in lista_descricao26.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima26= dados26.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima26= lista_temperatura_maxima26\
    .select('*', (lista_temperatura_maxima26['Temp_maxima']- 226).alias('TemperaturaMaxima'))

#26- Diminuindo as casas decimais.
lista_temperatura_maxima26= lista_temperatura_maxima26\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima26= lista_temperatura_maxima26.select("TemperaturaMaxima")

column_temperatura_maxima26= [c[0] for c in lista_temperatura_maxima26.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima26 = dados26.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima26 = lista_temperatura_minima26\
    .select('*', (lista_temperatura_minima26['Temp_minima']- 226).alias('TemperaturaMinima'))

#26- Diminuindo as casas decimais.
lista_temperatura_minima26 = lista_temperatura_minima26\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima26 = lista_temperatura_minima26.select("TemperaturaMinima")

column_temperatura_minima26 = [d[0] for d in lista_temperatura_minima26.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media26 = dados26.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media26 = lista_temperatura_media26\
    .select('*', (lista_temperatura_media26['Temp_media']- 226).alias('TemperaturaMedia'))

#26- Diminuindo as casas decimais.
lista_temperatura_media26 = lista_temperatura_media26\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media26 = lista_temperatura_media26.select("TemperaturaMedia")

column_temperatura_media26 = [e[0] for e in lista_temperatura_media26.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol26 = dados26.select('city.sunrise')
nascer_sol26 = [f[0] for f in lista_nascer_sol26.collect()] * 40

column_nascer_do_sol26 = []

for n in nascer_sol26:
    ns26 = int(n) # Convertendo para int
    ns26 = datetime.fromtimestamp(ns26, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns26 = str(ns26)
    ns26 = ns26[0:19]
    column_nascer_do_sol26.append(ns26)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol26 = dados26.select('city.sunset')
por_sol26 = [g[0] for g in lista_por_sol26.collect()] * 40

column_por_do_sol26 = []

for p in por_sol26:
    ps26 = int(p) # Convertendo para int
    ps26 = datetime.fromtimestamp(ps26, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps26 = str(ps26)
    ps26 = ps26[0:19]
    column_por_do_sol26.append(ps26)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude26 = dados26.select('city.coord.lat')
column_latitude26 = [h[0] for h in lista_latitude26.collect()] * 40


# LONGITUDE

lista_longitude26 = dados26.select('city.coord.lon')
column_longitude26 = [j[0] for j in lista_longitude26.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento26 = dados26.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento26 = [l[0] for l in lista_velocidade_vento26.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 27
"""

# DATA

lista_data27 = dados27.select (explode('list.dt_txt').alias('Data'))
column_data27 = [a[0] for a in lista_data27.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao27 = dados27.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao27 = lista_descricao27\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao27 = lista_descricao27\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao27 = lista_descricao27\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao27 = lista_descricao27\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao27 = lista_descricao27\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao27 = lista_descricao27\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao27 = lista_descricao27\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao27 = [b[0] for b in lista_descricao27.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima27= dados27.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima27= lista_temperatura_maxima27\
    .select('*', (lista_temperatura_maxima27['Temp_maxima']- 227).alias('TemperaturaMaxima'))

#27- Diminuindo as casas decimais.
lista_temperatura_maxima27= lista_temperatura_maxima27\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima27= lista_temperatura_maxima27.select("TemperaturaMaxima")

column_temperatura_maxima27= [c[0] for c in lista_temperatura_maxima27.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima27 = dados27.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima27 = lista_temperatura_minima27\
    .select('*', (lista_temperatura_minima27['Temp_minima']- 227).alias('TemperaturaMinima'))

#27- Diminuindo as casas decimais.
lista_temperatura_minima27 = lista_temperatura_minima27\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima27 = lista_temperatura_minima27.select("TemperaturaMinima")

column_temperatura_minima27 = [d[0] for d in lista_temperatura_minima27.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media27 = dados27.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media27 = lista_temperatura_media27\
    .select('*', (lista_temperatura_media27['Temp_media']- 227).alias('TemperaturaMedia'))

#27- Diminuindo as casas decimais.
lista_temperatura_media27 = lista_temperatura_media27\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media27 = lista_temperatura_media27.select("TemperaturaMedia")

column_temperatura_media27 = [e[0] for e in lista_temperatura_media27.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol27 = dados27.select('city.sunrise')
nascer_sol27 = [f[0] for f in lista_nascer_sol27.collect()] * 40

column_nascer_do_sol27 = []

for n in nascer_sol27:
    ns27 = int(n) # Convertendo para int
    ns27 = datetime.fromtimestamp(ns27, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns27 = str(ns27)
    ns27 = ns27[0:19]
    column_nascer_do_sol27.append(ns27)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol27 = dados27.select('city.sunset')
por_sol27 = [g[0] for g in lista_por_sol27.collect()] * 40

column_por_do_sol27 = []

for p in por_sol27:
    ps27 = int(p) # Convertendo para int
    ps27 = datetime.fromtimestamp(ps27, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps27 = str(ps27)
    ps27 = ps27[0:19]
    column_por_do_sol27.append(ps27)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude27 = dados27.select('city.coord.lat')
column_latitude27 = [h[0] for h in lista_latitude27.collect()] * 40


# LONGITUDE

lista_longitude27 = dados27.select('city.coord.lon')
column_longitude27 = [j[0] for j in lista_longitude27.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento27 = dados27.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento27 = [l[0] for l in lista_velocidade_vento27.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 28
"""

# DATA

lista_data28 = dados28.select (explode('list.dt_txt').alias('Data'))
column_data28 = [a[0] for a in lista_data28.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao28 = dados28.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao28 = lista_descricao28\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao28 = lista_descricao28\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao28 = lista_descricao28\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao28 = lista_descricao28\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao28 = lista_descricao28\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao28 = lista_descricao28\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao28 = lista_descricao28\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao28 = [b[0] for b in lista_descricao28.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima28= dados28.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima28= lista_temperatura_maxima28\
    .select('*', (lista_temperatura_maxima28['Temp_maxima']- 228).alias('TemperaturaMaxima'))

#28- Diminuindo as casas decimais.
lista_temperatura_maxima28= lista_temperatura_maxima28\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima28= lista_temperatura_maxima28.select("TemperaturaMaxima")

column_temperatura_maxima28= [c[0] for c in lista_temperatura_maxima28.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima28 = dados28.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima28 = lista_temperatura_minima28\
    .select('*', (lista_temperatura_minima28['Temp_minima']- 228).alias('TemperaturaMinima'))

#28- Diminuindo as casas decimais.
lista_temperatura_minima28 = lista_temperatura_minima28\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima28 = lista_temperatura_minima28.select("TemperaturaMinima")

column_temperatura_minima28 = [d[0] for d in lista_temperatura_minima28.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media28 = dados28.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media28 = lista_temperatura_media28\
    .select('*', (lista_temperatura_media28['Temp_media']- 228).alias('TemperaturaMedia'))

#28- Diminuindo as casas decimais.
lista_temperatura_media28 = lista_temperatura_media28\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media28 = lista_temperatura_media28.select("TemperaturaMedia")

column_temperatura_media28 = [e[0] for e in lista_temperatura_media28.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol28 = dados28.select('city.sunrise')
nascer_sol28 = [f[0] for f in lista_nascer_sol28.collect()] * 40

column_nascer_do_sol28 = []

for n in nascer_sol28:
    ns28 = int(n) # Convertendo para int
    ns28 = datetime.fromtimestamp(ns28, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns28 = str(ns28)
    ns28 = ns28[0:19]
    column_nascer_do_sol28.append(ns28)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol28 = dados28.select('city.sunset')
por_sol28 = [g[0] for g in lista_por_sol28.collect()] * 40

column_por_do_sol28 = []

for p in por_sol28:
    ps28 = int(p) # Convertendo para int
    ps28 = datetime.fromtimestamp(ps28, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps28 = str(ps28)
    ps28 = ps28[0:19]
    column_por_do_sol28.append(ps28)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude28 = dados28.select('city.coord.lat')
column_latitude28 = [h[0] for h in lista_latitude28.collect()] * 40


# LONGITUDE

lista_longitude28 = dados28.select('city.coord.lon')
column_longitude28 = [j[0] for j in lista_longitude28.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento28 = dados28.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento28 = [l[0] for l in lista_velocidade_vento28.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 29
"""

# DATA

lista_data29 = dados29.select (explode('list.dt_txt').alias('Data'))
column_data29 = [a[0] for a in lista_data29.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao29 = dados29.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao29 = lista_descricao29\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao29 = lista_descricao29\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao29 = lista_descricao29\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao29 = lista_descricao29\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao29 = lista_descricao29\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao29 = lista_descricao29\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao29 = lista_descricao29\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao29 = [b[0] for b in lista_descricao29.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima29= dados29.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima29= lista_temperatura_maxima29\
    .select('*', (lista_temperatura_maxima29['Temp_maxima']- 229).alias('TemperaturaMaxima'))

#29- Diminuindo as casas decimais.
lista_temperatura_maxima29= lista_temperatura_maxima29\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima29= lista_temperatura_maxima29.select("TemperaturaMaxima")

column_temperatura_maxima29= [c[0] for c in lista_temperatura_maxima29.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima29 = dados29.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima29 = lista_temperatura_minima29\
    .select('*', (lista_temperatura_minima29['Temp_minima']- 229).alias('TemperaturaMinima'))

#29- Diminuindo as casas decimais.
lista_temperatura_minima29 = lista_temperatura_minima29\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima29 = lista_temperatura_minima29.select("TemperaturaMinima")

column_temperatura_minima29 = [d[0] for d in lista_temperatura_minima29.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media29 = dados29.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media29 = lista_temperatura_media29\
    .select('*', (lista_temperatura_media29['Temp_media']- 229).alias('TemperaturaMedia'))

#29- Diminuindo as casas decimais.
lista_temperatura_media29 = lista_temperatura_media29\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media29 = lista_temperatura_media29.select("TemperaturaMedia")

column_temperatura_media29 = [e[0] for e in lista_temperatura_media29.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol29 = dados29.select('city.sunrise')
nascer_sol29 = [f[0] for f in lista_nascer_sol29.collect()] * 40

column_nascer_do_sol29 = []

for n in nascer_sol29:
    ns29 = int(n) # Convertendo para int
    ns29 = datetime.fromtimestamp(ns29, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns29 = str(ns29)
    ns29 = ns29[0:19]
    column_nascer_do_sol29.append(ns29)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol29 = dados29.select('city.sunset')
por_sol29 = [g[0] for g in lista_por_sol29.collect()] * 40

column_por_do_sol29 = []

for p in por_sol29:
    ps29 = int(p) # Convertendo para int
    ps29 = datetime.fromtimestamp(ps29, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps29 = str(ps29)
    ps29 = ps29[0:19]
    column_por_do_sol29.append(ps29)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude29 = dados29.select('city.coord.lat')
column_latitude29 = [h[0] for h in lista_latitude29.collect()] * 40


# LONGITUDE

lista_longitude29 = dados29.select('city.coord.lon')
column_longitude29 = [j[0] for j in lista_longitude29.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento29 = dados29.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento29 = [l[0] for l in lista_velocidade_vento29.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 30
"""

# DATA

lista_data30 = dados30.select (explode('list.dt_txt').alias('Data'))
column_data30 = [a[0] for a in lista_data30.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao30 = dados30.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao30 = lista_descricao30\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao30 = lista_descricao30\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao30= lista_descricao30\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao30 = lista_descricao30\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao30 = lista_descricao30\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao30 = lista_descricao30\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao30 = lista_descricao30\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao30 = [b[0] for b in lista_descricao30.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima30= dados30.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima30= lista_temperatura_maxima30\
    .select('*', (lista_temperatura_maxima30['Temp_maxima']- 230).alias('TemperaturaMaxima'))

#30- Diminuindo as casas decimais.
lista_temperatura_maxima30= lista_temperatura_maxima30\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima30= lista_temperatura_maxima30.select("TemperaturaMaxima")

column_temperatura_maxima30= [c[0] for c in lista_temperatura_maxima30.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima30 = dados30.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima30 = lista_temperatura_minima30\
    .select('*', (lista_temperatura_minima30['Temp_minima']- 230).alias('TemperaturaMinima'))

#30- Diminuindo as casas decimais.
lista_temperatura_minima30 = lista_temperatura_minima30\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima30 = lista_temperatura_minima30.select("TemperaturaMinima")

column_temperatura_minima30 = [d[0] for d in lista_temperatura_minima30.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media30 = dados30.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media30 = lista_temperatura_media30\
    .select('*', (lista_temperatura_media30['Temp_media']- 230).alias('TemperaturaMedia'))

#30- Diminuindo as casas decimais.
lista_temperatura_media30 = lista_temperatura_media30\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media30 = lista_temperatura_media30.select("TemperaturaMedia")

column_temperatura_media30 = [e[0] for e in lista_temperatura_media30.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol30 = dados30.select('city.sunrise')
nascer_sol30 = [f[0] for f in lista_nascer_sol30.collect()] * 40

column_nascer_do_sol30 = []

for n in nascer_sol30:
    ns30 = int(n) # Convertendo para int
    ns30 = datetime.fromtimestamp(ns30, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns30 = str(ns30)
    ns30 = ns30[0:19]
    column_nascer_do_sol30.append(ns30)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol30 = dados30.select('city.sunset') 
por_sol30 = [g[0] for g in lista_por_sol30.collect()] * 40

column_por_do_sol30 = []

for p in por_sol30:
    ps30 = int(p) # Convertendo para int
    ps30 = datetime.fromtimestamp(ps30, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps30 = str(ps30)
    ps30 = ps30[0:19]
    column_por_do_sol30.append(ps30)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude30 = dados30.select('city.coord.lat')
column_latitude30 = [h[0] for h in lista_latitude30.collect()] * 40


# LONGITUDE

lista_longitude30 = dados30.select('city.coord.lon')
column_longitude30 = [j[0] for j in lista_longitude30.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento30 = dados30.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento30 = [l[0] for l in lista_velocidade_vento30.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 31
"""

# DATA

lista_data31 = dados31.select (explode('list.dt_txt').alias('Data'))
column_data31 = [a[0] for a in lista_data31.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao31 = dados31.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao31 = lista_descricao31\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao31 = lista_descricao31\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao31 = lista_descricao31\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao31 = lista_descricao31\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao31 = lista_descricao31\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao31 = lista_descricao31\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao31 = lista_descricao31\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao31 = [b[0] for b in lista_descricao31.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima31= dados31.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima31= lista_temperatura_maxima31\
    .select('*', (lista_temperatura_maxima31['Temp_maxima']- 231).alias('TemperaturaMaxima'))

#31- Diminuindo as casas decimais.
lista_temperatura_maxima31= lista_temperatura_maxima31\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima31= lista_temperatura_maxima31.select("TemperaturaMaxima")

column_temperatura_maxima31= [c[0] for c in lista_temperatura_maxima31.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima31 = dados31.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima31 = lista_temperatura_minima31\
    .select('*', (lista_temperatura_minima31['Temp_minima']- 231).alias('TemperaturaMinima'))

#31- Diminuindo as casas decimais.
lista_temperatura_minima31 = lista_temperatura_minima31\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima31 = lista_temperatura_minima31.select("TemperaturaMinima")

column_temperatura_minima31 = [d[0] for d in lista_temperatura_minima31.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media31 = dados31.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media31 = lista_temperatura_media31\
    .select('*', (lista_temperatura_media31['Temp_media']- 231).alias('TemperaturaMedia'))

#31- Diminuindo as casas decimais.
lista_temperatura_media31 = lista_temperatura_media31\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media31 = lista_temperatura_media31.select("TemperaturaMedia")

column_temperatura_media31 = [e[0] for e in lista_temperatura_media31.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol31 = dados31.select('city.sunrise')
nascer_sol31 = [f[0] for f in lista_nascer_sol31.collect()] * 40

column_nascer_do_sol31 = []

for n in nascer_sol31:
    ns31 = int(n) # Convertendo para int
    ns31 = datetime.fromtimestamp(ns31, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns31 = str(ns31)
    ns31 = ns31[0:19]
    column_nascer_do_sol31.append(ns31)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol31 = dados31.select('city.sunset')
por_sol31 = [g[0] for g in lista_por_sol31.collect()] * 40

column_por_do_sol31 = []

for p in por_sol31:
    ps31 = int(p) # Convertendo para int
    ps31 = datetime.fromtimestamp(ps31, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps31 = str(ps31)
    ps31 = ps31[0:19]
    column_por_do_sol31.append(ps31)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude31 = dados31.select('city.coord.lat')
column_latitude31 = [h[0] for h in lista_latitude31.collect()] * 40


# LONGITUDE

lista_longitude31 = dados31.select('city.coord.lon')
column_longitude31 = [j[0] for j in lista_longitude31.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento31 = dados31.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento31 = [l[0] for l in lista_velocidade_vento31.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 32
"""

# DATA

lista_data32 = dados32.select (explode('list.dt_txt').alias('Data'))
column_data32 = [a[0] for a in lista_data32.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao32 = dados32.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao32 = lista_descricao32\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao32 = lista_descricao32\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao32 = lista_descricao32\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao32 = lista_descricao32\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao32 = lista_descricao32\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao32 = lista_descricao32\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao32 = lista_descricao32\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao32 = [b[0] for b in lista_descricao32.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima32= dados32.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima32= lista_temperatura_maxima32\
    .select('*', (lista_temperatura_maxima32['Temp_maxima']- 232).alias('TemperaturaMaxima'))

#32- Diminuindo as casas decimais.
lista_temperatura_maxima32= lista_temperatura_maxima32\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima32= lista_temperatura_maxima32.select("TemperaturaMaxima")

column_temperatura_maxima32= [c[0] for c in lista_temperatura_maxima32.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima32 = dados32.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima32 = lista_temperatura_minima32\
    .select('*', (lista_temperatura_minima32['Temp_minima']- 232).alias('TemperaturaMinima'))

#32- Diminuindo as casas decimais.
lista_temperatura_minima32 = lista_temperatura_minima32\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima32 = lista_temperatura_minima32.select("TemperaturaMinima")

column_temperatura_minima32 = [d[0] for d in lista_temperatura_minima32.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media32 = dados32.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media32 = lista_temperatura_media32\
    .select('*', (lista_temperatura_media32['Temp_media']- 232).alias('TemperaturaMedia'))

#32- Diminuindo as casas decimais.
lista_temperatura_media32 = lista_temperatura_media32\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media32 = lista_temperatura_media32.select("TemperaturaMedia")

column_temperatura_media32 = [e[0] for e in lista_temperatura_media32.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol32 = dados32.select('city.sunrise')
nascer_sol32 = [f[0] for f in lista_nascer_sol32.collect()] * 40

column_nascer_do_sol32 = []

for n in nascer_sol32:
    ns32 = int(n) # Convertendo para int
    ns32 = datetime.fromtimestamp(ns32, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns32 = str(ns32)
    ns32 = ns32[0:19]
    column_nascer_do_sol32.append(ns32)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol32 = dados32.select('city.sunset')
por_sol32 = [g[0] for g in lista_por_sol32.collect()] * 40

column_por_do_sol32 = []

for p in por_sol32:
    ps32 = int(p) # Convertendo para int
    ps32 = datetime.fromtimestamp(ps32, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps32 = str(ps32)
    ps32 = ps32[0:19]
    column_por_do_sol32.append(ps32)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude32 = dados32.select('city.coord.lat')
column_latitude32 = [h[0] for h in lista_latitude32.collect()] * 40


# LONGITUDE

lista_longitude32 = dados32.select('city.coord.lon')
column_longitude32 = [j[0] for j in lista_longitude32.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento32 = dados32.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento32 = [l[0] for l in lista_velocidade_vento32.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 33
"""

# DATA

lista_data33 = dados33.select (explode('list.dt_txt').alias('Data'))
column_data33 = [a[0] for a in lista_data33.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao33 = dados33.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao33 = lista_descricao33\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao33 = lista_descricao33\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao33 = lista_descricao33\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao33 = lista_descricao33\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao33 = lista_descricao33\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao33 = lista_descricao33\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao33 = lista_descricao33\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao33 = [b[0] for b in lista_descricao33.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima33= dados33.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima33= lista_temperatura_maxima33\
    .select('*', (lista_temperatura_maxima33['Temp_maxima']- 233).alias('TemperaturaMaxima'))

#33- Diminuindo as casas decimais.
lista_temperatura_maxima33= lista_temperatura_maxima33\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima33= lista_temperatura_maxima33.select("TemperaturaMaxima")

column_temperatura_maxima33= [c[0] for c in lista_temperatura_maxima33.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima33 = dados33.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima33 = lista_temperatura_minima33\
    .select('*', (lista_temperatura_minima33['Temp_minima']- 233).alias('TemperaturaMinima'))

#33- Diminuindo as casas decimais.
lista_temperatura_minima33 = lista_temperatura_minima33\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima33 = lista_temperatura_minima33.select("TemperaturaMinima")

column_temperatura_minima33 = [d[0] for d in lista_temperatura_minima33.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media33 = dados33.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media33 = lista_temperatura_media33\
    .select('*', (lista_temperatura_media33['Temp_media']- 233).alias('TemperaturaMedia'))

#33- Diminuindo as casas decimais.
lista_temperatura_media33 = lista_temperatura_media33\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media33 = lista_temperatura_media33.select("TemperaturaMedia")

column_temperatura_media33 = [e[0] for e in lista_temperatura_media33.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol33 = dados33.select('city.sunrise')
nascer_sol33 = [f[0] for f in lista_nascer_sol33.collect()] * 40

column_nascer_do_sol33 = []

for n in nascer_sol33:
    ns33 = int(n) # Convertendo para int
    ns33 = datetime.fromtimestamp(ns33, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns33 = str(ns33)
    ns33 = ns33[0:19]
    column_nascer_do_sol33.append(ns33)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol33 = dados33.select('city.sunset')
por_sol33 = [g[0] for g in lista_por_sol33.collect()] * 40

column_por_do_sol33 = []

for p in por_sol33:
    ps33 = int(p) # Convertendo para int
    ps33 = datetime.fromtimestamp(ps33, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps33 = str(ps33)
    ps33 = ps33[0:19]
    column_por_do_sol33.append(ps33)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude33 = dados33.select('city.coord.lat')
column_latitude33 = [h[0] for h in lista_latitude33.collect()] * 40


# LONGITUDE

lista_longitude33 = dados33.select('city.coord.lon')
column_longitude33 = [j[0] for j in lista_longitude33.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento33 = dados33.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento33 = [l[0] for l in lista_velocidade_vento33.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 34
"""

# DATA

lista_data34 = dados34.select (explode('list.dt_txt').alias('Data'))
column_data34 = [a[0] for a in lista_data34.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao34 = dados34.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao34 = lista_descricao34\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao34 = lista_descricao34\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao34 = lista_descricao34\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao34 = lista_descricao34\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao34 = lista_descricao34\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao34 = lista_descricao34\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao34 = lista_descricao34\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao34 = [b[0] for b in lista_descricao34.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima34= dados34.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima34= lista_temperatura_maxima34\
    .select('*', (lista_temperatura_maxima34['Temp_maxima']- 234).alias('TemperaturaMaxima'))

#34- Diminuindo as casas decimais.
lista_temperatura_maxima34= lista_temperatura_maxima34\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima34= lista_temperatura_maxima34.select("TemperaturaMaxima")

column_temperatura_maxima34= [c[0] for c in lista_temperatura_maxima34.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima34 = dados34.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima34 = lista_temperatura_minima34\
    .select('*', (lista_temperatura_minima34['Temp_minima']- 234).alias('TemperaturaMinima'))

#34- Diminuindo as casas decimais.
lista_temperatura_minima34 = lista_temperatura_minima34\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima34 = lista_temperatura_minima34.select("TemperaturaMinima")

column_temperatura_minima34 = [d[0] for d in lista_temperatura_minima34.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media34 = dados34.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media34 = lista_temperatura_media34\
    .select('*', (lista_temperatura_media34['Temp_media']- 234).alias('TemperaturaMedia'))

#34- Diminuindo as casas decimais.
lista_temperatura_media34 = lista_temperatura_media34\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media34 = lista_temperatura_media34.select("TemperaturaMedia")

column_temperatura_media34 = [e[0] for e in lista_temperatura_media34.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol34 = dados34.select('city.sunrise')
nascer_sol34 = [f[0] for f in lista_nascer_sol34.collect()] * 40

column_nascer_do_sol34 = []

for n in nascer_sol34:
    ns34 = int(n) # Convertendo para int
    ns34 = datetime.fromtimestamp(ns34, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns34 = str(ns34)
    ns34 = ns34[0:19]
    column_nascer_do_sol34.append(ns34)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol34 = dados34.select('city.sunset')
por_sol34 = [g[0] for g in lista_por_sol34.collect()] * 40

column_por_do_sol34 = []

for p in por_sol34:
    ps34 = int(p) # Convertendo para int
    ps34 = datetime.fromtimestamp(ps34, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps34 = str(ps34)
    ps34 = ps34[0:19]
    column_por_do_sol34.append(ps34)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude34 = dados34.select('city.coord.lat')
column_latitude34 = [h[0] for h in lista_latitude34.collect()] * 40


# LONGITUDE

lista_longitude34 = dados34.select('city.coord.lon')
column_longitude34 = [j[0] for j in lista_longitude34.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento34 = dados34.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento34 = [l[0] for l in lista_velocidade_vento34.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 35
"""

# DATA

lista_data35 = dados35.select (explode('list.dt_txt').alias('Data'))
column_data35 = [a[0] for a in lista_data35.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao35 = dados35.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao35 = lista_descricao35\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao35 = lista_descricao35\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao35 = lista_descricao35\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao35 = lista_descricao35\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao35 = lista_descricao35\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao35 = lista_descricao35\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao35 = lista_descricao35\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao35 = [b[0] for b in lista_descricao35.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima35= dados35.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima35= lista_temperatura_maxima35\
    .select('*', (lista_temperatura_maxima35['Temp_maxima']- 235).alias('TemperaturaMaxima'))

#35- Diminuindo as casas decimais.
lista_temperatura_maxima35= lista_temperatura_maxima35\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima35= lista_temperatura_maxima35.select("TemperaturaMaxima")

column_temperatura_maxima35= [c[0] for c in lista_temperatura_maxima35.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima35 = dados35.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima35 = lista_temperatura_minima35\
    .select('*', (lista_temperatura_minima35['Temp_minima']- 235).alias('TemperaturaMinima'))

#35- Diminuindo as casas decimais.
lista_temperatura_minima35 = lista_temperatura_minima35\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima35 = lista_temperatura_minima35.select("TemperaturaMinima")

column_temperatura_minima35 = [d[0] for d in lista_temperatura_minima35.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media35 = dados35.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media35 = lista_temperatura_media35\
    .select('*', (lista_temperatura_media35['Temp_media']- 235).alias('TemperaturaMedia'))

#35- Diminuindo as casas decimais.
lista_temperatura_media35 = lista_temperatura_media35\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media35 = lista_temperatura_media35.select("TemperaturaMedia")

column_temperatura_media35 = [e[0] for e in lista_temperatura_media35.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol35 = dados35.select('city.sunrise')
nascer_sol35 = [f[0] for f in lista_nascer_sol35.collect()] * 40

column_nascer_do_sol35 = []

for n in nascer_sol35:
    ns35 = int(n) # Convertendo para int
    ns35 = datetime.fromtimestamp(ns35, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns35 = str(ns35)
    ns35 = ns35[0:19]
    column_nascer_do_sol35.append(ns35)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol35 = dados35.select('city.sunset')
por_sol35 = [g[0] for g in lista_por_sol35.collect()] * 40

column_por_do_sol35 = []

for p in por_sol35:
    ps35 = int(p) # Convertendo para int
    ps35 = datetime.fromtimestamp(ps35, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps35 = str(ps35)
    ps35 = ps35[0:19]
    column_por_do_sol35.append(ps35)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude35 = dados35.select('city.coord.lat')
column_latitude35 = [h[0] for h in lista_latitude35.collect()] * 40


# LONGITUDE

lista_longitude35 = dados35.select('city.coord.lon')
column_longitude35 = [j[0] for j in lista_longitude35.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento35 = dados35.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento35 = [l[0] for l in lista_velocidade_vento35.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 36
"""

# DATA

lista_data36 = dados36.select (explode('list.dt_txt').alias('Data'))
column_data36 = [a[0] for a in lista_data36.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao36 = dados36.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao36 = lista_descricao36\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao36 = lista_descricao36\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao36 = lista_descricao36\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao36 = lista_descricao36\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao36 = lista_descricao36\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao36 = lista_descricao36\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao36 = lista_descricao36\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao36 = [b[0] for b in lista_descricao36.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima36= dados36.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima36= lista_temperatura_maxima36\
    .select('*', (lista_temperatura_maxima36['Temp_maxima']- 236).alias('TemperaturaMaxima'))

#36- Diminuindo as casas decimais.
lista_temperatura_maxima36= lista_temperatura_maxima36\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima36= lista_temperatura_maxima36.select("TemperaturaMaxima")

column_temperatura_maxima36= [c[0] for c in lista_temperatura_maxima36.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima36 = dados36.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima36 = lista_temperatura_minima36\
    .select('*', (lista_temperatura_minima36['Temp_minima']- 236).alias('TemperaturaMinima'))

#36- Diminuindo as casas decimais.
lista_temperatura_minima36 = lista_temperatura_minima36\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima36 = lista_temperatura_minima36.select("TemperaturaMinima")

column_temperatura_minima36 = [d[0] for d in lista_temperatura_minima36.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media36 = dados36.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media36 = lista_temperatura_media36\
    .select('*', (lista_temperatura_media36['Temp_media']- 236).alias('TemperaturaMedia'))

#36- Diminuindo as casas decimais.
lista_temperatura_media36 = lista_temperatura_media36\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media36 = lista_temperatura_media36.select("TemperaturaMedia")

column_temperatura_media36 = [e[0] for e in lista_temperatura_media36.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol36 = dados36.select('city.sunrise')
nascer_sol36 = [f[0] for f in lista_nascer_sol36.collect()] * 40

column_nascer_do_sol36 = []

for n in nascer_sol36:
    ns36 = int(n) # Convertendo para int
    ns36 = datetime.fromtimestamp(ns36, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns36 = str(ns36)
    ns36 = ns36[0:19]
    column_nascer_do_sol36.append(ns36)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol36 = dados36.select('city.sunset')
por_sol36 = [g[0] for g in lista_por_sol36.collect()] * 40

column_por_do_sol36 = []

for p in por_sol36:
    ps36 = int(p) # Convertendo para int
    ps36 = datetime.fromtimestamp(ps36, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps36 = str(ps36)
    ps36 = ps36[0:19]
    column_por_do_sol36.append(ps36)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude36 = dados36.select('city.coord.lat')
column_latitude36 = [h[0] for h in lista_latitude36.collect()] * 40


# LONGITUDE

lista_longitude36 = dados36.select('city.coord.lon')
column_longitude36 = [j[0] for j in lista_longitude36.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento36 = dados36.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento36 = [l[0] for l in lista_velocidade_vento36.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 37
"""

# DATA

lista_data37 = dados37.select (explode('list.dt_txt').alias('Data'))
column_data37 = [a[0] for a in lista_data37.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao37 = dados37.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao37 = lista_descricao37\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao37 = lista_descricao37\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao37 = lista_descricao37\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao37 = lista_descricao37\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao37 = lista_descricao37\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao37 = lista_descricao37\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao37 = lista_descricao37\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao37 = [b[0] for b in lista_descricao37.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima37= dados37.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima37= lista_temperatura_maxima37\
    .select('*', (lista_temperatura_maxima37['Temp_maxima']- 237).alias('TemperaturaMaxima'))

#37- Diminuindo as casas decimais.
lista_temperatura_maxima37= lista_temperatura_maxima37\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima37= lista_temperatura_maxima37.select("TemperaturaMaxima")

column_temperatura_maxima37= [c[0] for c in lista_temperatura_maxima37.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima37 = dados37.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima37 = lista_temperatura_minima37\
    .select('*', (lista_temperatura_minima37['Temp_minima']- 237).alias('TemperaturaMinima'))

#37- Diminuindo as casas decimais.
lista_temperatura_minima37 = lista_temperatura_minima37\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima37 = lista_temperatura_minima37.select("TemperaturaMinima")

column_temperatura_minima37 = [d[0] for d in lista_temperatura_minima37.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media37 = dados37.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media37 = lista_temperatura_media37\
    .select('*', (lista_temperatura_media37['Temp_media']- 237).alias('TemperaturaMedia'))

#37- Diminuindo as casas decimais.
lista_temperatura_media37 = lista_temperatura_media37\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media37 = lista_temperatura_media37.select("TemperaturaMedia")

column_temperatura_media37 = [e[0] for e in lista_temperatura_media37.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol37 = dados37.select('city.sunrise')
nascer_sol37 = [f[0] for f in lista_nascer_sol37.collect()] * 40

column_nascer_do_sol37 = []

for n in nascer_sol37:
    ns37 = int(n) # Convertendo para int
    ns37 = datetime.fromtimestamp(ns37, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns37 = str(ns37)
    ns37 = ns37[0:19]
    column_nascer_do_sol37.append(ns37)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol37 = dados37.select('city.sunset')
por_sol37 = [g[0] for g in lista_por_sol37.collect()] * 40

column_por_do_sol37 = []

for p in por_sol37:
    ps37 = int(p) # Convertendo para int
    ps37 = datetime.fromtimestamp(ps37, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps37 = str(ps37)
    ps37 = ps37[0:19]
    column_por_do_sol37.append(ps37)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude37 = dados37.select('city.coord.lat')
column_latitude37 = [h[0] for h in lista_latitude37.collect()] * 40


# LONGITUDE

lista_longitude37 = dados37.select('city.coord.lon')
column_longitude37 = [j[0] for j in lista_longitude37.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento37 = dados37.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento37 = [l[0] for l in lista_velocidade_vento37.collect()]
#--------------------------------------------------------------------------------------------------------

"""
CIDADE 38
"""

# DATA

lista_data38 = dados38.select (explode('list.dt_txt').alias('Data'))
column_data38 = [a[0] for a in lista_data38.collect()]


# DESCRICAO

#1- Extraíndo dados do arquivo json
lista_descricao38 = dados38.select(explode('list').alias('list'))\
    .select(explode('list.weather.description').alias('VaiChover'))

#2- Renomeando os dados da coluna (vaichover = sim ou não)
lista_descricao38 = lista_descricao38\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva leve', 'sim'))
lista_descricao38 = lista_descricao38\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva moderada', 'sim'))
lista_descricao38 = lista_descricao38\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'chuva forte', 'sim'))
lista_descricao38 = lista_descricao38\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nublado', 'não'))
lista_descricao38 = lista_descricao38\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'nuvens dispersas', 'não'))
lista_descricao38 = lista_descricao38\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'céu limpo', 'não'))
lista_descricao38 = lista_descricao38\
    .withColumn('VaiChover', regexp_replace('VaiChover', 'algumas nuvens', 'não'))

column_descricao38 = [b[0] for b in lista_descricao38.collect()]


# TEMPERATURA MÁXIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_maxima38= dados38.select(explode('list.main.temp_max').alias('Temp_maxima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_maxima38= lista_temperatura_maxima38\
    .select('*', (lista_temperatura_maxima38['Temp_maxima']- 238).alias('TemperaturaMaxima'))

#38- Diminuindo as casas decimais.
lista_temperatura_maxima38= lista_temperatura_maxima38\
    .withColumn("TemperaturaMaxima", round(col("TemperaturaMaxima"), 2))
lista_temperatura_maxima38= lista_temperatura_maxima38.select("TemperaturaMaxima")

column_temperatura_maxima38= [c[0] for c in lista_temperatura_maxima38.collect()]


# TEMPERATURA MÍNIMA

#1- Extraíndo dados do arquivo json
lista_temperatura_minima38 = dados38.select(explode('list.main.temp_min').alias('Temp_minima'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_minima38 = lista_temperatura_minima38\
    .select('*', (lista_temperatura_minima38['Temp_minima']- 238).alias('TemperaturaMinima'))

#38- Diminuindo as casas decimais.
lista_temperatura_minima38 = lista_temperatura_minima38\
    .withColumn("TemperaturaMinima", round(col("TemperaturaMinima"), 2))

lista_temperatura_minima38 = lista_temperatura_minima38.select("TemperaturaMinima")

column_temperatura_minima38 = [d[0] for d in lista_temperatura_minima38.collect()]


# TEMPERATURA MÉDIA

#1- Extraíndo dados do arquivo json
lista_temperatura_media38 = dados38.select(explode('list.main.temp').alias('Temp_media'))

#2- Convertendo (Kelvin em Celcius).
lista_temperatura_media38 = lista_temperatura_media38\
    .select('*', (lista_temperatura_media38['Temp_media']- 238).alias('TemperaturaMedia'))

#38- Diminuindo as casas decimais.
lista_temperatura_media38 = lista_temperatura_media38\
    .withColumn("TemperaturaMedia", round(col("TemperaturaMedia"), 2))

lista_temperatura_media38 = lista_temperatura_media38.select("TemperaturaMedia")

column_temperatura_media38 = [e[0] for e in lista_temperatura_media38.collect()]


# NASCER DO SOL

from datetime import datetime
from pytz import timezone

lista_nascer_sol38 = dados38.select('city.sunrise')
nascer_sol38 = [f[0] for f in lista_nascer_sol38.collect()] * 40

column_nascer_do_sol38 = []

for n in nascer_sol38:
    ns38 = int(n) # Convertendo para int
    ns38 = datetime.fromtimestamp(ns38, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ns38 = str(ns38)
    ns38 = ns38[0:19]
    column_nascer_do_sol38.append(ns38)
#print('Nascer do Sol:', column_nascer_do_sol)


# POR DO SOL

lista_por_sol38 = dados38.select('city.sunset')
por_sol38 = [g[0] for g in lista_por_sol38.collect()] * 40

column_por_do_sol38 = []

for p in por_sol38:
    ps38 = int(p) # Convertendo para int
    ps38 = datetime.fromtimestamp(ps38, tz = timezone("America/Sao_Paulo")) # Convertendo para o formato data
    ps38 = str(ps38)
    ps38 = ps38[0:19]
    column_por_do_sol38.append(ps38)
#print('Por do Sol:', column_por_do_sol)


# LATITUDE

lista_latitude38 = dados38.select('city.coord.lat')
column_latitude38 = [h[0] for h in lista_latitude38.collect()] * 40


# LONGITUDE

lista_longitude38 = dados38.select('city.coord.lon')
column_longitude38 = [j[0] for j in lista_longitude38.collect()] * 40


# VELOCIDADE DO VENTO

lista_velocidade_vento38 = dados38.select(explode('list.wind.speed').alias('VelocidadeDoVento'))
column_velocidade_do_vento38 = [l[0] for l in lista_velocidade_vento38.collect()]

# %% [markdown]
# **CONCATENANDO LISTAS DE DADOS**

# %%
# DATA

column_data0.extend(column_data1)
column_data0.extend(column_data2)
column_data0.extend(column_data3)
column_data0.extend(column_data4)
column_data0.extend(column_data5)
column_data0.extend(column_data6)
column_data0.extend(column_data7)
column_data0.extend(column_data8)
column_data0.extend(column_data9)
column_data0.extend(column_data10)
column_data0.extend(column_data11)
column_data0.extend(column_data12)
column_data0.extend(column_data13)
column_data0.extend(column_data14)
column_data0.extend(column_data15)
column_data0.extend(column_data16)
column_data0.extend(column_data17)
column_data0.extend(column_data18)
column_data0.extend(column_data19)
column_data0.extend(column_data20)
column_data0.extend(column_data21)
column_data0.extend(column_data22)
column_data0.extend(column_data23)
column_data0.extend(column_data24)
column_data0.extend(column_data25)
column_data0.extend(column_data26)
column_data0.extend(column_data27)
column_data0.extend(column_data28)
column_data0.extend(column_data29)
column_data0.extend(column_data30)
column_data0.extend(column_data31)
column_data0.extend(column_data32)
column_data0.extend(column_data33)
column_data0.extend(column_data34)
column_data0.extend(column_data35)
column_data0.extend(column_data36)
column_data0.extend(column_data37)
column_data0.extend(column_data38)

column_data = column_data0


# DESCRIÇÃO (VAI CHOVER OU NÃO)

column_descricao0.extend(column_descricao1)
column_descricao0.extend(column_descricao2)
column_descricao0.extend(column_descricao3)
column_descricao0.extend(column_descricao4)
column_descricao0.extend(column_descricao5)
column_descricao0.extend(column_descricao6)
column_descricao0.extend(column_descricao7)
column_descricao0.extend(column_descricao8)
column_descricao0.extend(column_descricao9)
column_descricao0.extend(column_descricao10)
column_descricao0.extend(column_descricao11)
column_descricao0.extend(column_descricao12)
column_descricao0.extend(column_descricao13)
column_descricao0.extend(column_descricao14)
column_descricao0.extend(column_descricao15)
column_descricao0.extend(column_descricao16)
column_descricao0.extend(column_descricao17)
column_descricao0.extend(column_descricao18)
column_descricao0.extend(column_descricao19)
column_descricao0.extend(column_descricao20)
column_descricao0.extend(column_descricao21)
column_descricao0.extend(column_descricao22)
column_descricao0.extend(column_descricao23)
column_descricao0.extend(column_descricao24)
column_descricao0.extend(column_descricao25)
column_descricao0.extend(column_descricao26)
column_descricao0.extend(column_descricao27)
column_descricao0.extend(column_descricao28)
column_descricao0.extend(column_descricao29)
column_descricao0.extend(column_descricao30)
column_descricao0.extend(column_descricao31)
column_descricao0.extend(column_descricao32)
column_descricao0.extend(column_descricao33)
column_descricao0.extend(column_descricao34)
column_descricao0.extend(column_descricao35)
column_descricao0.extend(column_descricao36)
column_descricao0.extend(column_descricao37)
column_descricao0.extend(column_descricao38)

column_descricao = column_descricao0


# TEMPERATURA MÁXIMA


column_temperatura_maxima0.extend(column_temperatura_maxima1)
column_temperatura_maxima0.extend(column_temperatura_maxima2)
column_temperatura_maxima0.extend(column_temperatura_maxima3)
column_temperatura_maxima0.extend(column_temperatura_maxima4)
column_temperatura_maxima0.extend(column_temperatura_maxima5)
column_temperatura_maxima0.extend(column_temperatura_maxima6)
column_temperatura_maxima0.extend(column_temperatura_maxima7)
column_temperatura_maxima0.extend(column_temperatura_maxima8)
column_temperatura_maxima0.extend(column_temperatura_maxima9)
column_temperatura_maxima0.extend(column_temperatura_maxima10)
column_temperatura_maxima0.extend(column_temperatura_maxima11)
column_temperatura_maxima0.extend(column_temperatura_maxima12)
column_temperatura_maxima0.extend(column_temperatura_maxima13)
column_temperatura_maxima0.extend(column_temperatura_maxima14)
column_temperatura_maxima0.extend(column_temperatura_maxima15)
column_temperatura_maxima0.extend(column_temperatura_maxima16)
column_temperatura_maxima0.extend(column_temperatura_maxima17)
column_temperatura_maxima0.extend(column_temperatura_maxima18)
column_temperatura_maxima0.extend(column_temperatura_maxima19)
column_temperatura_maxima0.extend(column_temperatura_maxima20)
column_temperatura_maxima0.extend(column_temperatura_maxima21)
column_temperatura_maxima0.extend(column_temperatura_maxima22)
column_temperatura_maxima0.extend(column_temperatura_maxima23)
column_temperatura_maxima0.extend(column_temperatura_maxima24)
column_temperatura_maxima0.extend(column_temperatura_maxima25)
column_temperatura_maxima0.extend(column_temperatura_maxima26)
column_temperatura_maxima0.extend(column_temperatura_maxima27)
column_temperatura_maxima0.extend(column_temperatura_maxima28)
column_temperatura_maxima0.extend(column_temperatura_maxima29)
column_temperatura_maxima0.extend(column_temperatura_maxima30)
column_temperatura_maxima0.extend(column_temperatura_maxima31)
column_temperatura_maxima0.extend(column_temperatura_maxima32)
column_temperatura_maxima0.extend(column_temperatura_maxima33)
column_temperatura_maxima0.extend(column_temperatura_maxima34)
column_temperatura_maxima0.extend(column_temperatura_maxima35)
column_temperatura_maxima0.extend(column_temperatura_maxima36)
column_temperatura_maxima0.extend(column_temperatura_maxima37)
column_temperatura_maxima0.extend(column_temperatura_maxima38)

column_temperatura_maxima = column_temperatura_maxima0


# TEMPERATURA MÍNIMA


column_temperatura_minima0.extend(column_temperatura_minima1)
column_temperatura_minima0.extend(column_temperatura_minima2)
column_temperatura_minima0.extend(column_temperatura_minima3)
column_temperatura_minima0.extend(column_temperatura_minima4)
column_temperatura_minima0.extend(column_temperatura_minima5)
column_temperatura_minima0.extend(column_temperatura_minima6)
column_temperatura_minima0.extend(column_temperatura_minima7)
column_temperatura_minima0.extend(column_temperatura_minima8)
column_temperatura_minima0.extend(column_temperatura_minima9)
column_temperatura_minima0.extend(column_temperatura_minima10)
column_temperatura_minima0.extend(column_temperatura_minima11)
column_temperatura_minima0.extend(column_temperatura_minima12)
column_temperatura_minima0.extend(column_temperatura_minima13)
column_temperatura_minima0.extend(column_temperatura_minima14)
column_temperatura_minima0.extend(column_temperatura_minima15)
column_temperatura_minima0.extend(column_temperatura_minima16)
column_temperatura_minima0.extend(column_temperatura_minima17)
column_temperatura_minima0.extend(column_temperatura_minima18)
column_temperatura_minima0.extend(column_temperatura_minima19)
column_temperatura_minima0.extend(column_temperatura_minima20)
column_temperatura_minima0.extend(column_temperatura_minima21)
column_temperatura_minima0.extend(column_temperatura_minima22)
column_temperatura_minima0.extend(column_temperatura_minima23)
column_temperatura_minima0.extend(column_temperatura_minima24)
column_temperatura_minima0.extend(column_temperatura_minima25)
column_temperatura_minima0.extend(column_temperatura_minima26)
column_temperatura_minima0.extend(column_temperatura_minima27)
column_temperatura_minima0.extend(column_temperatura_minima28)
column_temperatura_minima0.extend(column_temperatura_minima29)
column_temperatura_minima0.extend(column_temperatura_minima30)
column_temperatura_minima0.extend(column_temperatura_minima31)
column_temperatura_minima0.extend(column_temperatura_minima32)
column_temperatura_minima0.extend(column_temperatura_minima33)
column_temperatura_minima0.extend(column_temperatura_minima34)
column_temperatura_minima0.extend(column_temperatura_minima35)
column_temperatura_minima0.extend(column_temperatura_minima36)
column_temperatura_minima0.extend(column_temperatura_minima37)
column_temperatura_minima0.extend(column_temperatura_minima38)

column_temperatura_minima = column_temperatura_minima0




# TEMPERATURA MÉDIA


column_temperatura_media0.extend(column_temperatura_media1)
column_temperatura_media0.extend(column_temperatura_media2)
column_temperatura_media0.extend(column_temperatura_media3)
column_temperatura_media0.extend(column_temperatura_media4)
column_temperatura_media0.extend(column_temperatura_media5)
column_temperatura_media0.extend(column_temperatura_media6)
column_temperatura_media0.extend(column_temperatura_media7)
column_temperatura_media0.extend(column_temperatura_media8)
column_temperatura_media0.extend(column_temperatura_media9)
column_temperatura_media0.extend(column_temperatura_media10)
column_temperatura_media0.extend(column_temperatura_media11)
column_temperatura_media0.extend(column_temperatura_media12)
column_temperatura_media0.extend(column_temperatura_media13)
column_temperatura_media0.extend(column_temperatura_media14)
column_temperatura_media0.extend(column_temperatura_media15)
column_temperatura_media0.extend(column_temperatura_media16)
column_temperatura_media0.extend(column_temperatura_media17)
column_temperatura_media0.extend(column_temperatura_media18)
column_temperatura_media0.extend(column_temperatura_media19)
column_temperatura_media0.extend(column_temperatura_media20)
column_temperatura_media0.extend(column_temperatura_media21)
column_temperatura_media0.extend(column_temperatura_media22)
column_temperatura_media0.extend(column_temperatura_media23)
column_temperatura_media0.extend(column_temperatura_media24)
column_temperatura_media0.extend(column_temperatura_media25)
column_temperatura_media0.extend(column_temperatura_media26)
column_temperatura_media0.extend(column_temperatura_media27)
column_temperatura_media0.extend(column_temperatura_media28)
column_temperatura_media0.extend(column_temperatura_media29)
column_temperatura_media0.extend(column_temperatura_media30)
column_temperatura_media0.extend(column_temperatura_media31)
column_temperatura_media0.extend(column_temperatura_media32)
column_temperatura_media0.extend(column_temperatura_media33)
column_temperatura_media0.extend(column_temperatura_media34)
column_temperatura_media0.extend(column_temperatura_media35)
column_temperatura_media0.extend(column_temperatura_media36)
column_temperatura_media0.extend(column_temperatura_media37)
column_temperatura_media0.extend(column_temperatura_media38)

column_temperatura_media = column_temperatura_media0


#LATITUDE 


column_latitude0.extend(column_latitude1)
column_latitude0.extend(column_latitude2)
column_latitude0.extend(column_latitude3)
column_latitude0.extend(column_latitude4)
column_latitude0.extend(column_latitude5)
column_latitude0.extend(column_latitude6)
column_latitude0.extend(column_latitude7)
column_latitude0.extend(column_latitude8)
column_latitude0.extend(column_latitude9)
column_latitude0.extend(column_latitude10)
column_latitude0.extend(column_latitude11)
column_latitude0.extend(column_latitude12)
column_latitude0.extend(column_latitude13)
column_latitude0.extend(column_latitude14)
column_latitude0.extend(column_latitude15)
column_latitude0.extend(column_latitude16)
column_latitude0.extend(column_latitude17)
column_latitude0.extend(column_latitude18)
column_latitude0.extend(column_latitude19)
column_latitude0.extend(column_latitude20)
column_latitude0.extend(column_latitude21)
column_latitude0.extend(column_latitude22)
column_latitude0.extend(column_latitude23)
column_latitude0.extend(column_latitude24)
column_latitude0.extend(column_latitude25)
column_latitude0.extend(column_latitude26)
column_latitude0.extend(column_latitude27)
column_latitude0.extend(column_latitude28)
column_latitude0.extend(column_latitude29)
column_latitude0.extend(column_latitude30)
column_latitude0.extend(column_latitude31)
column_latitude0.extend(column_latitude32)
column_latitude0.extend(column_latitude33)
column_latitude0.extend(column_latitude34)
column_latitude0.extend(column_latitude35)
column_latitude0.extend(column_latitude36)
column_latitude0.extend(column_latitude37)
column_latitude0.extend(column_latitude38)

column_latitude = column_latitude0


# LONGITUDE


column_longitude0.extend(column_longitude1)
column_longitude0.extend(column_longitude2)
column_longitude0.extend(column_longitude3)
column_longitude0.extend(column_longitude4)
column_longitude0.extend(column_longitude5)
column_longitude0.extend(column_longitude6)
column_longitude0.extend(column_longitude7)
column_longitude0.extend(column_longitude8)
column_longitude0.extend(column_longitude9)
column_longitude0.extend(column_longitude10)
column_longitude0.extend(column_longitude11)
column_longitude0.extend(column_longitude12)
column_longitude0.extend(column_longitude13)
column_longitude0.extend(column_longitude14)
column_longitude0.extend(column_longitude15)
column_longitude0.extend(column_longitude16)
column_longitude0.extend(column_longitude17)
column_longitude0.extend(column_longitude18)
column_longitude0.extend(column_longitude19)
column_longitude0.extend(column_longitude20)
column_longitude0.extend(column_longitude21)
column_longitude0.extend(column_longitude22)
column_longitude0.extend(column_longitude23)
column_longitude0.extend(column_longitude24)
column_longitude0.extend(column_longitude25)
column_longitude0.extend(column_longitude26)
column_longitude0.extend(column_longitude27)
column_longitude0.extend(column_longitude28)
column_longitude0.extend(column_longitude29)
column_longitude0.extend(column_longitude30)
column_longitude0.extend(column_longitude31)
column_longitude0.extend(column_longitude32)
column_longitude0.extend(column_longitude33)
column_longitude0.extend(column_longitude34)
column_longitude0.extend(column_longitude35)
column_longitude0.extend(column_longitude36)
column_longitude0.extend(column_longitude37)
column_longitude0.extend(column_longitude38)

column_longitude = column_longitude0


# NASCER DO SOL


column_nascer_do_sol0.extend(column_nascer_do_sol1)
column_nascer_do_sol0.extend(column_nascer_do_sol2)
column_nascer_do_sol0.extend(column_nascer_do_sol3)
column_nascer_do_sol0.extend(column_nascer_do_sol4)
column_nascer_do_sol0.extend(column_nascer_do_sol5)
column_nascer_do_sol0.extend(column_nascer_do_sol6)
column_nascer_do_sol0.extend(column_nascer_do_sol7)
column_nascer_do_sol0.extend(column_nascer_do_sol8)
column_nascer_do_sol0.extend(column_nascer_do_sol9)
column_nascer_do_sol0.extend(column_nascer_do_sol10)
column_nascer_do_sol0.extend(column_nascer_do_sol11)
column_nascer_do_sol0.extend(column_nascer_do_sol12)
column_nascer_do_sol0.extend(column_nascer_do_sol13)
column_nascer_do_sol0.extend(column_nascer_do_sol14)
column_nascer_do_sol0.extend(column_nascer_do_sol15)
column_nascer_do_sol0.extend(column_nascer_do_sol16)
column_nascer_do_sol0.extend(column_nascer_do_sol17)
column_nascer_do_sol0.extend(column_nascer_do_sol18)
column_nascer_do_sol0.extend(column_nascer_do_sol19)
column_nascer_do_sol0.extend(column_nascer_do_sol20)
column_nascer_do_sol0.extend(column_nascer_do_sol21)
column_nascer_do_sol0.extend(column_nascer_do_sol22)
column_nascer_do_sol0.extend(column_nascer_do_sol23)
column_nascer_do_sol0.extend(column_nascer_do_sol24)
column_nascer_do_sol0.extend(column_nascer_do_sol25)
column_nascer_do_sol0.extend(column_nascer_do_sol26)
column_nascer_do_sol0.extend(column_nascer_do_sol27)
column_nascer_do_sol0.extend(column_nascer_do_sol28)
column_nascer_do_sol0.extend(column_nascer_do_sol29)
column_nascer_do_sol0.extend(column_nascer_do_sol30)
column_nascer_do_sol0.extend(column_nascer_do_sol31)
column_nascer_do_sol0.extend(column_nascer_do_sol32)
column_nascer_do_sol0.extend(column_nascer_do_sol33)
column_nascer_do_sol0.extend(column_nascer_do_sol34)
column_nascer_do_sol0.extend(column_nascer_do_sol35)
column_nascer_do_sol0.extend(column_nascer_do_sol36)
column_nascer_do_sol0.extend(column_nascer_do_sol37)
column_nascer_do_sol0.extend(column_nascer_do_sol38)

column_nascer_do_sol = column_nascer_do_sol0


# POR DO SOL


column_por_do_sol0.extend(column_por_do_sol1)
column_por_do_sol0.extend(column_por_do_sol2)
column_por_do_sol0.extend(column_por_do_sol3)
column_por_do_sol0.extend(column_por_do_sol4)
column_por_do_sol0.extend(column_por_do_sol5)
column_por_do_sol0.extend(column_por_do_sol6)
column_por_do_sol0.extend(column_por_do_sol7)
column_por_do_sol0.extend(column_por_do_sol8)
column_por_do_sol0.extend(column_por_do_sol9)
column_por_do_sol0.extend(column_por_do_sol10)
column_por_do_sol0.extend(column_por_do_sol11)
column_por_do_sol0.extend(column_por_do_sol12)
column_por_do_sol0.extend(column_por_do_sol13)
column_por_do_sol0.extend(column_por_do_sol14)
column_por_do_sol0.extend(column_por_do_sol15)
column_por_do_sol0.extend(column_por_do_sol16)
column_por_do_sol0.extend(column_por_do_sol17)
column_por_do_sol0.extend(column_por_do_sol18)
column_por_do_sol0.extend(column_por_do_sol19)
column_por_do_sol0.extend(column_por_do_sol20)
column_por_do_sol0.extend(column_por_do_sol21)
column_por_do_sol0.extend(column_por_do_sol22)
column_por_do_sol0.extend(column_por_do_sol23)
column_por_do_sol0.extend(column_por_do_sol24)
column_por_do_sol0.extend(column_por_do_sol25)
column_por_do_sol0.extend(column_por_do_sol26)
column_por_do_sol0.extend(column_por_do_sol27)
column_por_do_sol0.extend(column_por_do_sol28)
column_por_do_sol0.extend(column_por_do_sol29)
column_por_do_sol0.extend(column_por_do_sol30)
column_por_do_sol0.extend(column_por_do_sol31)
column_por_do_sol0.extend(column_por_do_sol32)
column_por_do_sol0.extend(column_por_do_sol33)
column_por_do_sol0.extend(column_por_do_sol34)
column_por_do_sol0.extend(column_por_do_sol35)
column_por_do_sol0.extend(column_por_do_sol36)
column_por_do_sol0.extend(column_por_do_sol37)
column_por_do_sol0.extend(column_por_do_sol38)

column_por_do_sol = column_por_do_sol0


# VELOCIDADE DO VENTO


column_velocidade_do_vento0.extend(column_velocidade_do_vento1)
column_velocidade_do_vento0.extend(column_velocidade_do_vento2)
column_velocidade_do_vento0.extend(column_velocidade_do_vento3)
column_velocidade_do_vento0.extend(column_velocidade_do_vento4)
column_velocidade_do_vento0.extend(column_velocidade_do_vento5)
column_velocidade_do_vento0.extend(column_velocidade_do_vento6)
column_velocidade_do_vento0.extend(column_velocidade_do_vento7)
column_velocidade_do_vento0.extend(column_velocidade_do_vento8)
column_velocidade_do_vento0.extend(column_velocidade_do_vento9)
column_velocidade_do_vento0.extend(column_velocidade_do_vento10)
column_velocidade_do_vento0.extend(column_velocidade_do_vento11)
column_velocidade_do_vento0.extend(column_velocidade_do_vento12)
column_velocidade_do_vento0.extend(column_velocidade_do_vento13)
column_velocidade_do_vento0.extend(column_velocidade_do_vento14)
column_velocidade_do_vento0.extend(column_velocidade_do_vento15)
column_velocidade_do_vento0.extend(column_velocidade_do_vento16)
column_velocidade_do_vento0.extend(column_velocidade_do_vento17)
column_velocidade_do_vento0.extend(column_velocidade_do_vento18)
column_velocidade_do_vento0.extend(column_velocidade_do_vento19)
column_velocidade_do_vento0.extend(column_velocidade_do_vento20)
column_velocidade_do_vento0.extend(column_velocidade_do_vento21)
column_velocidade_do_vento0.extend(column_velocidade_do_vento22)
column_velocidade_do_vento0.extend(column_velocidade_do_vento23)
column_velocidade_do_vento0.extend(column_velocidade_do_vento24)
column_velocidade_do_vento0.extend(column_velocidade_do_vento25)
column_velocidade_do_vento0.extend(column_velocidade_do_vento26)
column_velocidade_do_vento0.extend(column_velocidade_do_vento27)
column_velocidade_do_vento0.extend(column_velocidade_do_vento28)
column_velocidade_do_vento0.extend(column_velocidade_do_vento29)
column_velocidade_do_vento0.extend(column_velocidade_do_vento30)
column_velocidade_do_vento0.extend(column_velocidade_do_vento31)
column_velocidade_do_vento0.extend(column_velocidade_do_vento32)
column_velocidade_do_vento0.extend(column_velocidade_do_vento33)
column_velocidade_do_vento0.extend(column_velocidade_do_vento34)
column_velocidade_do_vento0.extend(column_velocidade_do_vento35)
column_velocidade_do_vento0.extend(column_velocidade_do_vento36)
column_velocidade_do_vento0.extend(column_velocidade_do_vento37)
column_velocidade_do_vento0.extend(column_velocidade_do_vento38)

column_velocidade_do_vento = column_velocidade_do_vento0

# %%
# CRIANDO UM DATAFRAME SPARK

colunas = StructType([StructField('Cidade', StringType(), True),
          StructField('CodigoDaCidade',IntegerType(), True),
          StructField('Data', StringType(), True),
          StructField('Regiao', StringType(), True),
          StructField('Estado', StringType(), True),
          StructField('Pais', StringType(), True),
          StructField('Latitude', StringType(), True),
          StructField('Longitude', StringType(), True),
          StructField('TemperaturaMaxima', FloatType(), True),
          StructField('TemperaturaMinima', FloatType(), True),
          StructField('TemperaturaMedia', FloatType(), True),
          StructField('VaiChover', StringType(), True),            
          StructField('NascerDoSol', StringType(), True), 
          StructField('PorDoSol', StringType(), True), 
          StructField('VelocidadeDoVento', StringType(), True)])
                     

dataframe_previsoes = spark.createDataFrame(zip(column_nome_cidade, column_codigo_cidade, column_data, column_regiao,
                                     column_estado, column_pais, column_latitude, column_longitude,
                                     column_temperatura_maxima, column_temperatura_minima, column_temperatura_media, 
                                     column_descricao, column_nascer_do_sol, column_por_do_sol,
                                     column_velocidade_do_vento), colunas)

# %%
dataframe_previsoes = dataframe_previsoes.withColumn("Data", dataframe_previsoes["Data"].cast("timestamp"))\
                   .withColumn("NascerDoSol", dataframe_previsoes["NascerDoSol"].cast("timestamp"))\
                   .withColumn("PorDoSol", dataframe_previsoes["PorDoSol"].cast("timestamp"))\
                   .withColumn("VelocidadeDoVento", dataframe_previsoes["VelocidadeDoVento"].cast("float"))

# %% [markdown]
# **EXTRAÍNDO DADOS PARA A TABELA2 - MAPEAMENTO**

# %%
dataframe_mapeamento = dataframe_previsoes.select('Cidade', 'Data', 'VaiChover')

# %%
# PEGA A DATA DE CINCO DIAS SEGUIDOS

data_hoje1 = date.today()   #Recebe a data de hoje
data_amanha1 = date.today() + timedelta (1)
data_amanha2 = date.today() + timedelta (2)
data_amanha3 = date.today() + timedelta (3)
data_amanha4 = date.today() + timedelta (4)
data_amanha5 = date.today() + timedelta (5)

data_hoje1 = str(data_hoje1)
data_amanha1 = str(data_amanha1)
data_amanha2 = str(data_amanha2)
data_amanha3 = str(data_amanha3)
data_amanha4 = str(data_amanha4)
data_amanha5 = str(data_amanha5)


# Pegar a quantidade de dias que choveu por cidade


#0
contando0 = 0
contando1 = 0
contando2 = 0
contando3 = 0
contando4 = 0
contando5 = 0

#1
contando6 = 0
contando7 = 0
contando8 = 0
contando9 = 0
contando10 = 0
contando11 = 0

#2
contando12 = 0
contando13 = 0
contando14 = 0
contando15 = 0
contando16 = 0
contando17 = 0

#3
contando18 = 0
contando19 = 0
contando20 = 0
contando21 = 0
contando22 = 0
contando23 = 0


#4
contando24 = 0
contando25 = 0
contando26 = 0
contando27 = 0
contando28 = 0
contando29 = 0


#5
contando30 = 0
contando31 = 0
contando32 = 0
contando33 = 0
contando34 = 0
contando35 = 0

#6
contando36 = 0
contando37 = 0
contando38 = 0
contando39 = 0
contando40 = 0
contando41 = 0


#7
contando42 = 0
contando43 = 0
contando44 = 0
contando45 = 0
contando46 = 0
contando47 = 0


#8
contando48 = 0
contando49 = 0
contando50 = 0
contando51 = 0
contando52 = 0
contando53 = 0

#9
contando54 = 0
contando55 = 0
contando56 = 0
contando57 = 0
contando58 = 0
contando59 = 0


#10
contando60 = 0
contando61 = 0
contando62 = 0
contando63 = 0
contando64 = 0
contando65 = 0


#11
contando66 = 0
contando67 = 0
contando68 = 0
contando69 = 0
contando70 = 0
contando71 = 0


#12
contando72 = 0
contando73 = 0
contando74 = 0
contando75 = 0
contando76 = 0
contando77 = 0


#13
contando78 = 0
contando79 = 0
contando80 = 0
contando81 = 0
contando82 = 0
contando83 = 0


#14
contando84 = 0
contando85 = 0
contando86 = 0
contando87 = 0
contando88 = 0
contando89 = 0


#15
contando90 = 0
contando91 = 0
contando92 = 0
contando93 = 0
contando94 = 0
contando95 = 0


#16
contando96 = 0
contando97 = 0
contando98 = 0
contando99 = 0
contando100 = 0
contando101 = 0


#17
contando102 = 0
contando103 = 0
contando104 = 0
contando105 = 0
contando106 = 0
contando107 = 0


#18
contando108 = 0
contando109 = 0
contando110 = 0
contando111 = 0
contando112 = 0
contando113 = 0


#19
contando114 = 0
contando115 = 0
contando116 = 0
contando117 = 0
contando118 = 0
contando119 = 0


#20
contando120 = 0
contando121 = 0
contando122 = 0
contando123 = 0
contando124 = 0
contando125 = 0


#21
contando126 = 0
contando127 = 0
contando128 = 0
contando129 = 0
contando130 = 0
contando131 = 0


#22
contando132 = 0
contando133 = 0
contando134 = 0
contando135 = 0
contando136 = 0
contando137 = 0


#23
contando138 = 0
contando139 = 0
contando140 = 0
contando141 = 0
contando142 = 0
contando143 = 0


#24
contando144 = 0
contando145 = 0
contando146 = 0
contando147 = 0
contando148 = 0
contando149 = 0


#25
contando150 = 0
contando151 = 0
contando152 = 0
contando153 = 0
contando154 = 0
contando155 = 0


#26
contando156 = 0
contando157 = 0
contando158 = 0
contando159 = 0
contando160 = 0
contando161 = 0


#27
contando162 = 0
contando163 = 0
contando164 = 0
contando165 = 0
contando166 = 0
contando167 = 0


#28
contando168 = 0
contando169 = 0
contando170 = 0
contando171 = 0
contando172 = 0
contando173 = 0


#29
contando174 = 0
contando175 = 0
contando176 = 0
contando177 = 0
contando178 = 0
contando179 = 0


#30
contando180 = 0
contando181 = 0
contando182 = 0
contando183 = 0
contando184 = 0
contando185 = 0


#31
contando186 = 0
contando187 = 0
contando188 = 0
contando189 = 0
contando190 = 0
contando191 = 0


#32
contando192 = 0
contando193 = 0
contando194 = 0
contando195 = 0
contando196 = 0
contando197 = 0


#33
contando198 = 0
contando199 = 0
contando200 = 0
contando201 = 0
contando202 = 0
contando203 = 0


#34
contando204 = 0
contando205 = 0
contando206 = 0
contando207 = 0
contando208 = 0
contando209 = 0


#35
contando210 = 0
contando211 = 0
contando212 = 0
contando213 = 0
contando214 = 0
contando215 = 0


#36
contando216 = 0
contando217 = 0
contando218 = 0
contando219 = 0
contando220 = 0
contando221 = 0


#37
contando222 = 0
contando223 = 0
contando224 = 0
contando225 = 0
contando226 = 0
contando227 = 0


#38
contando228 = 0
contando229 = 0
contando230 = 0
contando231 = 0
contando232 = 0
contando233 = 0

totalizando0 = 0
totalizando1 = 0
totalizando2 = 0
totalizando3 = 0
totalizando4 = 0
totalizando5 = 0


for i in dataframe_mapeamento.collect():
        
    nome_cidade = i[0]
    data0 = str(i[1])
    data1 = data0[0:10]
    vai_chover = i[2]
    
    
    #Pegar a quantidade de dias mapeados 
    
    
    if nome_cidade == cidade[0] and data1 == data_hoje1:
        totalizando0 = 1
        
    
    if nome_cidade == cidade[0] and data1 == data_amanha1:
        totalizando1 = 1
        
      
    if nome_cidade == cidade[0] and data1 == data_amanha2:
        totalizando2 = 1
    
    
    if nome_cidade == cidade[0] and data1 == data_amanha3:
        totalizando3 = 1
    
        
    if nome_cidade == cidade[0] and data1 == data_amanha4:
        totalizando4 = 1
        
        
    if nome_cidade == cidade[0] and data1 == data_amanha5:
        totalizando5 = 1
        


    #Cidade0
    
    
    if nome_cidade == cidade[0] and data1 == data_hoje1 and vai_chover == 'sim':
        contando0 = 1
        
    
    if nome_cidade == cidade[0] and data1 == data_amanha1 and vai_chover == 'sim':
        contando1 = 1
        
      
    if nome_cidade == cidade[0] and data1 == data_amanha2 and vai_chover == 'sim':
        contando2 = 1
    
    
    if nome_cidade == cidade[0] and data1 == data_amanha3 and vai_chover == 'sim':
        contando3 = 1
    
        
    if nome_cidade == cidade[0] and data1 == data_amanha4 and vai_chover == 'sim':
        contando4 = 1
        
        
    if nome_cidade == cidade[0] and data1 == data_amanha5 and vai_chover == 'sim':
        contando5 = 1
        

    
    #cidade1
    
    
    if nome_cidade == cidade[1] and data1 == data_hoje1 and vai_chover == 'sim':
        contando6 = 1
    
    
    if nome_cidade == cidade[1] and data1 == data_amanha1 and vai_chover == 'sim':
        contando7= 1
    
    
    if nome_cidade == cidade[1] and data1 == data_amanha2 and vai_chover == 'sim':
        contando8 = 1
    
    
    if nome_cidade == cidade[1] and data1 == data_amanha3 and vai_chover == 'sim':
        contando9 = 1
    
        
    if nome_cidade == cidade[1] and data1 == data_amanha4 and vai_chover == 'sim':
        contando10 = 1
        
    
    if nome_cidade == cidade[1] and data1 == data_amanha5 and vai_chover == 'sim':
        contando11 = 1
            
    
    
    #Cidade2
    
    
    if nome_cidade == cidade[2] and data1 == data_hoje1 and vai_chover == 'sim':
        contando12 = 1
    

    
    if nome_cidade == cidade[2] and data1 == data_amanha1 and vai_chover == 'sim':
        contando13 = 1
    

    
    if nome_cidade == cidade[2] and data1 == data_amanha2 and vai_chover == 'sim':
        contando14 = 1
    

    
    if nome_cidade == cidade[2] and data1 == data_amanha3 and vai_chover == 'sim':
        contando15 = 1
    

    
    if nome_cidade == cidade[2] and data1 == data_amanha4 and vai_chover == 'sim':
        contando16 = 1
        
    
    
    if nome_cidade == cidade[2] and data1 == data_amanha5 and vai_chover == 'sim':
        contando17 = 1
    
        
    
    
    #Cidade3
    
    
    if nome_cidade == cidade[3] and data1 == data_hoje1 and vai_chover == 'sim':
        contando18 = 1
    

    
    if nome_cidade == cidade[3] and data1 == data_amanha1 and vai_chover == 'sim':
        contando19 = 1
    

    
    if nome_cidade == cidade[3] and data1 == data_amanha2 and vai_chover == 'sim':
        contando20 = 1
    

    
    if nome_cidade == cidade[3] and data1 == data_amanha3 and vai_chover == 'sim':
        contando21 = 1
    

        
    if nome_cidade == cidade[3] and data1 == data_amanha4 and vai_chover == 'sim':
        contando22 = 1
        
        
    
    if nome_cidade == cidade[3] and data1 == data_amanha5 and vai_chover == 'sim':
        contando23 = 1
    
        
    
    #Cidade4
    
    
    if nome_cidade == cidade[4] and data1 == data_hoje1 and vai_chover == 'sim':
        contando24 = 1
    

    
    if nome_cidade == cidade[4] and data1 == data_amanha1 and vai_chover == 'sim':
        contando25 = 1
    

    
    if nome_cidade == cidade[4] and data1 == data_amanha2 and vai_chover == 'sim':
        contando26 = 1
    

    
    if nome_cidade == cidade[4] and data1 == data_amanha3 and vai_chover == 'sim':
        contando27 = 1
    

        
    if nome_cidade == cidade[4] and data1 == data_amanha4 and vai_chover == 'sim':
        contando28 = 1
        
        
    
    if nome_cidade == cidade[4] and data1 == data_amanha5 and vai_chover == 'sim':
        contando29 = 1
    
        
    
    #Cidade5
    
    
    if nome_cidade == cidade[5] and data1 == data_hoje1 and vai_chover == 'sim':
        contando30 = 1
    
    
    
    if nome_cidade == cidade[5] and data1 == data_amanha1 and vai_chover == 'sim':
        contando31 = 1
    

    
    if nome_cidade == cidade[5] and data1 == data_amanha2 and vai_chover == 'sim':
        contando32 = 1
    

    
    if nome_cidade == cidade[5] and data1 == data_amanha3 and vai_chover == 'sim':
        contando33 = 1
    

        
    if nome_cidade == cidade[5] and data1 == data_amanha4 and vai_chover == 'sim':
        contando34 = 1
        
        
    
    if nome_cidade == cidade[5] and data1 == data_amanha5 and vai_chover == 'sim':
        contando35 = 1
    
        
    
    #Cidade6
    
    
    if nome_cidade == cidade[6] and data1 == data_hoje1 and vai_chover == 'sim':
        contando36 = 1
    

    
    if nome_cidade == cidade[6] and data1 == data_amanha1 and vai_chover == 'sim':
        contando37 = 1
    

    
    if nome_cidade == cidade[6] and data1 == data_amanha2 and vai_chover == 'sim':
        contando38 = 1
    

    
    if nome_cidade == cidade[6] and data1 == data_amanha3 and vai_chover == 'sim':
        contando39 = 1
    

        
    if nome_cidade == cidade[6] and data1 == data_amanha4 and vai_chover == 'sim':
        contando40 = 1
        
        
    
    if nome_cidade == cidade[6] and data1 == data_amanha5 and vai_chover == 'sim':
        contando41 = 1
    
        
    
    #Cidade7
    
    
    if nome_cidade == cidade[7] and data1 == data_hoje1 and vai_chover == 'sim':
        contando42 = 1
    

    
    if nome_cidade == cidade[7] and data1 == data_amanha1 and vai_chover == 'sim':
        contando43 = 1
    

    
    if nome_cidade == cidade[7] and data1 == data_amanha2 and vai_chover == 'sim':
        contando44 = 1
    

    
    if nome_cidade == cidade[7] and data1 == data_amanha3 and vai_chover == 'sim':
        contando45 = 1
    

        
    if nome_cidade == cidade[7] and data1 == data_amanha4 and vai_chover == 'sim':
        contando46 = 1
        
        
    
    if nome_cidade == cidade[7] and data1 == data_amanha5 and vai_chover == 'sim':
        contando47 = 1
    
        
    
    #Cidade8
    
    
    if nome_cidade == cidade[8] and data1 == data_hoje1 and vai_chover == 'sim':
        contando48 = 1
    

    
    if nome_cidade == cidade[8] and data1 == data_amanha1 and vai_chover == 'sim':
        contando49 = 1
    

    
    if nome_cidade == cidade[8] and data1 == data_amanha2 and vai_chover == 'sim':
        contando50 = 1
    

    
    if nome_cidade == cidade[8] and data1 == data_amanha3 and vai_chover == 'sim':
        contando51 = 1
    

        
    if nome_cidade == cidade[8] and data1 == data_amanha4 and vai_chover == 'sim':
        contando52 = 1
        
    
    
    if nome_cidade == cidade[8] and data1 == data_amanha5 and vai_chover == 'sim':
        contando53 = 1
    
        
    
    #Cidade9
    
    
    if nome_cidade == cidade[9] and data1 == data_hoje1 and vai_chover == 'sim':
        contando54 = 1
    

    
    if nome_cidade == cidade[9] and data1 == data_amanha1 and vai_chover == 'sim':
        contando55 = 1
    

    
    if nome_cidade == cidade[9] and data1 == data_amanha2 and vai_chover == 'sim':
        contando56 = 1
    

    
    if nome_cidade == cidade[9] and data1 == data_amanha3 and vai_chover == 'sim':
        contando57 = 1
    

        
    if nome_cidade == cidade[9] and data1 == data_amanha4 and vai_chover == 'sim':
        contando58 = 1
        
        
        
    if nome_cidade == cidade[9] and data1 == data_amanha5 and vai_chover == 'sim':
        contando59 = 1
    
        
    
    #cidade0
    
    
    if nome_cidade == cidade[10] and data1 == data_hoje1 and vai_chover == 'sim':
        contando60 = 1
    

    
    if nome_cidade == cidade[10] and data1 == data_amanha1 and vai_chover == 'sim':
        contando61 = 1
    

    
    if nome_cidade == cidade[10] and data1 == data_amanha2 and vai_chover == 'sim':
        contando62 = 1
    

    
    if nome_cidade == cidade[10] and data1 == data_amanha3 and vai_chover == 'sim':
        contando63 = 1
    

        
    if nome_cidade == cidade[10] and data1 == data_amanha4 and vai_chover == 'sim':
        contando64 = 1
        
        
    
    if nome_cidade == cidade[10] and data1 == data_amanha5 and vai_chover == 'sim':
        contando65 = 1
    
        
    
    #cidade1
    
    
    if nome_cidade == cidade[11] and data1 == data_hoje1 and vai_chover == 'sim':
        contando66 = 1
    
        
    
    if nome_cidade == cidade[11] and data1 == data_amanha1 and vai_chover == 'sim':
        contando67 = 1
    
        
    
    if nome_cidade == cidade[11] and data1 == data_amanha2 and vai_chover == 'sim':
        contando68 = 1
    
        
    
    if nome_cidade == cidade[11] and data1 == data_amanha3 and vai_chover == 'sim':
        contando69 = 1
    
        
        
    if nome_cidade == cidade[11] and data1 == data_amanha4 and vai_chover == 'sim':
        contando70 = 1
        
        
    
    if nome_cidade == cidade[11] and data1 == data_amanha5 and vai_chover == 'sim':
        contando71 = 1
    
        
    
    #cidade2
    
    
    if nome_cidade == cidade[12] and data1 == data_hoje1 and vai_chover == 'sim':
        contando72 = 1
    
        
    
    if nome_cidade == cidade[12] and data1 == data_amanha1 and vai_chover == 'sim':
        contando73 = 1
    
        
    
    if nome_cidade == cidade[12] and data1 == data_amanha2 and vai_chover == 'sim':
        contando74 = 1
    
        
    
    if nome_cidade == cidade[12] and data1 == data_amanha3 and vai_chover == 'sim':
        contando75 = 1
    
        
        
    if nome_cidade == cidade[12] and data1 == data_amanha4 and vai_chover == 'sim':
        contando76 = 1
        
        
    
    if nome_cidade == cidade[12] and data1 == data_amanha5 and vai_chover == 'sim':
        contando77 = 1
    
        
    
    #cidade3
    
    
    if nome_cidade == cidade[13] and data1 == data_hoje1 and vai_chover == 'sim':
        contando78 = 1
    
        
    
    if nome_cidade == cidade[13] and data1 == data_amanha1 and vai_chover == 'sim':
        contando79 = 1
    
        
    
    if nome_cidade == cidade[13] and data1 == data_amanha2 and vai_chover == 'sim':
        contando80 = 1
    
        
    
    if nome_cidade == cidade[13] and data1 == data_amanha3 and vai_chover == 'sim':
        contando81 = 1
    
        
        
    if nome_cidade == cidade[13] and data1 == data_amanha4 and vai_chover == 'sim':
        contando82 = 1
        
        
    
    if nome_cidade == cidade[13] and data1 == data_amanha5 and vai_chover == 'sim':
        contando83 = 1
    
        
    
    #cidade4
    
    
    if nome_cidade == cidade[14] and data1 == data_hoje1 and vai_chover == 'sim':
        contando84 = 1
    
        
    
    if nome_cidade == cidade[14] and data1 == data_amanha1 and vai_chover == 'sim':
        contando85 = 1
    
        
    
    if nome_cidade == cidade[14] and data1 == data_amanha2 and vai_chover == 'sim':
        contando86 = 1
    
        
    
    if nome_cidade == cidade[14] and data1 == data_amanha3 and vai_chover == 'sim':
        contando87 = 1
    
        
        
    if nome_cidade == cidade[14] and data1 == data_amanha4 and vai_chover == 'sim':
        contando88 = 1
        
        
        
    if nome_cidade == cidade[14] and data1 == data_amanha5 and vai_chover == 'sim':
        contando89 = 1
    
    
        
    #cidade5
    
    
    if nome_cidade == cidade[15] and data1 == data_hoje1 and vai_chover == 'sim':
        contando90 = 1
    
        
    
    if nome_cidade == cidade[15] and data1 == data_amanha1 and vai_chover == 'sim':
        contando91 = 1
    
        
    
    if nome_cidade == cidade[15] and data1 == data_amanha2 and vai_chover == 'sim':
        contando92 = 1
    
        
    
    if nome_cidade == cidade[15] and data1 == data_amanha3 and vai_chover == 'sim':
        contando93 = 1
    
        
        
    if nome_cidade == cidade[15] and data1 == data_amanha4 and vai_chover == 'sim':
        contando94 = 1
        
        
    
    if nome_cidade == cidade[15] and data1 == data_amanha5 and vai_chover == 'sim':
        contando95 = 1
    
        
    
    #cidade6
    
    
    if nome_cidade == cidade[16] and data1 == data_hoje1 and vai_chover == 'sim':
        contando96 = 1
    
        
    
    if nome_cidade == cidade[16] and data1 == data_amanha1 and vai_chover == 'sim':
        contando97 = 1
    
        
    
    if nome_cidade == cidade[16] and data1 == data_amanha2 and vai_chover == 'sim':
        contando98 = 1
    
        
    
    if nome_cidade == cidade[16] and data1 == data_amanha3 and vai_chover == 'sim':
        contando99 = 1
    
        
        
    if nome_cidade == cidade[16] and data1 == data_amanha4 and vai_chover == 'sim':
        contando100 = 1
        
        
    
    if nome_cidade == cidade[16] and data1 == data_amanha5 and vai_chover == 'sim':
        contando101 = 1
    
        
    
    #cidade7
    
    
    if nome_cidade == cidade[17] and data1 == data_hoje1 and vai_chover == 'sim':
        contando102 = 1
    
        
    
    if nome_cidade == cidade[17] and data1 == data_amanha1 and vai_chover == 'sim':
        contando103 = 1
    
        
    
    if nome_cidade == cidade[17] and data1 == data_amanha2 and vai_chover == 'sim':
        contando104 = 1
    
        
    
    if nome_cidade == cidade[17] and data1 == data_amanha3 and vai_chover == 'sim':
        contando105 = 1
    
        
        
    if nome_cidade == cidade[17] and data1 == data_amanha4 and vai_chover == 'sim':
        contando106 = 1
        
        
    
    if nome_cidade == cidade[17] and data1 == data_amanha5 and vai_chover == 'sim':
        contando107 = 1
    
        
    
    #cidade8
    
    
    if nome_cidade == cidade[18] and data1 == data_hoje1 and vai_chover == 'sim':
        contando108 = 1
    
        
    
    if nome_cidade == cidade[18] and data1 == data_amanha1 and vai_chover == 'sim':
        contando109 = 1
    
        
    
    if nome_cidade == cidade[18] and data1 == data_amanha2 and vai_chover == 'sim':
        contando110 = 1
    
        
    
    if nome_cidade == cidade[18] and data1 == data_amanha3 and vai_chover == 'sim':
        contando111 = 1
    
        
        
    if nome_cidade == cidade[18] and data1 == data_amanha4 and vai_chover == 'sim':
        contando112 = 1
        
        
        
    if nome_cidade == cidade[18] and data1 == data_amanha5 and vai_chover == 'sim':
        contando113 = 1
    
    
        
    
    #cidade9
    
    
    if nome_cidade == cidade[19] and data1 == data_hoje1 and vai_chover == 'sim':
        contando114 = 1
    
        
    
    if nome_cidade == cidade[19] and data1 == data_amanha1 and vai_chover == 'sim':
        contando115 = 1
    
        
    
    if nome_cidade == cidade[19] and data1 == data_amanha2 and vai_chover == 'sim':
        contando116 = 1
    
        
    
    if nome_cidade == cidade[19] and data1 == data_amanha3 and vai_chover == 'sim':
        contando117 = 1
    
        
        
    if nome_cidade == cidade[19] and data1 == data_amanha4 and vai_chover == 'sim':
        contando118 = 1
        
        
    
    if nome_cidade == cidade[19] and data1 == data_amanha5 and vai_chover == 'sim':
        contando119 = 1
    
        
    
    #Cidade20
    
    
    if nome_cidade == cidade[20] and data1 == data_hoje1 and vai_chover == 'sim':
        contando120 = 1
    
        
    
    if nome_cidade == cidade[20] and data1 == data_amanha1 and vai_chover == 'sim':
        contando121 = 1
    
        
    
    if nome_cidade == cidade[20] and data1 == data_amanha2 and vai_chover == 'sim':
        contando122 = 1
    
    
    
    if nome_cidade == cidade[20] and data1 == data_amanha3 and vai_chover == 'sim':
        contando123 = 1
    
        
        
    if nome_cidade == cidade[20] and data1 == data_amanha4 and vai_chover == 'sim':
        contando124 = 1
        
        
        
    if nome_cidade == cidade[20] and data1 == data_amanha5 and vai_chover == 'sim':
        contando125 = 1
    
        
    
    #Cidade21
    
    
    if nome_cidade == cidade[21] and data1 == data_hoje1 and vai_chover == 'sim':
        contando126 = 1
    
        
    
    if nome_cidade == cidade[21] and data1 == data_amanha1 and vai_chover == 'sim':
        contando127 = 1
    
        
    
    if nome_cidade == cidade[21] and data1 == data_amanha2 and vai_chover == 'sim':
        contando128 = 1
    
        
    
    if nome_cidade == cidade[21] and data1 == data_amanha3 and vai_chover == 'sim':
        contando129 = 1
    
        
        
    if nome_cidade == cidade[21] and data1 == data_amanha4 and vai_chover == 'sim':
        contando130 = 1
        
        
    
    if nome_cidade == cidade[21] and data1 == data_amanha5 and vai_chover == 'sim':
        contando131 = 1
    
        
    
    #Cidade22
    
    
    if nome_cidade == cidade[22] and data1 == data_hoje1 and vai_chover == 'sim':
        contando132 = 1
    
        
    
    if nome_cidade == cidade[22] and data1 == data_amanha1 and vai_chover == 'sim':
        contando133 = 1
    
        
    
    if nome_cidade == cidade[22] and data1 == data_amanha2 and vai_chover == 'sim':
        contando134 = 1
    
        
    
    if nome_cidade == cidade[22] and data1 == data_amanha3 and vai_chover == 'sim':
        contando135 = 1
    
        
        
    if nome_cidade == cidade[22] and data1 == data_amanha4 and vai_chover == 'sim':
        contando136 = 1
        
        
    
    if nome_cidade == cidade[22] and data1 == data_amanha5 and vai_chover == 'sim':
        contando137 = 1
    
        
    
    #Cidade23
    
    
    if nome_cidade == cidade[23] and data1 == data_hoje1 and vai_chover == 'sim':
        contando138 = 1
    
        
    
    if nome_cidade == cidade[23] and data1 == data_amanha1 and vai_chover == 'sim':
        contando139 = 1
    
        
    
    if nome_cidade == cidade[23] and data1 == data_amanha2 and vai_chover == 'sim':
        contando140 = 1
    
        
    
    if nome_cidade == cidade[23] and data1 == data_amanha3 and vai_chover == 'sim':
        contando141 = 1
    
        
        
    if nome_cidade == cidade[23] and data1 == data_amanha4 and vai_chover == 'sim':
        contando142 = 1
        
        
    
    if nome_cidade == cidade[23] and data1 == data_amanha5 and vai_chover == 'sim':
        contando143 = 1
    
        
    
    #Cidade24
    
    
    if nome_cidade == cidade[24] and data1 == data_hoje1 and vai_chover == 'sim':
        contando144 = 1
    
        
    
    if nome_cidade == cidade[24] and data1 == data_amanha1 and vai_chover == 'sim':
        contando145 = 1
    
        
    
    if nome_cidade == cidade[24] and data1 == data_amanha2 and vai_chover == 'sim':
        contando146 = 1
    
        
    
    if nome_cidade == cidade[24] and data1 == data_amanha3 and vai_chover == 'sim':
        contando147 = 1
    
        
        
    if nome_cidade == cidade[24] and data1 == data_amanha4 and vai_chover == 'sim':
        contando148 = 1
        
        
        
    if nome_cidade == cidade[24] and data1 == data_amanha5 and vai_chover == 'sim':
        contando149 = 1
    
        
    
    #Cidade25
    
    
    if nome_cidade == cidade[25] and data1 == data_hoje1 and vai_chover == 'sim':
        contando150 = 1
    
        
    
    if nome_cidade == cidade[25] and data1 == data_amanha1 and vai_chover == 'sim':
        contando151 = 1
    
        
    
    if nome_cidade == cidade[25] and data1 == data_amanha2 and vai_chover == 'sim':
        contando152 = 1
    
        
    
    if nome_cidade == cidade[25] and data1 == data_amanha3 and vai_chover == 'sim':
        contando153 = 1
    
        
        
    if nome_cidade == cidade[25] and data1 == data_amanha4 and vai_chover == 'sim':
        contando154 = 1
        
        
        
    if nome_cidade == cidade[25] and data1 == data_amanha5 and vai_chover == 'sim':
        contando155 = 1
    
    
        
    #Cidade26
    
    
    if nome_cidade == cidade[26] and data1 == data_hoje1 and vai_chover == 'sim':
        contando156 = 1
    
        
    
    if nome_cidade == cidade[26] and data1 == data_amanha1 and vai_chover == 'sim':
        contando157 = 1
    
        
    
    if nome_cidade == cidade[26] and data1 == data_amanha2 and vai_chover == 'sim':
        contando158 = 1
    
        
    
    if nome_cidade == cidade[26] and data1 == data_amanha3 and vai_chover == 'sim':
        contando159 = 1
    
        
        
    if nome_cidade == cidade[26] and data1 == data_amanha4 and vai_chover == 'sim':
        contando160 = 1
        
        
    
    if nome_cidade == cidade[26] and data1 == data_amanha5 and vai_chover == 'sim':
        contando161 = 1
    
    
    
    #Cidade27
    
    
    if nome_cidade == cidade[27] and data1 == data_hoje1 and vai_chover == 'sim':
        contando162 = 1
    
        
    
    if nome_cidade == cidade[27] and data1 == data_amanha1 and vai_chover == 'sim':
        contando163 = 1
    
        
    
    if nome_cidade == cidade[27] and data1 == data_amanha2 and vai_chover == 'sim':
        contando164 = 1
    
        
    
    if nome_cidade == cidade[27] and data1 == data_amanha3 and vai_chover == 'sim':
        contando165 = 1
    
        
        
    if nome_cidade == cidade[27] and data1 == data_amanha4 and vai_chover == 'sim':
        contando166 = 1
        
        
        
    if nome_cidade == cidade[27] and data1 == data_amanha5 and vai_chover == 'sim':
        contando167 = 1
    
        
    
    #Cidade28
    
    
    if nome_cidade == cidade[28] and data1 == data_hoje1 and vai_chover == 'sim':
        contando168 = 1
    
        
    
    if nome_cidade == cidade[28] and data1 == data_amanha1 and vai_chover == 'sim':
        contando169 = 1
    
        
    
    if nome_cidade == cidade[28] and data1 == data_amanha2 and vai_chover == 'sim':
        contando170 = 1
    
        
    
    if nome_cidade == cidade[28] and data1 == data_amanha3 and vai_chover == 'sim':
        contando171 = 1
    
        
        
    if nome_cidade == cidade[28] and data1 == data_amanha4 and vai_chover == 'sim':
        contando172 = 1
        
        
    
    if nome_cidade == cidade[28] and data1 == data_amanha5 and vai_chover == 'sim':
        contando173 = 1
    
    
        
    #Cidade29
    
    
    if nome_cidade == cidade[29] and data1 == data_hoje1 and vai_chover == 'sim':
        contando174 = 1
    
        
    
    if nome_cidade == cidade[29] and data1 == data_amanha1 and vai_chover == 'sim':
        contando175 = 1
    
        
    
    if nome_cidade == cidade[29] and data1 == data_amanha2 and vai_chover == 'sim':
        contando176 = 1
    
        
    
    if nome_cidade == cidade[29] and data1 == data_amanha3 and vai_chover == 'sim':
        contando177 = 1
    
        
        
    if nome_cidade == cidade[29] and data1 == data_amanha4 and vai_chover == 'sim':
        contando178 = 1
        
        
        
    if nome_cidade == cidade[29] and data1 == data_amanha5 and vai_chover == 'sim':
        contando179 = 1
    
    
        
    #Cidade30
    
    
    if nome_cidade == cidade[30] and data1 == data_hoje1 and vai_chover == 'sim':
        contando180 = 1
    
        
    
    if nome_cidade == cidade[30] and data1 == data_amanha1 and vai_chover == 'sim':
        contando181 = 1
    
        
    
    if nome_cidade == cidade[30] and data1 == data_amanha2 and vai_chover == 'sim':
        contando182 = 1
    
        
    
    if nome_cidade == cidade[30] and data1 == data_amanha3 and vai_chover == 'sim':
        contando183 = 1
    
        
        
    if nome_cidade == cidade[30] and data1 == data_amanha4 and vai_chover == 'sim':
        contando184 = 1
        
        
    
    if nome_cidade == cidade[30] and data1 == data_amanha5 and vai_chover == 'sim':
        contando185 = 1
    
    
        
    #Cidade31
    
    
    if nome_cidade == cidade[31] and data1 == data_hoje1 and vai_chover == 'sim':
        contando186 = 1
    
        
    
    if nome_cidade == cidade[31] and data1 == data_amanha1 and vai_chover == 'sim':
        contando187 = 1
    
        
    
    if nome_cidade == cidade[31] and data1 == data_amanha2 and vai_chover == 'sim':
        contando188 = 1
    
        
    
    if nome_cidade == cidade[31] and data1 == data_amanha3 and vai_chover == 'sim':
        contando189 = 1
    
        
        
    if nome_cidade == cidade[31] and data1 == data_amanha4 and vai_chover == 'sim':
        contando190 = 1
        
        
        
    if nome_cidade == cidade[31] and data1 == data_amanha5 and vai_chover == 'sim':
        contando191 = 1
    
        
    
    #Cidade32
    
    
    if nome_cidade == cidade[32] and data1 == data_hoje1 and vai_chover == 'sim':
        contando192 = 1
    
        
    
    if nome_cidade == cidade[32] and data1 == data_amanha1 and vai_chover == 'sim':
        contando193 = 1
    
        
    
    if nome_cidade == cidade[32] and data1 == data_amanha2 and vai_chover == 'sim':
        contando194 = 1
    
        
    
    if nome_cidade == cidade[32] and data1 == data_amanha3 and vai_chover == 'sim':
        contando195 = 1
    
        
        
    if nome_cidade == cidade[32] and data1 == data_amanha4 and vai_chover == 'sim':
        contando196 = 1
        
        
    
    if nome_cidade == cidade[32] and data1 == data_amanha5 and vai_chover == 'sim':
        contando197 = 1
    
        
    
    #Cidade33
    
    
    if nome_cidade == cidade[33] and data1 == data_hoje1 and vai_chover == 'sim':
        contando198 = 1
    
        
    
    if nome_cidade == cidade[33] and data1 == data_amanha1 and vai_chover == 'sim':
        contando199 = 1
    
        
    
    if nome_cidade == cidade[33] and data1 == data_amanha2 and vai_chover == 'sim':
        contando200 = 1
    
        
    
    if nome_cidade == cidade[33] and data1 == data_amanha3 and vai_chover == 'sim':
        contando201 = 1
    
        
        
    if nome_cidade == cidade[33] and data1 == data_amanha4 and vai_chover == 'sim':
        contando202 = 1
        
        
    
    if nome_cidade == cidade[33] and data1 == data_amanha5 and vai_chover == 'sim':
        contando203 = 1
    
    
        
    #Cidade34
    
    
    if nome_cidade == cidade[34] and data1 == data_hoje1 and vai_chover == 'sim':
        contando204 = 1
    
        
    
    if nome_cidade == cidade[34] and data1 == data_amanha1 and vai_chover == 'sim':
        contando205 = 1
    
        
    
    if nome_cidade == cidade[34] and data1 == data_amanha2 and vai_chover == 'sim':
        contando206 = 1
    
        
    
    if nome_cidade == cidade[34] and data1 == data_amanha3 and vai_chover == 'sim':
        contando207 = 1
    
        
        
    if nome_cidade == cidade[34] and data1 == data_amanha4 and vai_chover == 'sim':
        contando208 = 1
        
        
        
    if nome_cidade == cidade[34] and data1 == data_amanha5 and vai_chover == 'sim':
        contando209 = 1
    
        
    
    #Cidade35
    
    
    if nome_cidade == cidade[35] and data1 == data_hoje1 and vai_chover == 'sim':
        contando210 = 1
    
        
    
    if nome_cidade == cidade[35] and data1 == data_amanha1 and vai_chover == 'sim':
        contando211 = 1
    
        
    
    if nome_cidade == cidade[35] and data1 == data_amanha2 and vai_chover == 'sim':
        contando212 = 1
    
        
    
    if nome_cidade == cidade[35] and data1 == data_amanha3 and vai_chover == 'sim':
        contando213 = 1
    
        
        
    if nome_cidade == cidade[35] and data1 == data_amanha4 and vai_chover == 'sim':
        contando214 = 1
        
        
    
    if nome_cidade == cidade[35] and data1 == data_amanha5 and vai_chover == 'sim':
        contando215 = 1
    
        
    
    #Cidade36
    
    
    if nome_cidade == cidade[36] and data1 == data_hoje1 and vai_chover == 'sim':
        contando216 = 1
    
        
    
    if nome_cidade == cidade[36] and data1 == data_amanha1 and vai_chover == 'sim':
        contando217 = 1
    
        
    
    if nome_cidade == cidade[36] and data1 == data_amanha2 and vai_chover == 'sim':
        contando218 = 1
    
        
    
    if nome_cidade == cidade[36] and data1 == data_amanha3 and vai_chover == 'sim':
        contando219 = 1
    
        
        
    if nome_cidade == cidade[36] and data1 == data_amanha4 and vai_chover == 'sim':
        contando220 = 1
        
        
        
    if nome_cidade == cidade[36] and data1 == data_amanha5 and vai_chover == 'sim':
        contando221 = 1
    
        
    
    #Cidade37
    
    
    if nome_cidade == cidade[37] and data1 == data_hoje1 and vai_chover == 'sim':
        contando222 = 1
    
        
    
    if nome_cidade == cidade[37] and data1 == data_amanha1 and vai_chover == 'sim':
        contando223 = 1
    
        
    
    if nome_cidade == cidade[37] and data1 == data_amanha2 and vai_chover == 'sim':
        contando224 = 1
    
        
    
    if nome_cidade == cidade[37] and data1 == data_amanha3 and vai_chover == 'sim':
        contando225 = 1
    
        
        
    if nome_cidade == cidade[37] and data1 == data_amanha4 and vai_chover == 'sim':
        contando226 = 1
        
        
    
    if nome_cidade == cidade[37] and data1 == data_amanha5 and vai_chover == 'sim':
        contando227 = 1
    
    
        
    #Cidade38
    
    
    if nome_cidade == cidade[38] and data1 == data_hoje1 and vai_chover == 'sim':
        contando228 = 1
    
        
    
    if nome_cidade == cidade[38] and data1 == data_amanha1 and vai_chover == 'sim':
        contando229 = 1
    
        
    
    if nome_cidade == cidade[38] and data1 == data_amanha2 and vai_chover == 'sim':
        contando230 = 1
    
        
    
    if nome_cidade == cidade[38] and data1 == data_amanha3 and vai_chover == 'sim':
        contando231 = 1
    
        
        
    if nome_cidade == cidade[38] and data1 == data_amanha4 and vai_chover == 'sim':
        contando232 = 1
        
        
    
    if nome_cidade == cidade[38] and data1 == data_amanha5 and vai_chover == 'sim':
        contando233 = 1
    
    
    
# Somando a quantidade de dias que vai chover por cidade

#Sim

lista_contador0 = []
lista_contador1 = []
lista_contador2 = []
lista_contador3 = []
lista_contador4 = []
lista_contador5 = []
lista_contador6 = []
lista_contador7 = []
lista_contador8 = []
lista_contador9 = []
lista_contador10 = []
lista_contador11 = []
lista_contador12 = []
lista_contador13 = []
lista_contador14 = []
lista_contador15 = []
lista_contador16 = []
lista_contador17 = []
lista_contador18 = []
lista_contador19 = []
lista_contador20 = []
lista_contador21 = []
lista_contador22 = []
lista_contador23 = []
lista_contador24 = []
lista_contador25 = []
lista_contador26 = []
lista_contador27 = []
lista_contador28 = []
lista_contador29 = []
lista_contador30 = []
lista_contador31 = []
lista_contador32 = []
lista_contador33 = []
lista_contador34 = []
lista_contador35 = []
lista_contador36 = []
lista_contador37 = []
lista_contador38 = []


# Contar tudo

#0

contar0 = contando0 + contando1 + contando2 + contando3 + contando4 + contando5
lista_contador0.append(contar0)

#1

contar1 = contando6 +  contando7 + contando8 + contando9 + contando10 + contando11
lista_contador1.append(contar1)

#2

contar2 = contando12 + contando13 + contando14 + contando15 + contando16 + contando17
lista_contador2.append(contar2)

#3

contar3 = contando18 + contando19 + contando20 + contando21 + contando22 + contando23 
lista_contador3.append(contar3)


#4

contar4 = contando24 + contando25 + contando26 + contando27 + contando28 + contando29
lista_contador4.append(contar4)


#5

contar5 = contando30 + contando31 + contando32 + contando33 + contando34 + contando35
lista_contador5.append(contar5)


#6

contar6 = contando36 + contando37 + contando38 + contando39 + contando40 + contando41
lista_contador6.append(contar6)




#7

contar7 = contando42 + contando43 + contando44 + contando45 + contando46 + contando47 
lista_contador7.append(contar7)


#8

contar8 = contando48 + contando49 + contando50 + contando51 + contando52 + contando53
lista_contador8.append(contar8)


#9

contar9 = contando54 + contando55 + contando56 + contando57 + contando58 + contando59
lista_contador9.append(contar9)


#10

contar10 = contando60 + contando61 + contando62 + contando63 + contando64 + contando65
lista_contador10.append(contar10)


#11

contar11 = contando66 + contando67 + contando68 + contando69 + contando70 + contando71
lista_contador11.append(contar11)


#12

contar12 = contando72 + contando73 + contando74 + contando75 + contando76 + contando77 
lista_contador12.append(contar12)


#13

contar13 = contando78 + contando79 + contando80 + contando81 + contando82 + contando83
lista_contador13.append(contar13)


#14

contar14 = contando84 + contando85 + contando86 + contando87 + contando88 + contando89
lista_contador14.append(contar14)


#15

contar15 = contando90 + contando91 + contando92 + contando93 + contando94 + contando95
lista_contador15.append(contar15)


#16

contar16 = contando96 + contando97 + contando98 + contando99 + contando100 + contando101
lista_contador16.append(contar16)


#17

contar17 = contando102 + contando103 + contando104 + contando105 + contando106 + contando107
lista_contador17.append(contar17)


#18

contar18 = contando108 + contando109 + contando110 + contando111 + contando112 + contando113
lista_contador18.append(contar18)


#19

contar19 = contando114 + contando115 + contando116 + contando117 + contando118 + contando119
lista_contador19.append(contar19)


#20

contar20 = contando120 + contando121 + contando122 + contando123 + contando124 + contando125
lista_contador20.append(contar20)


#21

contar21 = contando126 + contando127 + contando128 + contando129 + contando130 + contando131
lista_contador21.append(contar21)


#22

contar22 = contando132 + contando133 + contando134 + contando135 + contando136 + contando137
lista_contador22.append(contar22)


#23

contar23 = contando138 + contando139 + contando140 + contando141 + contando142 + contando143
lista_contador23.append(contar23)


#24

contar24 = contando144 + contando145 + contando146 + contando147 + contando148 + contando149
lista_contador24.append(contar24)


#25

contar25 = contando150 + contando151 + contando152 + contando153 + contando154 + contando155 
lista_contador25.append(contar25)


#26

contar26 = contando156 + contando157 + contando158 + contando159 + contando160 + contando161
lista_contador26.append(contar26)


#27

contar27 = contando162 + contando163 + contando164 + contando165 + contando166 + contando167
lista_contador27.append(contar27)


#28

contar28 = contando168 + contando169 + contando170 + contando171 + contando172 + contando173
lista_contador28.append(contar28)


#29

contar29 = contando174 + contando175 + contando176 + contando177 + contando178 + contando179
lista_contador29.append(contar29)


#30

contar30 = contando180 + contando181 + contando182 + contando183 + contando184 + contando185
lista_contador30.append(contar30)


#31

contar31 = contando186 + contando187 + contando188 + contando189 + contando190 + contando191
lista_contador31.append(contar31)


#32

contar32 = contando192 + contando193 + contando194 + contando195 + contando196 + contando197
lista_contador32.append(contar32)


#33

contar33 = contando198 + contando199 + contando200 + contando201 + contando202 + contando203
lista_contador33.append(contar33)


#34

contar34 = contando204 + contando205 + contando206 + contando207 + contando208 + contando209
lista_contador34.append(contar34)


#35

contar35 = contando210 + contando211 + contando212 + contando213 + contando214 + contando215
lista_contador35.append(contar35)


#36

contar36 = contando216 + contando217 + contando218 + contando219 + contando220 + contando221
lista_contador36.append(contar36)


#37

contar37 = contando222 + contando223 + contando224 + contando225 + contando226 + contando227
lista_contador37.append(contar37)


#38

contar38 = contando228 + contando229 + contando230 + contando231 + contando232 + contando233
lista_contador38.append(contar38)


# Totalizador (saber a quantidade diferentes de datas) 

totalizador = totalizando0 + totalizando1 + totalizando2 + totalizando3 + totalizando4 + totalizando5


# Concatenando lista contador


lista_contador0.extend(lista_contador1)
lista_contador0.extend(lista_contador2)
lista_contador0.extend(lista_contador3)
lista_contador0.extend(lista_contador4)
lista_contador0.extend(lista_contador5)
lista_contador0.extend(lista_contador6)
lista_contador0.extend(lista_contador7)
lista_contador0.extend(lista_contador8)
lista_contador0.extend(lista_contador9)
lista_contador0.extend(lista_contador10)
lista_contador0.extend(lista_contador11)
lista_contador0.extend(lista_contador12)
lista_contador0.extend(lista_contador13)
lista_contador0.extend(lista_contador14)
lista_contador0.extend(lista_contador15)
lista_contador0.extend(lista_contador16)
lista_contador0.extend(lista_contador17)
lista_contador0.extend(lista_contador18)
lista_contador0.extend(lista_contador19)
lista_contador0.extend(lista_contador20)
lista_contador0.extend(lista_contador21)
lista_contador0.extend(lista_contador22)
lista_contador0.extend(lista_contador23)
lista_contador0.extend(lista_contador24)
lista_contador0.extend(lista_contador25)
lista_contador0.extend(lista_contador26)
lista_contador0.extend(lista_contador27)
lista_contador0.extend(lista_contador28)
lista_contador0.extend(lista_contador29)
lista_contador0.extend(lista_contador30)
lista_contador0.extend(lista_contador31)
lista_contador0.extend(lista_contador32)
lista_contador0.extend(lista_contador33)
lista_contador0.extend(lista_contador34)
lista_contador0.extend(lista_contador35)
lista_contador0.extend(lista_contador36)
lista_contador0.extend(lista_contador37)
lista_contador0.extend(lista_contador38)

# %% [markdown]
# **CALCULANDO A QUANTIDADE DE DIAS DE CHUVA, NÃO CHUVA E TOTAL DE DIAS MAPEADOS**

# %%
column_qtd_dias_chovendo = lista_contador0
column_qtd_dias_sem_chuva = []
column_total_dias_mapeados = [totalizador] * 39


# Quando vier 6 datas diferentes na API

if totalizador == 6:

    for gama in lista_contador0:
        
        if gama == 6:
            gama0 = 0
            column_qtd_dias_sem_chuva.append(gama0)
        if gama == 5:
            gama1 = 1
            column_qtd_dias_sem_chuva.append(gama1)
        if gama == 4:
            gama2 = 2
            column_qtd_dias_sem_chuva.append(gama2)
        if gama == 3:
            gama3 = 3
            column_qtd_dias_sem_chuva.append(gama3)
        if gama == 2:
            gama4 = 4
            column_qtd_dias_sem_chuva.append(gama4)
        if gama == 1:
            gama5 = 5
            column_qtd_dias_sem_chuva.append(gama5)
        if gama == 0:
            gama6 = 6
            column_qtd_dias_sem_chuva.append(gama6)
            

# Quando vier 5 datas diferentes na API

if totalizador == 5:
    

    for delta in lista_contador0:
        
        if delta == 5:
            delta0 = 0
            column_qtd_dias_sem_chuva.append(delta0)
        if delta == 4:
            delta1 = 1
            column_qtd_dias_sem_chuva.append(delta1)
        if delta == 3:
            delta2 = 2
            column_qtd_dias_sem_chuva.append(delta2)
        if delta == 2:
            delta3 = 3
            column_qtd_dias_sem_chuva.append(delta3)
        if delta == 1:
            delta4 = 4
            column_qtd_dias_sem_chuva.append(delta4)
        if delta == 0:
            delta5 = 5
            column_qtd_dias_sem_chuva.append(delta5)
            
#print(column_qtd_dias_chovendo)
#print(column_qtd_dias_sem_chuva)
#print(column_total_dias_mapeados)
#print(totalizador) #Mostra a quantidade de datas diferentes

# %% [markdown]
# **CRIANDO DATAFRAME (QTD DE DIAS CHOVENDO, NÃO CHOVENDO E QTD DE DIAS MAPEADOS)**

# %%
colunas2 = StructType([StructField('Cidade', StringType(), True),
                       StructField('QtdDiasVaiChover', IntegerType(), True),
                       StructField('QtdDiasNaoVaiChover', IntegerType(), True),
                       StructField('TotalDiasMapeados', IntegerType(), True)])

dataframe_mapeamento = spark.createDataFrame(zip(cidade, column_qtd_dias_chovendo,
                                                 column_qtd_dias_sem_chuva, column_total_dias_mapeados), colunas2)

# %% [markdown]
# **CRIANDO UMA VISÃO TEMPORÁRIA DA TABELA PREVISÕES**

# %%
dataframe_previsoes.createOrReplaceTempView("forecasts")
spark.sql("SELECT Cidade, Data FROM forecasts").show(41)

# %% [markdown]
# **CRIANDO UMA VISÃO TEMPORÁRIA DA TABELA MAPEAMENTO**

# %%
dataframe_mapeamento.createOrReplaceTempView("mapping")
spark.sql("SELECT * FROM mapping").show(39)

# %% [markdown]
# **EXPORTANDO DATAFRAME (PREVISÕES E MAPEAMENTO) PARA UM ARQUIVO CSV**

# %%
#SPARK

#dataframe_previsoes.write.csv("/home/rowedder/tabela1.csv")
#dataframe_mapeamento.write.csv("/home/rowedder/tabela2.csv")

# %% [markdown]
# **CONVERTENDO DATAFRAME SPARK EM DATAFRAME PANDAS**

# %%
import pandas

# Previsões

tabela1_pandas = dataframe_previsoes
tabela1_pandas = tabela1_pandas.toPandas() # Convertendo para dataframe pandas

# Mapeamento

tabela2_pandas = dataframe_mapeamento
tabela2_pandas = tabela2_pandas.toPandas() # Convertendo para dataframe pandas

# %% [markdown]
# **EXPORTANDO DATAFRAMES (PREVISÕES E MAPEAMENTO) PARA ARQUIVOS CSV**

# %%
#PANDAS

tabela1_pandas.to_csv("/home/rowedder/Tabelas/tabela1.csv")
tabela2_pandas.to_csv("/home/rowedder/Tabelas/tabela2.csv")
